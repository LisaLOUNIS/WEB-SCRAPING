# %% [markdown]
# #API scrapping of all the pages of Google Jobs

# %%
import requests

def fetch_all_google_jobs_data(api_key, query, location, hl="en", chips=None):
    """
    Récupère les données de toutes les pages de l'API Google Jobs pour une recherche donnée.

    Paramètres :
    api_key (str): Clé privée SerpApi.
    query (str): Requête de recherche.
    location (str, optionnel): Lieu géographique pour la recherche.
    hl (str): Langue pour la recherche.
    chips (list, optionnel): Conditions supplémentaires pour la requête.

    Retourne :
    list: Toutes les réponses JSON analysées de l'API.
    """
    all_results = []
    start = 0
    while True:
        # Paramètres pour la requête API
        params = {
            "engine": "google_jobs",
            "q": query,
            "start": start,
            "hl": hl,
            "api_key": api_key
        }

        if location:
            params["location"] = location

        if chips:
            params["chips"] = ','.join(chips)

        # URL de base pour l'API Google Jobs
        base_url = "https://serpapi.com/search.json"

        # Envoi d'une requête GET à l'API
        response = requests.get(base_url, params=params)
        if response.status_code == 200:
            data = response.json()
            all_results.append(data)

            # Vérifier s'il y a encore des résultats
            if "jobs_results" not in data or not data["jobs_results"]:
                break

            start += 20  # Incrémenter pour la prochaine page
        else:
            break

    return all_results

# Utilisation de la fonction
# Remplacez 'your_api_key' par votre clé SerpApi rée
complete_data = fetch_all_google_jobs_data("b384a7a8bd5ed660d935e64bc467147a6587986f9eeee21c92e5468fa37c0016", "Data", "Italy")

# %%
complete_data
# Out:
# [{'search_metadata': {'id': '65ac3c6dc9de455e8ce489f0',
#    'status': 'Success',
#    'json_endpoint': 'https://serpapi.com/searches/7adfbc37a851fbc3/65ac3c6dc9de455e8ce489f0.json',
#    'created_at': '2024-01-20 21:34:37 UTC',
#    'processed_at': '2024-01-20 21:34:37 UTC',
#    'google_jobs_url': 'https://www.google.com/search?q=Data&ibp=htl;jobs&uule=w+CAIQICILU3dpdHplcmxhbmQ&hl=en&start=0',
#    'raw_html_file': 'https://serpapi.com/searches/7adfbc37a851fbc3/65ac3c6dc9de455e8ce489f0.html',
#    'total_time_taken': 0.74},
#   'search_parameters': {'q': 'Data',
#    'engine': 'google_jobs',
#    'location_requested': 'Switzerland',
#    'location_used': 'Switzerland',
#    'google_domain': 'google.com',
#    'hl': 'en',
#    'start': 0},
#   'jobs_results': [{'title': 'Flow Cytometry Data Analyst',
#     'company_name': 'Roche',
#     'location': '  Basel, Switzerland   ',
#     'via': 'via Roche Careers',
#     'description': "The Position\n\nIn Roche’s Pharmaceutical Research and Early Development organization (pRED), we make transformative medicines for patients in order to tackle some of the world’s toughest unmet healthcare needs. At pRED, we are united by our mission to transform science into medicines. Together, we create a culture defined by curiosity, responsibility and humility, where our talented people are empowered and inspired to bring forward extraordinary life-changing innovation at speed.\n\n360 Labs Initiative at a Glance\n\nThe 360 Labs are a new capability that is currently being built up within the Pharmaceutical Research and Early Development organization (pRED). The primary mission of this effort is to provide greater access and support for the use of cutting-edge biomedical research technologies by scientists across our discovery portfolio.\n\nOperating as an integrated ecosystem, the 360 Lab environment will deliver core scientific technologies, expertise and enabling activities, as well as... facilitate knowledge sharing and learning experiences in close collaboration with our therapeutic areas and functions. Together, these efforts will serve to increase the speed, enhance the robustness and improve the sustainability of our exploratory research and early discovery activities.\n\nWe are currently recruiting scientific professionals with varied backgrounds in Flow Cytometry, Genomics, Proteomics, Histopathology, and Microscopy / Imaging. In these new roles, your collaborative mindset is as valued as your scientific expertise. The 360 Labs are by nature a hands-on, interactive workplace where face-to-face presence in our labs is a priority. Our ambition is to bring to life a thriving workplace environment, acting as an highly integrated ecosystem, supporting research and development, working collaboratively, and focused on fostering excellence and sustainability.\n\nJob Mission and Impact\n\nThe Flow Cytometry Core Technology Platform in the 360 Labs Initiative is seeking to add to its team an experienced, highly motivated and collaborative Flow Cytometry Data Analyst. The successful candidate will have a strong background in computational biology with a high-proficiency in the processing, analysis, and visualization of flow cytometry data. You will work as a part of a matrix team and collaborate closely with experts from various pRED therapeutic areas and functions to advance drug discovery projects and will participate in the continued evolution of the Flow Cytometry Core Technology Platform within the pRED organization.\n\nYour Role and Responsibilities\n• You will work collaboratively with the Flow 360 Core Technology Platform team, and other wet lab and bioinformatic teams across the pRED organization, to support the analysis of high-dimensional and high-throughput datasets from flow cytometry experiments\n• You will establish high dimensional data analysis pipelines using commercially available software (as Tercen or OMIQ), or in some cases develop new solutions (using R).\n• You will, in collaboration with the Flow Cytometry Technology Platform team, organize educational workshops on complex data analysis approaches in flow cytometry.\n• You will continually evaluate and understand the needs of the different disease areas in pRED to identify and deliver the best analytical solutions for flow cytometry.\n• You will embrace a continuous learning mindset by actively engaging with the scientific literature to stay abreast of emergent bioinformatics approaches in the flow cytometry field.\n\nYour Profile\n• You have a Master's or PhD degree in computational biology, bioinformatics, biostatistics, or similar field with a deep understanding of molecular biology.\n• You have wide-ranging experience in the complex analyses of high-dimensional flow cytometry data, with an in-depth proficiency in R and at least one other programming language (Python, Perl, C/C++, Java).\n• You are familiar with the software to ...
#     'job_highlights': [{'items': ["The Position\n\nIn Roche’s Pharmaceutical Research and Early Development organization (pRED), we make transformative medicines for patients in order to tackle some of the world’s toughest unmet healthcare needs. At pRED, we are united by our mission to transform science into medicines. Together, we create a culture defined by curiosity, responsibility and humility, where our talented people are empowered and inspired to bring forward extraordinary life-changing innovation at speed.\n\n360 Labs Initiative at a Glance\n\nThe 360 Labs are a new capability that is currently being built up within the Pharmaceutical Research and Early Development organization (pRED). The primary mission of this effort is to provide greater access and support for the use of cutting-edge biomedical research technologies by scientists across our discovery portfolio.\n\nOperating as an integrated ecosystem, the 360 Lab environment will deliver core scientific technologies, expertise and enabling activities, as well as... facilitate knowledge sharing and learning experiences in close collaboration with our therapeutic areas and functions. Together, these efforts will serve to increase the speed, enhance the robustness and improve the sustainability of our exploratory research and early discovery activities.\n\nWe are currently recruiting scientific professionals with varied backgrounds in Flow Cytometry, Genomics, Proteomics, Histopathology, and Microscopy / Imaging. In these new roles, your collaborative mindset is as valued as your scientific expertise. The 360 Labs are by nature a hands-on, interactive workplace where face-to-face presence in our labs is a priority. Our ambition is to bring to life a thriving workplace environment, acting as an highly integrated ecosystem, supporting research and development, working collaboratively, and focused on fostering excellence and sustainability.\n\nJob Mission and Impact\n\nThe Flow Cytometry Core Technology Platform in the 360 Labs Initiative is seeking to add to its team an experienced, highly motivated and collaborative Flow Cytometry Data Analyst. The successful candidate will have a strong background in computational biology with a high-proficiency in the processing, analysis, and visualization of flow cytometry data. You will work as a part of a matrix team and collaborate closely with experts from various pRED therapeutic areas and functions to advance drug discovery projects and will participate in the continued evolution of the Flow Cytometry Core Technology Platform within the pRED organization.\n\nYour Role and Responsibilities\n• You will work collaboratively with the Flow 360 Core Technology Platform team, and other wet lab and bioinformatic teams across the pRED organization, to support the analysis of high-dimensional and high-throughput datasets from flow cytometry experiments\n• You will establish high dimensional data analysis pipelines using commercially available software (as Tercen or OMIQ), or in some cases develop new solutions (using R).\n• You will, in collaboration with the Flow Cytometry Technology Platform team, organize educational workshops on complex data analysis approaches in flow cytometry.\n• You will continually evaluate and understand the needs of the different disease areas in pRED to identify and deliver the best analytical solutions for flow cytometry.\n• You will embrace a continuous learning mindset by actively engaging with the scientific literature to stay abreast of emergent bioinformatics approaches in the flow cytometry field.\n\nYour Profile\n• You have a Master's or PhD degree in computational biology, bioinformatics, biostatistics, or similar field with a deep understanding of molecular biology.\n• You have wide-ranging experience in the complex analyses of high-dimensional flow cytometry data, with an in-depth proficiency in R and at least one other programming language (Python, Perl, C/C++, Java).\n• You are familiar with  ...
#     'related_links': [{'link': 'http://www.roche.com/', 'text': 'roche.com'},
#      {'link': 'https://www.google.com/search?sca_esv=600122311&hl=en&q=Roche&sa=X&ved=0ahUKEwiwybLo9eyDAxX1D1kFHdOJAZIQmJACCO0K',
#       'text': 'See web results for Roche'}],
#     'thumbnail': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRAaksaUfLEOk1fIQPvb_ruWUxfWDbRhyIRQ8EH&s=0',
#     'extensions': ['3 days ago', 'Full-time'],
#     'detected_extensions': {'posted_at': '3 days ago',
#      'schedule_type': 'Full-time'},
#     'job_id': '...'},
#    {'title': 'MOSE Data Strategy, Governance and Management Manager (location: EU)',
#     'company_name': 'ABB',
#     'location': '  Baden, Switzerland   (+2 others)   ',
#     'via': 'via ABB Career',
#     'description': 'MOSE Data Strategy, Governance and Management Manager (location: EU)\nTake your next career step at ABB with a global team that is energizing the transformation of society and industry to achieve a more productive, sustainable future.\n\nAt ABB, we have the clear goal of driving diversity and inclusion across all dimensions: gender, LGBTQ+, abilities, ethnicity and generations. Together, we are embarking on a journey where each and every one of us, individually and collectively, welcomes and celebrates individual differences.\n\nThe MOSE Data Strategy connects the dots between products, technology, processes, services, and people across the MOSE division to enable and support our business objectives and create new opportunities for growth.\n\nIn this role, you will be accountable for developing and implementing the MOSE Installed Base Data Strategy and Data Architecture that enable and support the MOSE business strategy and objectives.\n\nYou will also be accountable for leading the design... implementation, and support of end-to-end Data Processes and Governance framework that will be enabled by the Data Management backend platform. The platform will serve as a common data repository and provide data services to all applications across the MOSE division as well as other MO divisions as required.\n\nAdditionally, you will be accountable for planning and leading the execution of required data programs across the MOSE division, ensuring their alignment with other MO BA and divisional programs and adherence to the enterprise and data architecture standards and guidelines, and ensuring the end-to-end data security, integrity, compliance, and quality in delivered solutions and services.\n\nThis role is open globally, but its location is set in ABB Offices in Krakow (Poland), Helsinki (Finland), or Baden (Switzerland).\nThis is a position with global grade\n\n10\nThis position reports to\n\nMOSE CIO\nYour responsibilities\n• Accountable for the MOSE Division Data Strategy, end-to-end Data Process design, Data Governance framework, and Data Architecture. Own the implementation roadmap and deliverables.\n• Foster and drive collaboration across MO/MOSE business and key IS stakeholders to a common, consistent, and holistic approach in designing end-to-end processes and data flows and their usage across the IS ecosystem.\n• Responsible for the data architecture in all business/IS and Data & Analytics solutions used by the MOSE business service lines and functions.\n• Deeply understand business strategy, objectives, and insights to design and implement optimal data processes, governance, and management frameworks and flows across different service lines/functions and use cases across MO divisions and in MOSE.\n• Drive and secure alignment on Data Processes, Governance, and Management across business stakeholders and MO/MOSE IS programs.\n• Lead business requirements discussions across MOSE business domains for functional Data & Analytics processes, governance, and management in all MOSE solutions, providing technical expertise and ensuring a holistic approach for data-related domains.\n• Get engaged in and lead data requirement analysis and data engineering in all MOSE programs to ensure proper reusability and leverage of the existing portfolio before building new solutions. Drive validation and prioritization of business demand related to the data domain in collaboration with business process and data owners and IS stakeholders across MOSE organizations.\n• Organize and manage the support and timely resolution of data-related issues in processes, governance, or management areas during project delivery to avoid delays or any other negative impact on the project or service. Collaborate with business and project teams to develop and deploy the best feasible and cost-efficient data solutions and services for the business.\n• Drive standardization of data and analytics tools across service lines/functions and existing solu ...
#     'job_highlights': [{'items': ['MOSE Data Strategy, Governance and Management Manager (location: EU)\nTake your next career step at ABB with a global team that is energizing the transformation of society and industry to achieve a more productive, sustainable future.\n\nAt ABB, we have the clear goal of driving diversity and inclusion across all dimensions: gender, LGBTQ+, abilities, ethnicity and generations. Together, we are embarking on a journey where each and every one of us, individually and collectively, welcomes and celebrates individual differences.\n\nThe MOSE Data Strategy connects the dots between products, technology, processes, services, and people across the MOSE division to enable and support our business objectives and create new opportunities for growth.\n\nIn this role, you will be accountable for developing and implementing the MOSE Installed Base Data Strategy and Data Architecture that enable and support the MOSE business strategy and objectives.\n\nYou will also be accountable for leading the design... implementation, and support of end-to-end Data Processes and Governance framework that will be enabled by the Data Management backend platform. The platform will serve as a common data repository and provide data services to all applications across the MOSE division as well as other MO divisions as required.\n\nAdditionally, you will be accountable for planning and leading the execution of required data programs across the MOSE division, ensuring their alignment with other MO BA and divisional programs and adherence to the enterprise and data architecture standards and guidelines, and ensuring the end-to-end data security, integrity, compliance, and quality in delivered solutions and services.\n\nThis role is open globally, but its location is set in ABB Offices in Krakow (Poland), Helsinki (Finland), or Baden (Switzerland).\nThis is a position with global grade\n\n10\nThis position reports to\n\nMOSE CIO\nYour responsibilities\n• Accountable for the MOSE Division Data Strategy, end-to-end Data Process design, Data Governance framework, and Data Architecture. Own the implementation roadmap and deliverables.\n• Foster and drive collaboration across MO/MOSE business and key IS stakeholders to a common, consistent, and holistic approach in designing end-to-end processes and data flows and their usage across the IS ecosystem.\n• Responsible for the data architecture in all business/IS and Data & Analytics solutions used by the MOSE business service lines and functions.\n• Deeply understand business strategy, objectives, and insights to design and implement optimal data processes, governance, and management frameworks and flows across different service lines/functions and use cases across MO divisions and in MOSE.\n• Drive and secure alignment on Data Processes, Governance, and Management across business stakeholders and MO/MOSE IS programs.\n• Lead business requirements discussions across MOSE business domains for functional Data & Analytics processes, governance, and management in all MOSE solutions, providing technical expertise and ensuring a holistic approach for data-related domains.\n• Get engaged in and lead data requirement analysis and data engineering in all MOSE programs to ensure proper reusability and leverage of the existing portfolio before building new solutions. Drive validation and prioritization of business demand related to the data domain in collaboration with business process and data owners and IS stakeholders across MOSE organizations.\n• Organize and manage the support and timely resolution of data-related issues in processes, governance, or management areas during project delivery to avoid delays or any other negative impact on the project or service. Collaborate with business and project teams to develop and deploy the best feasible and cost-efficient data solutions and services for the business.\n• Drive standardization of data and analytics tools across service lines/functions an ...
#     'related_links': [{'link': 'https://www.google.com/search?sca_esv=600122311&hl=en&q=ABB&sa=X&ved=0ahUKEwiwybLo9eyDAxX1D1kFHdOJAZIQmJACCKQL',
#       'text': 'See web results for ABB'}],
#     'extensions': ['2 days ago', 'Full-time'],
#     'detected_extensions': {'posted_at': '2 days ago',
#      'schedule_type': 'Full-time'},
#     'job_id': '...'},
#    {'title': 'Senior Specialist "Informal economy data and diagnostics"',
#     'company_name': 'International Labour Organization',
#     'location': '  Geneva, Switzerland   ',
#     'via': 'via ILO Jobs',
#     'description': "Grade: P5\n\nVacancy no.: DC/AP-FORMALIZATION/P/2024/02\n\nPublication date: 17 January 2024\n\nApplication deadline (midnight Geneva time): 31 January 2024\n\nJob ID: 11558\n\nDepartment: DDG\n\nOrganization Unit: AP/FORMALIZATION\n\nLocation: Geneva\n\nContract type: Fixed Term\n\nContract duration: 12 Months\n\nUnder article 4.2, paragraph (e) of the Staff Regulations, the filling of vacancies in technical cooperation projects does not fall under Annex I of the Staff Regulations and is made by direct selection by the Director-General.\n\nIn order to support the best informed process in the filling of the present vacancy by direct selection, the ILO invites interested candidates to submit their candidature online by the above date.\n\nTechnical cooperation appointments are not expected to lead to a career in the ILO and they do not carry any expectation of renewal or conversion to any other type of appointment in the Organization. A one-year fixed-term contract will be given. Extensions of technical... cooperation contracts are subject to various elements including the following: availability of funds, continuing need of the functions and satisfactory conduct and performance.\n\nThe following are eligible to apply:\n• ILO Internal candidates in accordance with paragraphs 31 and 32 of Annex I of the Staff Regulations.\n• External candidates.\n\nThe ILO values diversity among its staff and welcomes applications from qualified female candidates. We also encourage applicants with disabilities. If you are unable to complete our online application form due to a disability, please send an email to ilojobs@ilo.org.\n\nIntroduction\n\nThe position is located in the Priority Action Programme “Transition from the informal to the formal economy” (AP/Formalization) under the DDG portfolio. IGDS no.660 provides details about the objectives and operational modalities of the four Priority Action Programmes (APs) introduced through the Programme and Budget for 2024–25. The APs focus on the effective coordination and integration of policies and activities across the different areas of the ILO’s work and the provision of integrated support to constituents.\n\nThey are expected to function as entry points for leveraging partnerships and cooperation in support of the Global Coalition for Social Justice. The four APs have been designed to foster integrated cross-Office action and collaborative working modalities across departments at headquarters and in field offices, addressing decent work deficits affecting specific, well-defined populations and ensuring integrated policy responses aimed to result in measurable outcomes. In this way, the APs will enable the consolidation and expansion of in-house expertise and knowledge on key policy areas of the world of work; this will translate into increased impact at country level and the stronger positioning of the ILO globally. The APs will be implemented in close cooperation with ILO tripartite constituents and involve relevant entities of the multilateral system, as well as development partners and civil society organizations concerned with the specific theme each AP is targeting.\n\nThe APs aim to consolidate relevant facets of the specific AP themes that are addressed by different organizational units, adding value to and enabling this work by: (a) facilitating knowledge exchange; (b) developing and sharing new tools and methodologies; (c) strengthening advocacy and communication; (d) improving coordination of capacity development initiatives, including with the ITC–ILO; and (e) engaging with multilateral organizations and building consensus and coordinated action that ensures the bulk of the risk is not placed on the most vulnerable workers least able to bear it. Such actions should ensure that APs’ impact on knowledge, policy advice and capacity-building is significant, measurable and visible.\n\nWithin the policy and procedural requirements established by the ILO and the AP/For ...
#     'job_highlights': [{'items': ["Grade: P5\n\nVacancy no.: DC/AP-FORMALIZATION/P/2024/02\n\nPublication date: 17 January 2024\n\nApplication deadline (midnight Geneva time): 31 January 2024\n\nJob ID: 11558\n\nDepartment: DDG\n\nOrganization Unit: AP/FORMALIZATION\n\nLocation: Geneva\n\nContract type: Fixed Term\n\nContract duration: 12 Months\n\nUnder article 4.2, paragraph (e) of the Staff Regulations, the filling of vacancies in technical cooperation projects does not fall under Annex I of the Staff Regulations and is made by direct selection by the Director-General.\n\nIn order to support the best informed process in the filling of the present vacancy by direct selection, the ILO invites interested candidates to submit their candidature online by the above date.\n\nTechnical cooperation appointments are not expected to lead to a career in the ILO and they do not carry any expectation of renewal or conversion to any other type of appointment in the Organization. A one-year fixed-term contract will be given. Extensions of technical... cooperation contracts are subject to various elements including the following: availability of funds, continuing need of the functions and satisfactory conduct and performance.\n\nThe following are eligible to apply:\n• ILO Internal candidates in accordance with paragraphs 31 and 32 of Annex I of the Staff Regulations.\n• External candidates.\n\nThe ILO values diversity among its staff and welcomes applications from qualified female candidates. We also encourage applicants with disabilities. If you are unable to complete our online application form due to a disability, please send an email to ilojobs@ilo.org.\n\nIntroduction\n\nThe position is located in the Priority Action Programme “Transition from the informal to the formal economy” (AP/Formalization) under the DDG portfolio. IGDS no.660 provides details about the objectives and operational modalities of the four Priority Action Programmes (APs) introduced through the Programme and Budget for 2024–25. The APs focus on the effective coordination and integration of policies and activities across the different areas of the ILO’s work and the provision of integrated support to constituents.\n\nThey are expected to function as entry points for leveraging partnerships and cooperation in support of the Global Coalition for Social Justice. The four APs have been designed to foster integrated cross-Office action and collaborative working modalities across departments at headquarters and in field offices, addressing decent work deficits affecting specific, well-defined populations and ensuring integrated policy responses aimed to result in measurable outcomes. In this way, the APs will enable the consolidation and expansion of in-house expertise and knowledge on key policy areas of the world of work; this will translate into increased impact at country level and the stronger positioning of the ILO globally. The APs will be implemented in close cooperation with ILO tripartite constituents and involve relevant entities of the multilateral system, as well as development partners and civil society organizations concerned with the specific theme each AP is targeting.\n\nThe APs aim to consolidate relevant facets of the specific AP themes that are addressed by different organizational units, adding value to and enabling this work by: (a) facilitating knowledge exchange; (b) developing and sharing new tools and methodologies; (c) strengthening advocacy and communication; (d) improving coordination of capacity development initiatives, including with the ITC–ILO; and (e) engaging with multilateral organizations and building consensus and coordinated action that ensures the bulk of the risk is not placed on the most vulnerable workers least able to bear it. Such actions should ensure that APs’ impact on knowledge, policy advice and capacity-building is significant, measurable and visible.\n\nWithin the policy and procedural requirements established by the ILO ...
#     'related_links': [{'link': 'http://www.ilo.org/', 'text': 'ilo.org'},
#      {'link': 'https://www.google.com/search?sca_esv=600122311&hl=en&q=International+Labour+Organization&sa=X&ved=0ahUKEwiwybLo9eyDAxX1D1kFHdOJAZIQmJACCOIL',
#       'text': 'See web results for International Labour Organization'}],
#     'thumbnail': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSIZGwJ7n_VeGKogXRIQoqaK4PKGJ8f682ay3sF&s=0',
#     'extensions': ['5 days ago', 'Temp work'],
#     'detected_extensions': {'posted_at': '5 days ago',
#      'schedule_type': 'Temp work'},
#     'job_id': '...'},
#    {'title': 'Manufacturing Master Data Specialist',
#     'company_name': 'Bristol-Myers Squibb  Co',
#     'location': '  Boudry, Switzerland   ',
#     'via': 'via Bristol Myers Squibb',
#     'description': "Chez Bristol Myers Squibb, nous sommes inspirés par une vision unique : transformer la vie des patients grâce à la science. Dans les domaines de l'oncologie, de l'hématologie, de l'immunologie et des maladies cardiovasculaires – avec l'un des pipelines les plus diversifiés et les plus prometteurs de l'industrie - chacun de nos collègues est passionné et contribue à des innovations qui entraînent des changements significatifs. Nous apportons une touche humaine à chaque traitement dont nous sommes les pionniers. Rejoignez-nous et faites une difference!\n\nIn this position the OSD Manufacturing Master Data – Specialist will execute tasks related to Manufacturing and Quality Control master data in the Manufacturing ERP System (SAP) following the GXP guidelines.\n\nThis includes and is not limited to: data entry, data analysis, workflow follow-up, functional testing of ERP system, manufacturing ERP data technical development, master data SME, and coordinate or lead on manufacturing ERP data... project.\n\nThis position will work in close collaboration with Boudry Manufacturing departments, Global Master Data, Quality Assurance and other internal stakeholders.\n\nDuties/Responsibilities\n\nThe OSD Manufacturing Master Data – Specialist:\n• Is able to timely execute the assigned tasks and assess the impact of these changes upon other Manufacturing ERP Data within the ERP system. He/She understands the full scope and is consulted during the reflection on timelines and impacts.\n• Prepares and follows data templates and workflows in order to meet the requested timelines and makes the data entry in the ERP system.\n• Is CAPA action owner and change control action owner and must ensure that the proper actions are done in due time and according to the GxP guidelines and liaise with more global project timelines.\n• Collects user’s requests and proactively proposes solutions for improvement to the impacted departments and involve the relevant person upon need. He/She will creatively think of solution that could be process oriented.\n• Coordinates the stakeholder session of routing improvement.\n• Analyse the impact of improvement request and will advise the stakeholder of the impact and will take the relevant action in order to stay aligned across routings with timelines\n• Ensures proper IT development; implements and executes the needed data tests/loads within the ERP system.\n• Has the expertise to conceptualize, create and update packaging routings and to update existing bulk routings.\n• Provides necessary training on routings and other master data for any employee, function or department requiring such training.\n• Plays an active role during UAT sessions for ERP improvement or org developments. He/she can be consulted during UAT script creation, execution of tests related to master data, production, QC, QA, Scheduling and Warehouse functions/modules, and can also participate as coordinator for these sessions.\n• Is expert in using the different tool related to data entry, such as data loader and/or conversion tool.\n• Participates to data collection for KPI analyses and KPI set-ups.\n• Participates in project related to MDM activities as subject master expert and can lead or co-lead such projects.\n• Act as the back-up of his/her peers and managers mainly regarding coordination activities.\n\nQualifications\n• Commercial diploma, (CFC ) or equivalent\n• at least 2 year's of experience in Manufacturing Master Data management ( Materiel Master, BOM, and Receipe) ( mandatory)\n• Conscientious, reliable in action follow-up and priority management\n• Strong team-player\n• Fluency both in French and English is required\n• Good insight in processes and dependencies\n• Concentrated conscious, aiming for “right first time”\n• Aiming for the full picture and the full understanding of the of other’s implication\n• Interested and skills in relationship and cross-department interactions.\n• Strictly follow established process ...
#     'job_highlights': [{'items': ["Chez Bristol Myers Squibb, nous sommes inspirés par une vision unique : transformer la vie des patients grâce à la science. Dans les domaines de l'oncologie, de l'hématologie, de l'immunologie et des maladies cardiovasculaires – avec l'un des pipelines les plus diversifiés et les plus prometteurs de l'industrie - chacun de nos collègues est passionné et contribue à des innovations qui entraînent des changements significatifs. Nous apportons une touche humaine à chaque traitement dont nous sommes les pionniers. Rejoignez-nous et faites une difference!\n\nIn this position the OSD Manufacturing Master Data – Specialist will execute tasks related to Manufacturing and Quality Control master data in the Manufacturing ERP System (SAP) following the GXP guidelines.\n\nThis includes and is not limited to: data entry, data analysis, workflow follow-up, functional testing of ERP system, manufacturing ERP data technical development, master data SME, and coordinate or lead on manufacturing ERP data... project.\n\nThis position will work in close collaboration with Boudry Manufacturing departments, Global Master Data, Quality Assurance and other internal stakeholders.\n\nDuties/Responsibilities\n\nThe OSD Manufacturing Master Data – Specialist:\n• Is able to timely execute the assigned tasks and assess the impact of these changes upon other Manufacturing ERP Data within the ERP system. He/She understands the full scope and is consulted during the reflection on timelines and impacts.\n• Prepares and follows data templates and workflows in order to meet the requested timelines and makes the data entry in the ERP system.\n• Is CAPA action owner and change control action owner and must ensure that the proper actions are done in due time and according to the GxP guidelines and liaise with more global project timelines.\n• Collects user’s requests and proactively proposes solutions for improvement to the impacted departments and involve the relevant person upon need. He/She will creatively think of solution that could be process oriented.\n• Coordinates the stakeholder session of routing improvement.\n• Analyse the impact of improvement request and will advise the stakeholder of the impact and will take the relevant action in order to stay aligned across routings with timelines\n• Ensures proper IT development; implements and executes the needed data tests/loads within the ERP system.\n• Has the expertise to conceptualize, create and update packaging routings and to update existing bulk routings.\n• Provides necessary training on routings and other master data for any employee, function or department requiring such training.\n• Plays an active role during UAT sessions for ERP improvement or org developments. He/she can be consulted during UAT script creation, execution of tests related to master data, production, QC, QA, Scheduling and Warehouse functions/modules, and can also participate as coordinator for these sessions.\n• Is expert in using the different tool related to data entry, such as data loader and/or conversion tool.\n• Participates to data collection for KPI analyses and KPI set-ups.\n• Participates in project related to MDM activities as subject master expert and can lead or co-lead such projects.\n• Act as the back-up of his/her peers and managers mainly regarding coordination activities.\n\nQualifications\n• Commercial diploma, (CFC ) or equivalent\n• at least 2 year's of experience in Manufacturing Master Data management ( Materiel Master, BOM, and Receipe) ( mandatory)\n• Conscientious, reliable in action follow-up and priority management\n• Strong team-player\n• Fluency both in French and English is required\n• Good insight in processes and dependencies\n• Concentrated conscious, aiming for “right first time”\n• Aiming for the full picture and the full understanding of the of other’s implication\n• Interested and skills in relationship and cross-department interactions.\n• Strictly follow esta ...
#     'related_links': [{'link': 'http://www.bms.com/', 'text': 'bms.com'},
#      {'link': 'https://www.google.com/search?sca_esv=600122311&hl=en&q=Bristol-Myers+Squibb++Co&sa=X&ved=0ahUKEwiwybLo9eyDAxX1D1kFHdOJAZIQmJACCKAM',
#       'text': 'See web results for Bristol-Myers Squibb Co'}],
#     'thumbnail': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQZSiBbrph3asWTMuM4CZcMDRhv-f8ipSGaEoxZ&s=0',
#     'extensions': ['5 days ago', 'Full-time'],
#     'detected_extensions': {'posted_at': '5 days ago',
#      'schedule_type': 'Full-time'},
#     'job_id': '...'},
#    {'title': 'Computer Vision Data Scientist',
#     'company_name': 'Apple',
#     'location': '  Zürich, Switzerland   ',
#     'via': 'via Careers At Apple',
#     'description': 'Summary\nPosted: Dec 12, 2023\n\nRole Number:200528012\n\nDo you have a passion for computer vision and deep learning problems? We are looking for someone who thrives on collaboration and wants to push the boundaries of what is possible today! The Video Computer Vision org is a centralized applied research and engineering organization responsible for developing real-time on-device Computer Vision and Machine Perception technologies across Apple products. Our data scientist will work closely with other members of the Video Computer Vision org to implement model evaluation pipeline, analyze large scale data to help influence product decision and improve product quality. This position will require strong analytical and coding skills, presentation skills, and collaborating with multiple teams. You will get to work on computer vision products like FaceID and exciting future technologies.\n\nKey Qualifications\n\nKey Qualifications\n• 2+ industry experience in data science domain\n• Extensive... knowledge of statistical data analysis and machine learning techniques.\n• Solid programming skills with Python for data processing and development.\n• Experience developing data science pipelines, tool-chains, and workflows.\n• Have a big enough toolbox to know how to find patterns in large and messy data, identify targets for performance, and identify sources of variance about those targets.\n• Experienced with data visualization (e.g. matplotlib/ggplot/tableau).\n• Have excellent verbal and written communication skills and experience in influencing decisions with information.\n• You are self-motivated and curious with demonstrated creative and critical thinking capabilities and an innate drive to improve how things work.\n• You have a high tolerance for ambiguity in a fast paced environment. You find a way through. You anticipate. You connect and synthesize!\n\nDescription\n\nDescription\nWe work on complex problems in computer vision that require robust, efficient, well tested, and clean solutions. The ideal candidate will possess the self-motivation, curiosity, and initiative to achieve those goals. You will work together with similar minds in a unique team where your skills and expertise can be used to influence future user experiences and products that will be used by millions.\n\nEducation & Experience\n\nEducation & Experience\nPhD or MS in Data Science, Statistics, Bioinformatics, Operations Research, Computer Science, or similar quantitative domain.\n\nAdditional Requirements\n\nAdditional Requirements\n• Apple is an equal-opportunity employer that is committed to inclusion and diversity. We also take affirmative action to offer employment and advancement opportunities to all applicants, including minorities, women, protected veterans, and individuals with disabilities. Apple will not discriminate or retaliate against applicants who inquire about, disclose, or discuss their compensation or that of other applicants. We will ensure that individuals with disabilities are provided reasonable accommodation to participate in the job application or interview process, perform crucial job functions, and receive other benefits and privileges of employment. Please contact us to request an accommodation',
#     'job_highlights': [{'items': ['Summary\nPosted: Dec 12, 2023\n\nRole Number:200528012\n\nDo you have a passion for computer vision and deep learning problems? We are looking for someone who thrives on collaboration and wants to push the boundaries of what is possible today! The Video Computer Vision org is a centralized applied research and engineering organization responsible for developing real-time on-device Computer Vision and Machine Perception technologies across Apple products. Our data scientist will work closely with other members of the Video Computer Vision org to implement model evaluation pipeline, analyze large scale data to help influence product decision and improve product quality. This position will require strong analytical and coding skills, presentation skills, and collaborating with multiple teams. You will get to work on computer vision products like FaceID and exciting future technologies.\n\nKey Qualifications\n\nKey Qualifications\n• 2+ industry experience in data science domain\n• Extensive... knowledge of statistical data analysis and machine learning techniques.\n• Solid programming skills with Python for data processing and development.\n• Experience developing data science pipelines, tool-chains, and workflows.\n• Have a big enough toolbox to know how to find patterns in large and messy data, identify targets for performance, and identify sources of variance about those targets.\n• Experienced with data visualization (e.g. matplotlib/ggplot/tableau).\n• Have excellent verbal and written communication skills and experience in influencing decisions with information.\n• You are self-motivated and curious with demonstrated creative and critical thinking capabilities and an innate drive to improve how things work.\n• You have a high tolerance for ambiguity in a fast paced environment. You find a way through. You anticipate. You connect and synthesize!\n\nDescription\n\nDescription\nWe work on complex problems in computer vision that require robust, efficient, well tested, and clean solutions. The ideal candidate will possess the self-motivation, curiosity, and initiative to achieve those goals. You will work together with similar minds in a unique team where your skills and expertise can be used to influence future user experiences and products that will be used by millions.\n\nEducation & Experience\n\nEducation & Experience\nPhD or MS in Data Science, Statistics, Bioinformatics, Operations Research, Computer Science, or similar quantitative domain.\n\nAdditional Requirements\n\nAdditional Requirements\n• Apple is an equal-opportunity employer that is committed to inclusion and diversity. We also take affirmative action to offer employment and advancement opportunities to all applicants, including minorities, women, protected veterans, and individuals with disabilities. Apple will not discriminate or retaliate against applicants who inquire about, disclose, or discuss their compensation or that of other applicants. We will ensure that individuals with disabilities are provided reasonable accommodation to participate in the job application or interview process, perform crucial job functions, and receive other benefits and privileges of employment. Please contact us to request an accommodation']}],
#     'related_links': [{'link': 'http://www.apple.com/', 'text': 'apple.com'},
#      {'link': 'https://www.google.com/search?sca_esv=600122311&hl=en&q=Apple&sa=X&ved=0ahUKEwiwybLo9eyDAxX1D1kFHdOJAZIQmJACCN0M',
#       'text': 'See web results for Apple'}],
#     'thumbnail': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRrGv1mwjAAcRpCBNFJqhHUrLDBCojde7VFUsuc87k&s',
#     'extensions': ['Full-time'],
#     'detected_extensions': {'schedule_type': 'Full-time'},
#     'job_id': '...'},
#    {'title': 'Director, Product management Data Platform',
#     'company_name': 'Quartz Bio',
#     'location': '  Geneva, Switzerland   ',
#     'via': 'via Greenhouse',
#     'description': "QuartzBio (www.quartz.bio ) is a Software-as-a-Service (SaaS) solutions provider to the life sciences industry. We deliver innovative, data enabling technologies (i.e., software) that provide biotech/pharma (R&D) teams with enterprise-level access to sample/biomarker data management solutions & analytics, information, insight & reporting capabilities.\n\nOur end-to-end (from sample collection to biomarker data) suite of solutions are focused on providing sponsors information (data with context) – we do this by connecting biospecimen, assay as well as clinical data sources in a secure and scalable cloud-based infrastructure, enabling seamless, automated data management workflows, key insight development, improved collaboration, and the ability to make faster, more informed decisions.\n\nPosition Summary:\n\nAs we continue to expand our product management team, we are seeking a highly skilled Director, Product Design to lead product design activities for both the data management and analytics... component of the platform. This leadership role is responsible for setting up the core design infrastructure such as the design system, setting up of design ecosystem, lead user research and create UX concept. Responsibilities include building out the product design team to enable creation of product design deliverables for every release.\n\nKey Responsibilities:\n• Product Roadmaps:\n• Collaborate with product management team to create product design roadmaps that is consistent with the product roadmap\n• Create product design infrastructure such as the product design system\n• Perform user research to create user experience concepts for both data platform and analytics\n• Synthesizes requirements across the team to create an overall design strategy.\n• Develop and conceptualize a comprehensive UI / UX design strategy for software and technology products and solutions across assets and applications.\n• Product Feature Requirements:\n• Collaborate with product requirements team to enable creation of low fidelity wireframes (in consistent with journey maps and design principles)\n• Lead UX design for both the data platform and analytics products\n• Develop UI mockups and prototypes that clearly illustrate how applications may function and be consumed.\n• Conduct user research, user testing, and analyze user feedback to identify user needs and pain points to guide design decisions.\n• Produce high-quality UX design solutions through wireframes, visual and graphic designs, flow diagrams, storyboards, site maps, and prototypes.\n• Build the UI team\n• Product Releases:\n• Collaborate to attend Product grooming sessions with product development functional groups (Engg, Data sciences, QA)\n• Perform and lead product design activities to deliver journey maps and product design deliverables (User journey maps, Low & high-fidelity wireframes) for the scoped items in the release.\n• Enable UI design consistency with UX, for individual product(s) and also across the integrated platform\n• Enable creation of product design deliverables of high quality and on schedule during product release activities\n• Lead the design of UI elements and tools such as navigation menus, search boxes, tabs, and widgets for our software and digital assets, ensuring all elements designed by the team present a common and cohesive look and feel.\n• Lead the design of graphic user interface elements, like menus, tabs and widgets, ensuring all elements designed by the team present a common and cohesive look and feel.\n• Post release:\n• Lead collaboration efforts with product support team for measuring product adoption and user experience\n• Lead steps to get product & platform speed back for UX/UI design & implementation.\n• Conduct Periodic stakeholder meetings to provide update on product design.\n• Team Leadership\n• Build and lead a high-performing team of product design analysts, fostering a culture of continuous learning and improvement.\n• Set cl ...
# ...
#     'related_links': [{'link': 'http://www.roche.com/', 'text': 'roche.com'},
#      {'link': 'https://www.google.com/search?sca_esv=600122311&hl=en&q=1201+F.+Hoffmann-La+Roche+AG&sa=X&ved=0ahUKEwjm4-749eyDAxV2iq8BHa83AP44hAIQmJACCMkM',
#       'text': 'See web results for 1201 F. Hoffmann-La Roche AG'}],
#     'thumbnail': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRAaksaUfLEOk1fIQPvb_ruWUxfWDbRhyIRQ8EH&s=0',
#     'extensions': ['Work from home', 'Full-time'],
#     'detected_extensions': {'schedule_type': 'Full-time',
#      'work_from_home': True},
#     'job_id': '...'}],
#   'chips': [{'type': 'Title',
#     'param': 'job_family_1',
#     'options': [{'text': 'All'},
#      {'text': 'Data engineer', 'value': 'data engineer'},
#      {'text': 'Data scientist', 'value': 'data scientist'},
#      {'text': 'Data analyst', 'value': 'data analyst'},
#      {'text': 'Manager', 'value': 'manager'},
#      {'text': 'Data manager', 'value': 'data manager'},
#      {'text': 'Data architect', 'value': 'data architect'},
#      {'text': 'Cloud architect', 'value': 'cloud architect'},
#      {'text': 'Consultant', 'value': 'consultant'},
#      {'text': 'Data specialist', 'value': 'data specialist'},
#      {'text': 'Analyst', 'value': 'analyst'},
#      {'text': 'Data management', 'value': 'data management'},
#      {'text': 'Software engineer', 'value': 'software engineer'},
#      {'text': 'Director', 'value': 'director'},
#      {'text': 'Engineer', 'value': 'engineer'},
#      {'text': 'Platform engineer', 'value': 'platform engineer'},
#      {'text': 'Product owner', 'value': 'product owner'},
#      {'text': 'Specialist', 'value': 'specialist'},
#      {'text': 'Trainee', 'value': 'trainee'},
#      {'text': 'Architect', 'value': 'architect'},
#      {'text': 'Communication specialist', 'value': 'communication specialist'},
#      {'text': 'Leader', 'value': 'leader'},
#      {'text': 'Project coordinator', 'value': 'project coordinator'},
#      {'text': 'Project manager', 'value': 'project manager'},
#      {'text': 'Quality analyst', 'value': 'quality analyst'},
#      {'text': 'Senior', 'value': 'senior'},
#      {'text': 'Senior specialist', 'value': 'senior specialist'},
#      {'text': 'Steward', 'value': 'steward'},
#      {'text': 'Account manager', 'value': 'account manager'},
#      {'text': 'Analytics consultant', 'value': 'analytics consultant'},
#      {'text': 'Analytics specialist', 'value': 'analytics specialist'},
#      {'text': 'Application analyst', 'value': 'application analyst'},
#      {'text': 'Associate', 'value': 'associate'},
#      {'text': 'Associate director', 'value': 'associate director'},
#      {'text': 'Clients', 'value': 'clients'},
#      {'text': 'Data consultant', 'value': 'data consultant'},
#      {'text': 'Data coordinator', 'value': 'data coordinator'},
#      {'text': 'Data science', 'value': 'data science'},
#      {'text': 'Design manager', 'value': 'design manager'},
#      {'text': 'Electrical engineer', 'value': 'electrical engineer'},
#      {'text': 'Engineering manager', 'value': 'engineering manager'},
#      {'text': 'Evaluator', 'value': 'evaluator'},
#      {'text': 'Expertise', 'value': 'expertise'},
#      {'text': 'Facilities engineer', 'value': 'facilities engineer'},
#      {'text': 'Functional consultant', 'value': 'functional consultant'},
#      {'text': 'Legal counsel', 'value': 'legal counsel'},
#      {'text': 'Logistics', 'value': 'logistics'},
#      {'text': 'Management assistant', 'value': 'management assistant'},
#      {'text': 'Management manager', 'value': 'management manager'},
#      {'text': 'Modeller', 'value': 'modeller'},
#      {'text': 'Phd student', 'value': 'phd student'},
#      {'text': 'Postdoctoral researcher', 'value': 'postdoctoral researcher'},
#      {'text': 'Product manager', 'value': 'product manager'}]},
#    {'type': 'Location',
#     'param': 'city',
#     'options': [{'text': 'All'},
#      {'text': 'Zürich', 'value': 'GaK-SZcLkEcD3B_n8Y1u5g=='},
#      {'text': 'Geneva', 'value': '6-LQkwZljEc5vAt7NZW2oA=='},
#      {'text': 'Basel', 'value': 'TzBpJ8dJkEeQim3zcOscNg=='},
#      {'text': 'Lausanne', 'value': '5aeJzT4pjEde7uLKyT8X6w=='},
#      {'text': 'Bern', 'value': 'dxs61MA5jkeaZVcE_l9Vyw=='},
#      {'text': 'Chiasso', 'value': 'RT7X08qChkfmgs1S0vaYBw=='},
#      {'text': 'Stabio', 'value': 'wZ-5UhyChkdxS_tG6cxV5Q=='},
#      {'text': 'Meyrin', 'value': 'qyoJ0nZjjEfl2q29rO0J3Q=='},
#      {'text': 'Montanaire', 'value': '_bTfrYLTjUfCSmUwdyKwOQ=='},
#      {'text': 'Villars-sur-Glâne', 'value': 'z855fjJkjkdLaDTM1NEK6A=='},
#      {'text': 'Zug', 'value': '8-RGYCmrmkcQ6uPHA79QqQ=='},
#      {'text': 'Baden', 'value': '7Y326MZskEdAV2IljzsjKw=='},
#      {'text': 'Boudry', 'value': '8_k_HbTgjUdZdyBxPo39sg=='},
#      {'text': 'Buchs', 'value': 'L20Fgikum0e_Y3bsakQYiQ=='},
#      {'text': 'Kaiseraugst', 'value': 'vdzXMLa1kUe7NBNziM3nbg=='},
#      {'text': 'Lachen', 'value': '1xzoXxK2mkdVl6eWLg-8pg=='},
#      {'text': 'Lancy', 'value': 'h4s-Tzl7jEc42JpBB3txLg=='},
#      {'text': 'Neuchâtel', 'value': 'm81S1RkKjkcEZLZVaMNcIw=='},
#      {'text': 'Vevey', 'value': 'p34g0TKDjkd_7JcyuUTojw=='},
#      {'text': 'Adliswil', 'value': 'RcIZASAIkEegvznAaOyv_w=='},
#      {'text': 'Allschwil', 'value': 'j_CRCc64kUf8B-VcVbwC4w=='},
#      {'text': 'Aubonne', 'value': 'dTTIVdVHjEfgQRlAiP8ABA=='},
#      {'text': 'Baar', 'value': 'D5CdDsurmkda-qYhO_8bUQ=='},
#      {'text': 'Biel/Bienne', 'value': 'z-y6XNAejkcecEHQQ5fcUA=='},
#      {'text': 'Cham', 'value': 'WdZa4NsAkEekepJ4yXLN0Q=='},
#      {'text': 'Corsier-sur-Vevey', 'value': 'Y2GzdHKDjkctO6PhTIxWSg=='},
#      {'text': 'Einsiedeln', 'value': 'n5-RB0Ozmkf7OZnl7T5VsQ=='},
#      {'text': 'Eysins', 'value': 'wXsA2CVdjEem_FhYDUXP_Q=='},
#      {'text': 'Freienbach', 'value': 'mddScVqxmkdgatgcD77zmg=='},
#      {'text': 'Fully', 'value': 'aXGBLbbHjke3FPT50bND4w=='},
#      {'text': 'Kloten', 'value': 'H9Z_uO-fmkdYmFmAZedODg=='},
#      {'text': 'Lenzburg', 'value': 'G--Udg0WkEdIwiH2N_2Tcg=='},
#      {'text': 'Mendrisio', 'value': '0dlZL68phEcjWEUvLXrKGw=='},
#      {'text': 'Morges', 'value': 'TT2OphY3jEcnY5YdzhirEA=='},
#      {'text': 'Nyon', 'value': 'Zwgvdy9DjEdHr0ESGtS3bw=='},
#      {'text': 'Oberengstringen', 'value': '7bb4gngLkEew0xhAiP8ABA=='},
#      {'text': 'Orbe', 'value': 'cf1nP2fJjUeTgG4eQnFDGQ=='},
#      {'text': 'Rafz', 'value': 'sbPHXtx5kEeVjX9BTQPcyA=='},
#      {'text': 'Rümlang', 'value': 'AQm-SjF1kEcn4EfM87kjjQ=='},
#      {'text': 'Schlieren', 'value': 'FaLQ-AoMkEcIleVQ3YD54w=='},
#      {'text': 'Solothurn', 'value': 'R3O5lfDXkUepE41U5g6plg=='},
#      {'text': 'St. Gallen', 'value': 'Vdgzdikem0cUYf4fCFAimg=='},
#      {'text': 'Turgi', 'value': 'FfDiCBNrkEcdi-HtcHzJDA=='},
#      {'text': 'Vernier', 'value': '6YIYrENjjEeMav1pH3sZgQ=='},
#      {'text': 'Visp', 'value': 'eSGraQVrj0foFWBR-tgxhQ=='},
#      {'text': 'Winterthur', 'value': 'verASaAMkEfsHQRBnwSY8A=='}]},
#    {'type': 'Date posted',
#     'param': 'date_posted',
#     'options': [{'text': 'All'},
#      {'text': 'Past day', 'value': 'today'},
#      {'text': 'Past 3 days', 'value': '3days'},
#      {'text': 'Past week', 'value': 'week'},
#      {'text': 'Past month', 'value': 'month'}]},
#    {'type': 'Requirements',
#     'param': 'requirements',
#     'options': [{'text': 'All'},
#      {'text': 'No degree', 'value': 'no_degree'},
#      {'text': 'No experience', 'value': 'no_experience'},
#      {'text': 'Under 3 years of experience', 'value': 'years3under'},
#      {'text': '3+ years of experience', 'value': 'years3plus'}]},
#    {'type': 'Language',
#     'param': 'language',
#     'options': [{'text': 'All'},
#      {'text': 'English Results', 'value': 'en'},
#      {'text': 'German Results', 'value': 'de'},
#      {'text': 'French Results', 'value': 'fr'}]},
#    {'type': 'Type',
#     'param': 'employment_type',
#     'options': [{'text': 'All'},
#      {'text': 'Full-time', 'value': 'FULLTIME'},
#      {'text': 'Part-time', 'value': 'PARTTIME'},
#      {'text': 'Internship', 'value': 'INTERN'},
#      {'text': 'Contractor', 'value': 'CONTRACTOR'}]},
#    {'type': 'Company type',
#     'param': 'industry.id',
#     'options': [{'text': 'All'},
#      {'text': 'Manufacturing', 'value': '/business/naics2007/31'},
#      {'text': 'Consulting', 'value': '/business/naics2007/5416'},
#      {'text': 'Computer Services', 'value': '/business/naics2007/5415'},
#      {'text': 'Information', 'value': '/business/naics2007/51'},
#      {'text': 'Education', 'value': '/business/naics2007/61'},
#      {'text': 'Finance', 'value': '/business/naics2007/52'},
#      {'text': 'Retail', 'value': '/business/naics2007/44'},
#      {'text': 'Accounting', 'value': '/business/naics2007/5412'},
#      {'text': 'Logistics', 'value': '/business/naics2007/48'},
#      {'text': 'Engineering Services', 'value': '/business/naics2007/5413'},
#      {'text': 'Research', 'value': '/business/naics2007/5417'},
#      {'text': 'Travel', 'value': '/business/naics2007/5615'},
#      {'text': 'Management', 'value': '/business/naics2007/55'},
#      {'text': 'Toiletries', 'value': '/business/naics2007/3256'},
#      {'text': 'Professional, Scientific, and Technical Services',
#       'value': '/business/naics2007/54'},
#      {'text': 'Real Estate', 'value': '/business/naics2007/53'},
#      {'text': 'Staffing', 'value': '/business/naics2007/5613'},
#      {'text': 'Entertainment', 'value': '/business/naics2007/71'},
#      {'text': 'Foods & Beverages', 'value': '/business/naics2007/311'}]},
#    {'type': 'Employer',
#     'param': 'organization_mid',
#     'options': [{'text': 'All'},
#      {'text': 'Roche', 'value': '/m/02nyk6'},
#      {'text': 'EY', 'value': '/m/0g9jc'},
#      {'text': 'Richemont', 'value': '/m/03g266'},
#      {'text': 'Swiss International Air Lines AG', 'value': '/m/015mtr'},
#      {'text': 'ABB', 'value': '/m/01bs_z'},
#      {'text': 'Gartner Switzerland GmbH', 'value': '/m/09l_gtr'},
#      {'text': 'Nestle Operational Services Worldwide SA',
#       'value': '/g/11f00t1g4b'},
#      {'text': 'Universität Zürich', 'value': '/m/01tpvt'},
#      {'text': 'Lastminute.com', 'value': '/m/040dhz'},
#      {'text': 'Bristol Myers Squibb', 'value': '/m/02hh10'},
#      {'text': 'Merck KGaA, Darmstadt, Germany', 'value': '/m/02fwl6'},
#      {'text': 'NTT DATA Services', 'value': '/g/11bc6fn8n9'},
#      {'text': 'Philip Morris International', 'value': '/m/08f__w'},
#      {'text': 'Proclinical', 'value': '/g/11dxq24455'},
#      {'text': 'Royal HaskoningDHV', 'value': '/m/010r7ppq'},
#      {'text': 'Synechron', 'value': '/m/027hdqs'},
#      {'text': 'VF', 'value': '/m/07y_vs'},
#      {'text': 'Velocity Business Solutions', 'value': '/g/11rxw02h_d'},
#      {'text': 'AWK Group AG', 'value': '/g/11c73ptd2g'},
#      {'text': 'Academic Work', 'value': '/g/122_g301'},
#      {'text': 'Boston Consulting Group', 'value': '/m/03w00p'},
#      {'text': 'CBRE', 'value': '/m/090r7m'},
#      {'text': 'CERN', 'value': '/m/099rn'},
#      {'text': 'DSM', 'value': '/m/0446xk'},
#      {'text': 'Databricks', 'value': '/m/0120wgnc'},
#      {'text': 'Digitec Galaxus AG', 'value': '/m/013f7lyt'},
#      {'text': 'Equinix', 'value': '/m/07btnq'},
#      {'text': 'Hilti Corporation', 'value': '/g/1tnbk36c'},
#      {'text': "L'Oréal Suisse SA", 'value': '/g/11g9mwjqx4'},
#      {'text': 'Michael Page', 'value': '/m/04cxldw'},
#      {'text': 'Nexthink', 'value': '/g/11g9n3lbmv'},
#      {'text': 'Novartis Pharma AG', 'value': '/g/11fy1ttl51'},
#      {'text': 'Octapharma', 'value': '/m/09gdl4_'},
#      {'text': 'Publicis Sapient', 'value': '/m/02myjp'},
#      {'text': 'PwC', 'value': '/m/012_78'},
#      {'text': 'Unit8 SA', 'value': '/g/11sd0c76hz'},
#      {'text': '110 Lombard Odier Asset Management (Switzerland) SA',
#       'value': '/g/11gxsc6qph'},
#      {'text': '42matters', 'value': '/g/11g70cs724'},
#      {'text': 'AE Studio', 'value': '/g/11v42qxf7c'}]}]},
#  {'search_metadata': {'id': '65ac3c919f55b31d7ebbe263',
#    'status': 'Success',
#    'json_endpoint': 'https://serpapi.com/searches/d9302a721ad951c3/65ac3c919f55b31d7ebbe263.json',
#    'created_at': '2024-01-20 21:35:13 UTC',
#    'processed_at': '2024-01-20 21:35:13 UTC',
#    'google_jobs_url': 'https://www.google.com/search?q=Data&ibp=htl;jobs&uule=w+CAIQICILU3dpdHplcmxhbmQ&hl=en&start=280',
#    'raw_html_file': 'https://serpapi.com/searches/d9302a721ad951c3/65ac3c919f55b31d7ebbe263.html',
#    'total_time_taken': 2.16},
#   'search_parameters': {'q': 'Data',
#    'engine': 'google_jobs',
#    'location_requested': 'Switzerland',
#    'location_used': 'Switzerland',
#    'google_domain': 'google.com',
#    'hl': 'en',
#    'start': 280},
#   'search_information': {'jobs_results_state': 'Fully empty'},
#   'error': "Google hasn't returned any results for this query."}]

# %%
import requests

payload = { 'api_key': '02c61b750bca71883a0e8dbb30c630b0', 'url': 'https://serpapi.com/search.json' }
r = requests.get('https://api.scraperapi.com/', params=payload)
print(r.text)
# Out:
# Request failed. You will not be charged for this request. Please make sure your url is correct and try the request again. If this continues to happen, please contact support@scraperapi.com. The domain may be protected, please try adding the premium=true OR ultra_premium=true parameter to your request.

# %%
import re

def extract_job_info(jobs_results):
    """
    Extrait les informations d'une liste d'offres d'emploi à partir de données JSON.

    :param jobs_results: Liste de dictionnaires contenant les données des emplois.
    :return: Liste de dictionnaires avec les informations extraites pour chaque emploi.
    """
    extracted_jobs = []
    for job_data in jobs_results:
        job_info = {
            "title": job_data.get("title", "N/A"),
            "company_name": job_data.get("company_name", "N/A"),
            "location": job_data.get("location", "N/A").strip(),
            "experience": extract_experience(job_data.get("description", "")),
            "technical_skills": extract_technical_skills(job_data.get("description", ""))
        }
        extracted_jobs.append(job_info)
    return extracted_jobs

def extract_experience(description):
    """
    Extrait l'expérience requise à partir de la description de l'emploi.

    :param description: La description de l'emploi.
    :return: Expérience requise (sous forme de texte).
    """
    experience_patterns = [
        r'(\d+ ans d’expérience)',
        r'expérience de (\d+ ans)',
        r'expérience d’au moins (\d+ ans)'
    ]
    for pattern in experience_patterns:
        match = re.search(pattern, description)
        if match:
            return match.group(0)
    return "Non spécifié"

def extract_technical_skills(description):
    """
    Extrait les compétences techniques de la description de l'emploi.

    :param description: La description de l'emploi.
    :return: Liste des compétences techniques.
    """
    # Liste des compétences techniques courantes à rechercher
    skills = [
    "Python", "R", "SQL", "Excel", "Tableau", "PowerBI", "Dataiku", "Snowflake",
    "GCP", "AWS", "AZURE", "Databricks", "Talend", "Spark", "Scala", "Dataiku",
    "Airflow", "S3", "Kafka", "Hadoop", "SQL", "NoSQL", "Cassandra", "MongoDB",
    "ELK", "Git", "Kubernetes", "Docker", "OVH", "Kanban", "Jira", "Jenkins",
    "ElasticSearch", "Linus", "Kibana", "LogStash", "keras", "Tensorflow", "Gitlab",
    "Snowflake", "NLP", "Random Forest", "XGBoost", "SQL Server", "Oracle", "LLM",
    "IA generative", "generative AI", "GPT", "Terraform", "Yolo", "Pytorch",
    "Transformers", "scikit-learn", "pySpark", "Pyspark", "PySpark", "SAS", "scipy",
    "Azure Data Factory", "Java", "VBA", "Matplotlib", "Seaborn", "Pandas",
    "NumPy", "SciKit-Learn", "Streamlit", "Dash", "Shiny", "Flask", "Django",
    "BigQuery", "Redshift", "PostgreSQL", "MySQL", "DB2", "SQLite", "MLflow",
    "Plotly", "Bokeh", "D3.js", "GraphQL", "REST API", "Microservices"
]


    found_skills = []
    for skill in skills:
        if skill.lower() in description.lower():
            found_skills.append(skill)
    return found_skills if found_skills else ["Non spécifié"]

# %%
import pandas as pd
from google.colab import files

def extract_job_info(complete_data):
    """
    Extrait les informations de toutes les offres d'emploi dans la structure de données complète.

    :param complete_data: Liste de dictionnaires contenant les métadonnées de recherche et les résultats des emplois.
    :return: Liste de dictionnaires avec les informations extraites pour chaque emploi.
    """
    all_job_infos = []
    for data in complete_data:
        jobs_results = data.get('jobs_results', [])
        for job_data in jobs_results:
            job_info = {
                "title": job_data.get("title", "N/A"),
                "company_name": job_data.get("company_name", "N/A"),
                "location": job_data.get("location", "N/A").strip(),
                "experience": extract_experience(job_data.get("description", "")),
                "technical_skills": extract_technical_skills(job_data.get("description", ""))
            }
            all_job_infos.append(job_info)
    return all_job_infos

# Exemple d'utilisation
extracted_job_infos = extract_job_info(complete_data)
# Création d'un DataFrame à partir de la liste des offres d'emploi
df = pd.DataFrame(extracted_job_infos)
# Sauvegarde du DataFrame dans un fichier CSV
df.to_csv("google_jobs_data.csv", index=False)


files.download('google_jobs_data.csv')

# %%
# !pip install pandas
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (1.5.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas) (1.23.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)

# %%
complete_data
# Out:
# []

# %%
all_extracted_job_infos = []
for data in complete_data:
    job_infos = extract_job_info(data['jobs_results'])
    all_extracted_job_infos.extend(job_infos)

# Affichage des informations extraites pour chaque emploi
for job_info in all_extracted_job_infos:
    print(job_info)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-8-ecf460c24d52> in <cell line: 2>()
#       1 all_extracted_job_infos = []
#       2 for data in complete_data:
# ----> 3     job_infos = extract_job_info(data['jobs_results'])
#       4     all_extracted_job_infos.extend(job_infos)
#       5
#
# KeyError: 'jobs_results'
