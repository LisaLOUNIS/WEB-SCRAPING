# %% [markdown]
# # Webscraping from *welcometothejungle.com*

# %% [markdown]
# ### URLs to be scraped

# %%
urls = [
    "https://www.welcometothejungle.com/fr/companies/quantcube-technology/jobs/stagiaire-intern-advanced-macro-data-scientist_paris?q=f3cdd48ce0a998f317ecc1d16b8088d1&o=2266581" 
    "https://www.welcometothejungle.com/fr/companies/wivoo/jobs/consultant-senior-data-analyst_paris?q=f3cdd48ce0a998f317ecc1d16b8088d1&o=2069426",
    "https://www.welcometothejungle.com/fr/companies/groupe-micropole/jobs/stage-consultant-customer-data-management-f-h_levallois-perret_MICRO_RAz4krm?q=f3cdd48ce0a998f317ecc1d16b8088d1&o=1405897",
    "https://www.welcometothejungle.com/fr/companies/meilleurtaux-com/jobs/data-engineer-senior-h-f_paris?q=f3cdd48ce0a998f317ecc1d16b8088d1&o=2291701",
    "https://www.welcometothejungle.com/fr/companies/meilleurtaux-com/jobs/head-of-data-engineering-h-f_paris?q=f3cdd48ce0a998f317ecc1d16b8088d1&o=2291695",
    "https://www.welcometothejungle.com/fr/companies/meilleurtaux-com/jobs/product-manager-plateforme-data-h-f_paris_MEILL_DZqxyql?q=0852cdbe92c9248226e4a3fa7c95bc85&o=2289438",
    "https://www.welcometothejungle.com/fr/companies/quantcube-technology/jobs/intern-data-scientist-nlp_paris?q=0852cdbe92c9248226e4a3fa7c95bc85&o=1565637",
    "https://www.welcometothejungle.com/fr/companies/skiils/jobs/data-scientist-pricing-senior-h-f?q=bf40d746ee3afd6b88506af9e2585a6c&o=2283993",
    "https://www.welcometothejungle.com/fr/companies/carbo/jobs/carbon-data-scientist-stage_paris?q=bf40d746ee3afd6b88506af9e2585a6c&o=1936014",
    "https://www.welcometothejungle.com/fr/companies/datascientest/jobs/data-scientist_levallois-perret?q=bf40d746ee3afd6b88506af9e2585a6c&o=367193"
]

# %% [markdown]
# ## Scraping using BeautifulSoup

# %%
import requests
from bs4 import BeautifulSoup

for url in urls:
    response = requests.get(url)
    data = response.text
    soup = BeautifulSoup(data, 'html.parser')
    title = soup.find('h2').get_text()
    company = soup.find('span', class_="wui-text").get_text()
    location = soup.find('span', class_='sc-1eoldvz-0 bZJPQK').get_text()
    profil_recherche_section = soup.findAll('div', class_='sc-18ygef-1 ezamTS')[1] 
    lists = profil_recherche_section.find_all('ul')
    competences = []
    for ul in lists:
        items = ul.find_all('li')
        for item in items:
            competences.append(item.get_text(strip=True))
    print(f"Job offer: {title}")
    print(f"Company: {company}")
    print(f"Location: {location}")
    print(f"Demanded skills:")
    for c in competences:
        print(f" - {c}")
    print("----------------------------------------------------------")
# Out:
# Job offer: Stagiaire / Intern Advanced Macro Data Scientist
# Company: QuantCube Technology
# Location: Paris
# Demanded skills:
#  - Advanced Programming skills in Python, including OOP
#  - Mastery in Machine Learning models for classification and regression (Robust Linear Models, Clustering, Random Forest and Boosting Models, SVM …)
#  - Mastery in Time Series models (like ARIMA, VAR, ARCH,…), knowledge on Bayesian Learning and State Space Modeling (DFM) appreciated
#  - Strong interest for Economics and Finance
#  - Fluent in English, Fluency in any other language would be strongly appreciated
#  - Advanced level in Mathematics, Probability and Statistics and strong ability to learn new fields such as  Signal Extraction and Spectral Theory or Graph and Causality Theory
#  - Compétences avancées en programmation en Python, y compris en OOP
#  - Maîtrise des modèles d’apprentissage automatique pour la classification et la régression (modèles linéaires robustes, clustering, modèles Random Forest et Boosting, SVM …)
#  - Maîtrise des modèles de séries temporelles (comme ARIMA, VAR, ARCH,…), connaissance de l’apprentissage bayésien et de la modélisation de l’espace d’état (DFM) appréciée.
#  - Intérêt marqué pour l’économie et la finance
#  - Maîtrise de l’anglais, la maîtrise d’une autre langue serait fortement appréciée.
#  - Niveau avancé en mathématiques, probabilités et statistiques et forte capacité à apprendre de nouveaux domaines tels que l’extraction de signaux et la théorie spectrale ou la théorie des graphes et de la causalité.
# ----------------------------------------------------------
# Job offer: Stage Consultant Data Management (F/H)
# Company: Micropole
# Location: Levallois-Perret
# Demanded skills:
#  - Bonne expression orale et qualité rédactionnelle,
#  - Modélisation de données,
#  - Développement orienté objet (JS et PHP     serait un plus),
#  - Motivé, rigoureux, pragmatique, bon esprit de synthèse,
#  - Vous aimez travailler en équipe.
#  - Rigueur des livrables,
#  - Vous aimez travailler au sein d’une équipe pluridisciplinaire
#  - • Modélisation UML
#  - Modélisation de données
# ----------------------------------------------------------
# Job offer: Data Engineer Senior H/F
# Company: Meilleurtaux
# Location: Paris
# Demanded skills:
#  - Avec une expérience d'au moins 8 ans dans la Data, vous aviez été amené(e) à manager une petite équipe (entre 1 à 3 personnes) de Data Engineers.
#  - Vous savez créer desarchitectures de données efficaces,évolutivesetrobustes.
#  - Vous concevez des systèmes adaptés au présent mais également à l'avenir et qui résistent à l'épreuve du temps.
#  - Bien entendu, il est important que vous ayez de très bonnes compétences techniques que ce soit enPython;SQLet les autres outils pouvant exister en ingénierie de données.
#  - La Big Data n'a plus de secret pour vous.Spark&Hadoopsont vos plateformes de référence sur ce domaine.
#  - Vous avez déjà participé au déploiement d'infrastructure en Big Data.
#  - Idéalement, vous faîtes partie d'unecommunautéde professionnels de la Data vous permettant d'être toujours au fait des dernières actualités.
#  - Le must : cette expertise a été acquise au sein de l'industrieFintech/Assurtechou secteur équivalent.
#  - Du leadership :vous savez embarquer vos interlocuteurs dans un projet structurant et à forts enjeux pour l'entreprise.
#  - De la curiosité et de l'apprentissage continu :dans un domaine en constante évolution, nous recherchons une personne connectée aux nouvelles technologies et aux dernières innovations.
#  - De l'adaptation: vous savez prendre en considération les contraintes de l'entreprise et évaluer les risques techniques.
# ----------------------------------------------------------
# Job offer: Head of Data Engineering H/F
# Company: Meilleurtaux
# Location: Paris
# Demanded skills:
#  - Avec une expérience d'au moins 8 ans dans la Data, vous aviez été amené(e) à manager une petite équipe (entre 1 à 3 personnes) de Data Engineers.
#  - Vous savez créer desarchitectures de données efficaces,évolutivesetrobustes.
#  - Vous concevez des systèmes adaptés au présent mais également à l'avenir et qui résistent à l'épreuve du temps.
#  - Bien entendu, il est important que vous ayez de très bonnes compétences techniques que ce soit enPython;SQLet les autres outils pouvant exister en ingénierie de données.
#  - La Big Data n'a plus de secret pour vous.Spark&Hadoopsont vos plateformes de référence sur ce domaine.
#  - Vous avez déjà participé au déploiement d'infrastructure en Big Data.
#  - Idéalement, vous faîtes partie d'unecommunautéde professionnels de la Data vous permettant d'être toujours au fait des dernières actualités.
#  - Le must : cette expertise a été acquise au sein de l'industrieFintech/Assurtechou secteur équivalent.
#  - Du leadership :vous savez embarquer vos interlocuteurs dans un projet structurant et à forts enjeux pour l'entreprise.
#  - De la curiosité et de l'apprentissage continu :dans un domaine en constante évolution, nous recherchons une personne connectée aux nouvelles technologies et aux dernières innovations.
#  - De l'adaptation: vous savez prendre en considération les contraintes de l'entreprise et évaluer les risques techniques.
# ----------------------------------------------------------
# Job offer: Product Manager Plateforme Data H/F
# Company: Meilleurtaux
# Location: Paris
# Demanded skills:
#  - Vous êtes PO/PM depuis au moins 3 ans
#  - Vous avez une bonne maîtrise du discovery et du pilotage de roadmap en mode agile
#  - Vous avez une réelle appétence pour les sujets data
#  - Un bon relationnel pour pouvoir travailler avec de nombreuses équipes.
#  - Une bonne capacité d'écoute et d'analyse.
#  - Etre force de proposition.
# ----------------------------------------------------------
# Job offer: Intern NLP Data Scientist : Country Risk
# Company: QuantCube Technology
# Location: Paris
# Demanded skills:
#  - Strong programming skills in Python, with object oriented programming and pandas mastery. Ability to learn rapidly new python libraries.
#  - Experience dealing with NLP data, knowledge of basic concepts such as (embedding, preprocessing), and understanding of attention networks & LLMs are required.
#  - Genuine interest for Economics and Finance, and strong political or geopolitical knowledge. A demonstrated interest in the field is a strong asset.
#  - Strong Mathematics, Probabilities and Statistical Background, notably Bayesian statistics. Causal inference knowledge and practical experience in this field is a strong asset.
#  - Mastery in Machine Learning models for classification and regression (Robust Linear Models, Clustering, Random Forest and Boosting Models, SVM …) is a must.
#  - Experience dealing with time-series data and time-series modeling, with strong understanding of challenges related to time-series modelisation.
#  - Fluent in English, Fluency in any other language would be strongly appreciatedv
#  - team-player
#  - motivation,
#  - detail-oriented
#  - curiosity
#  - ability to communicate all results to the team
#  - Solides compétences en programmation en Python, avec une maîtrise de la programmation orientée objet et de pandas. Capacité à apprendre rapidement de nouvelles bibliothèques python.
#  - Expérience dans le traitement de données NLP, connaissance des concepts de base tels que (embedding, preprocessing), et compréhension des réseaux d’attention et des LLM sont nécessaires.
#  - Un véritable intérêt pour l’économie et la finance, ainsi que de solides connaissances politiques ou géopolitiques. Un intérêt manifeste pour le domaine est un atout majeur.
#  - Solides connaissances en mathématiques, probabilités et statistiques, notamment en statistiques bayésiennes. Une connaissance de l’inférence causale et une expérience pratique dans ce domaine constituent un atout majeur.
#  - La maîtrise des modèles d’apprentissage automatique pour la classification et la régression (modèles linéaires robustes, clustering, modèles Random Forest et Boosting, SVM …) est un atout.
#  - Expérience dans le traitement de données de séries temporelles et dans la modélisation de séries temporelles, avec une forte compréhension des défis liés à la modélisation de séries temporelles.
#  - Maîtrise de l’anglais, la maîtrise d’une autre langue serait fortement appréciée.
#  - esprit d’équipe
#  - motivation,
#  - sens du détail
#  - curiosité
#  - capacité à communiquer tous les résultats à l’équipe
# ----------------------------------------------------------
# Job offer: Data Scientist Pricing - Sénior H/F
# Company: skiils
# Location: Suresnes
# Demanded skills:
#  - Les processus agiles, c’est ton Dada ! Le Manifeste Agiles est toujours sur ta table de nuit
#  - Comprendre l’environnement fonctionnel du client est ta priorité, car tu sais que c’est grâce à cela que tu seras pertinent dans tes analyses
#  - Tu fais preuve d’autonomie, de dynamisme et les relations humaines font partie de tes fondements
#  - Tu pratiques l’Anglais aussi bien que Gad Elmaleh !
#  - Tu es à l’aise dans les chiffres et avez une bonne maîtrise d’Excel..
#  - Tu maitrise les technologies / languages,Python, SQL, Docker, Kubernetes, Git, Cloudprovider (GCP idéalement)
#  - Tu as la capacité d’élaborer des analyses statistiques / datamining (analyse de données, modélisation, segmentation, régression, prévision…)
#  - Tu es doté(e) d’un bon relationnel, permettant de s’adapter à différents types d’interlocuteurs (techniques et non-techniques),
#  - Tu bénéficie d’une excellente connaissance de la data visualisation et de la présentation des données ;
#  - Bon communiquant, tu as une bonne capacité à présenter des résultats complexes de manière claire et concise.
#  - Une expérience préalable dans le secteur du retail serait un atout.
# ----------------------------------------------------------
# Job offer: Carbon Data Scientist - Stage
# Company: Carbo
# Location: Paris
# Demanded skills:
#  - Tu as une formation et/ou de l’expérience en data science
#  - Tu as une première expérience ou un fort intérêt pour la comptabilité carbone, la transition énergétique et/ou environnementale.
#  - Tu maitrises la programmation Python
#  - Tu es à l’aise dans un environnement où les données sont non structurées, incomplètes et ambiguës
# ----------------------------------------------------------
# Job offer: Data Scientist (H/F) | Stage
# Company: Datascientest
# Location: Puteaux
# Demanded skills:
#  - Capable de gérer des charges de travail parfois élevées.
#  - Bonne maîtrise de Python.
#  - La maîtrise de la programmation orienté objet et/ou du cloud computing est un plus.
#  - Bonne culture data-science et attrait pour l’actualité relative aux machine learning au sens large.
#  - Bon niveau rédactionnel et oral en français/anglais.
#  - Prêt à énormément apprendre et à vivre une expérience unique dans un environnement start-up.
#  - Attrait pour la polyvalence et capacité à gérer plusieurs projets de front.
# ----------------------------------------------------------

# %% [markdown]
# ## Scraping using Selenium

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options

driver_path = '/path/to/chromedriver'

for url in urls:
    driver = webdriver.Chrome()
    driver.get(url)

    title = driver.find_element(By.TAG_NAME, 'h2').text
    company = driver.find_element(By.CLASS_NAME, 'wui-text').text
    location = driver.find_element(By.CLASS_NAME, 'sc-1eoldvz-0.bZJPQK').text

    profil_recherche_section = driver.find_elements(By.CLASS_NAME, 'sc-18ygef-1.ezamTS')[1]
    lists = profil_recherche_section.find_elements(By.TAG_NAME, 'ul')
    competences = []
    for ul in lists:
        items = ul.find_elements(By.TAG_NAME, 'li')
        for item in items:
            if item.text:
                competences.append(item.text)

    print(f"Job offer: {title}")
    print(f"Company: {company}")
    print(f"Location: {location}")
    print("Demanded skills:")
    for c in competences:
        print(f" - {c}")
    print("----------------------------------------------------------")
    driver.quit()
# Out:
# Job offer: Stagiaire / Intern Advanced Macro Data Scientist
# Company: QUANTCUBE TECHNOLOGY
# Location: Paris
# Demanded skills:
#  - Advanced Programming skills in Python, including OOP
#  - Mastery in Machine Learning models for classification and regression (Robust Linear Models, Clustering, Random Forest and Boosting Models, SVM …)
#  - Mastery in Time Series models (like ARIMA, VAR, ARCH,…), knowledge on Bayesian Learning and State Space Modeling (DFM) appreciated
#  - Strong interest for Economics and Finance
#  - Fluent in English, Fluency in any other language would be strongly appreciated
#  - Advanced level in Mathematics, Probability and Statistics and strong ability to learn new fields such as  Signal Extraction and Spectral Theory or Graph and Causality Theory
# ----------------------------------------------------------
# Job offer: Stage Consultant Data Management (F/H)
# Company: MICROPOLE
# Location: Levallois-Perret
# Demanded skills:
#  - Bonne expression orale et qualité rédactionnelle,
#  - Modélisation de données,
#  - Développement orienté objet (JS et PHP serait un plus),
#  - Motivé, rigoureux, pragmatique, bon esprit de synthèse,
#  - Vous aimez travailler en équipe.
#  - Rigueur des livrables,
#  - Vous aimez travailler au sein d’une équipe pluridisciplinaire
#  - • Modélisation UML
#  - Modélisation de données
# ----------------------------------------------------------
# Job offer: Data Engineer Senior H/F
# Company: MEILLEURTAUX
# Location: Paris
# Demanded skills:
#  - Avec une expérience d'au moins 8 ans dans la Data, vous aviez été amené(e) à manager une petite équipe (entre 1 à 3 personnes) de Data Engineers.
#  - Vous savez créer des architectures de données efficaces, évolutives et robustes.
#  - Vous concevez des systèmes adaptés au présent mais également à l'avenir et qui résistent à l'épreuve du temps.
#  - Bien entendu, il est important que vous ayez de très bonnes compétences techniques que ce soit en Python ; SQL et les autres outils pouvant exister en ingénierie de données.
#  - La Big Data n'a plus de secret pour vous. Spark & Hadoop sont vos plateformes de référence sur ce domaine.
# ----------------------------------------------------------
# Job offer: Head of Data Engineering H/F
# Company: MEILLEURTAUX
# Location: Paris
# Demanded skills:
#  - Avec une expérience d'au moins 8 ans dans la Data, vous aviez été amené(e) à manager une petite équipe (entre 1 à 3 personnes) de Data Engineers.
#  - Vous savez créer des architectures de données efficaces, évolutives et robustes.
#  - Vous concevez des systèmes adaptés au présent mais également à l'avenir et qui résistent à l'épreuve du temps.
#  - Bien entendu, il est important que vous ayez de très bonnes compétences techniques que ce soit en Python ; SQL et les autres outils pouvant exister en ingénierie de données.
#  - La Big Data n'a plus de secret pour vous. Spark & Hadoop sont vos plateformes de référence sur ce domaine.
# ----------------------------------------------------------
# Job offer: Product Manager Plateforme Data H/F
# Company: MEILLEURTAUX
# Location: Paris
# Demanded skills:
#  - Vous êtes PO/PM depuis au moins 3 ans
#  - Vous avez une bonne maîtrise du discovery et du pilotage de roadmap en mode agile
#  - Vous avez une réelle appétence pour les sujets data
#  - Un bon relationnel pour pouvoir travailler avec de nombreuses équipes.
#  - Une bonne capacité d'écoute et d'analyse.
#  - Etre force de proposition.
# ----------------------------------------------------------
# Job offer: Intern NLP Data Scientist : Country Risk
# Company: QUANTCUBE TECHNOLOGY
# Location: Paris
# Demanded skills:
#  - Strong programming skills in Python, with object oriented programming and pandas mastery. Ability to learn rapidly new python libraries.
#  - Experience dealing with NLP data, knowledge of basic concepts such as (embedding, preprocessing), and understanding of attention networks & LLMs are required.
#  - Genuine interest for Economics and Finance, and strong political or geopolitical knowledge. A demonstrated interest in the field is a strong asset.
#  - Strong Mathematics, Probabilities and Statistical Background, notably Bayesian statistics. Causal inference knowledge and practical experience in this field is a strong asset.
# ----------------------------------------------------------
# Job offer: Data Scientist Pricing - Sénior H/F
# Company: SKIILS
# Location: Suresnes
# Demanded skills:
#  - Les processus agiles, c’est ton Dada ! Le Manifeste Agiles est toujours sur ta table de nuit
#  - Comprendre l’environnement fonctionnel du client est ta priorité, car tu sais que c’est grâce à cela que tu seras pertinent dans tes analyses
#  - Tu fais preuve d’autonomie, de dynamisme et les relations humaines font partie de tes fondements
#  - Tu pratiques l’Anglais aussi bien que Gad Elmaleh !
#  - Tu es à l’aise dans les chiffres et avez une bonne maîtrise d’Excel..
#  - Tu maitrise les technologies / languages, Python, SQL, Docker, Kubernetes, Git, Cloud provider (GCP idéalement)
# ----------------------------------------------------------
# Job offer: Carbon Data Scientist - Stage
# Company: CARBO
# Location: Paris
# Demanded skills:
#  - Tu as une formation et/ou de l’expérience en data science
#  - Tu as une première expérience ou un fort intérêt pour la comptabilité carbone, la transition énergétique et/ou environnementale.
#  - Tu maitrises la programmation Python
#  - Tu es à l’aise dans un environnement où les données sont non structurées, incomplètes et ambiguës
# ----------------------------------------------------------
# Job offer: Data Scientist (H/F) | Stage
# Company: DATASCIENTEST
# Location: Puteaux
# Demanded skills:
#  - Capable de gérer des charges de travail parfois élevées.
#  - Bonne maîtrise de Python.
#  - La maîtrise de la programmation orienté objet et/ou du cloud computing est un plus.
#  - Bonne culture data-science et attrait pour l’actualité relative aux machine learning au sens large.
#  - Bon niveau rédactionnel et oral en français/anglais.
#  - Prêt à énormément apprendre et à vivre une expérience unique dans un environnement start-up.
#  - Attrait pour la polyvalence et capacité à gérer plusieurs projets de front.
# ----------------------------------------------------------
