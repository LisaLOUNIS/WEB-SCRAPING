# %% [markdown]
# #API scrapping of all the pages of Google Jobs

# %%
import requests
import pandas as pd

def fetch_all_google_jobs_data(api_key, query, location, hl="en", chips=None):
    """
    Récupère les données de toutes les pages de l'API Google Jobs pour une recherche donnée.

    Paramètres :
    api_key (str): Clé privée SerpApi.
    query (str): Requête de recherche.
    location (str, optionnel): Lieu géographique pour la recherche.
    hl (str): Langue pour la recherche.
    chips (list, optionnel): Conditions supplémentaires pour la requête.

    Retourne :
    list: Toutes les réponses JSON analysées de l'API.
    """
    all_results = []
    start = 0
    while True:
        # Paramètres pour la requête API
        params = {
            "engine": "google_jobs",
            "q": query,
            "start": start,
            "hl": hl,
            "api_key": api_key
        }

        if location:
            params["location"] = location

        if chips:
            params["chips"] = ','.join(chips)

        # URL de base pour l'API Google Jobs
        base_url = "https://serpapi.com/search.json"

        # Envoi d'une requête GET à l'API
        response = requests.get(base_url, params=params)
        if response.status_code == 200:
            data = response.json()
            all_results.append(data)

            # Vérifier s'il y a encore des résultats
            if "jobs_results" not in data or not data["jobs_results"]:
                break

            start += 20  # Incrémenter pour la prochaine page
        else:
            break

    return all_results

# Utilisation de la fonction
# Remplacez 'your_api_key' par votre clé SerpApi rée
complete_data = fetch_all_google_jobs_data("65c15aeae94ce28a059108557e76ff428c362bd6550714533d91c1cf3c77f016", "Data", "France")

# %%
complete_data
# Out:
# [{'search_metadata': {'id': '65b54c2d7d171ac804ca8446',
#    'status': 'Success',
#    'json_endpoint': 'https://serpapi.com/searches/1763f059e06b1a6e/65b54c2d7d171ac804ca8446.json',
#    'created_at': '2024-01-27 18:32:13 UTC',
#    'processed_at': '2024-01-27 18:32:13 UTC',
#    'google_jobs_url': 'https://www.google.com/search?q=Data&ibp=htl;jobs&uule=w+CAIQICIGRnJhbmNl&hl=en&start=0',
#    'raw_html_file': 'https://serpapi.com/searches/1763f059e06b1a6e/65b54c2d7d171ac804ca8446.html',
#    'total_time_taken': 2.02},
#   'search_parameters': {'q': 'Data',
#    'engine': 'google_jobs',
#    'location_requested': 'France',
#    'location_used': 'France',
#    'google_domain': 'google.com',
#    'hl': 'en',
#    'start': 0},
#   'jobs_results': [{'title': 'Job offer Data Scientist / Quant Research Analyst W/M - BNP Paribas',
#     'company_name': 'BNP Paribas',
#     'location': '  France   ',
#     'via': 'via CFA Institute Career Center',
#     'description': "Data Scientist - Quant Research Analyst - W/M\n\nStrengthening the quantitative research capacity and meeting the sustainable ambitions of BNP Paribas Asset Management\n\n#Quant #Data Scientist\n\nConcretely your daily life?\n\n- Act as sparring partners for investment teams, developing a collaborative relationship with experienced portfolio managers while being able to challenge them. You will also need to pitch our capabilities in front of clients and at conferences. In nutshell, developing our savoir faire (expertise) as well as our faire savoir (to inform).\n\n- Contribute towards making BNP Paribas Asset Management ambitions real. You will work with investment teams for which the use of quantitative techniques is still not sufficiently strong and develop the relationship and models with such teams, leading to cutting edge robust investment processes while respecting the investment team's philosophy.\n\n- Contribute towards BNP Paribas Asset Management factor investing ambitions by... researching and enriching our library of factors with new ones, putting strong emphasis on their economic rationale and ensuring that portfolio construction is delivering the targeted factor exposures given various constraints. Factor investing ambitions cover equities, fixed income and other asset classes. You will also take the responsibility for presenting our research to clients and at conferences.\n\n- Contribute towards the design of sustainable and innovative investment solutions. He/she will need to play a key role in measuring ESG criteria and taking them into account in our investment strategies. He/she will help our solutions group answering client needs and increasing our AUM. We also expect them to keep track of industry developments and to propose new and innovative ideas to develop quantitative investment solutions that give the BNP Paribas Asset Management a competitive advantage.\n\n- Work along with our data scientists assisting the Quant Research Group with extracting value from big data. He/she will rely on machine learning and artificial intelligence techniques to improve and develop quantitative strategies where required, bringing the quantitative investment expertise required to make such strategies work.\n\n- Work on topics listed above as well as on other topics that may be considered in the future as key for BNP Paribas Asset Management. As such he/she needs to be flexible and capable of addressing new research topics as a function of priorities.\n\n- We offer a challenging role with many responsibilities and visible impact. Your daily work will go from processing big data to analyzing various signals and discussing research insights with your colleagues and PMs. Your frequent interactions with various parties inside and outside our department provide many learning opportunities. You will experience quantitative research and quantitative portfolio management from nearby. You are expected to contribute to our future success by generating innovative ideas and getting things done!\n\nThe work environment is important!\n\nBNP Paribas Asset Management is looking to hire data scientists/quantitative analysts to strengthen its Quant Research Group. BNP Paribas Asset Management is the investment management arm of BNP Paribas, one of the world's major financial institutions. Managing and advising around EUR 0.5 trillion in assets in 2023, BNP Paribas Asset Management offers a comprehensive range of active, passive and quantitative investment solutions covering a broad spectrum of asset classes and regions. The Quant Research Group was created 15 years ago with the objective of creating a team with a critical size to develop a strong quantitative culture at BNP Paribas Asset Management. The team has about 30 people in Paris, Amsterdam, London and Hong Kong.\n\nThe Quant Research Group is looking to hire quantitative analysts to help us meet the four quantitative ambitions of BNP Paribas Asset Management:\n\ ...
#     'job_highlights': [{'items': ["Data Scientist - Quant Research Analyst - W/M\n\nStrengthening the quantitative research capacity and meeting the sustainable ambitions of BNP Paribas Asset Management\n\n#Quant #Data Scientist\n\nConcretely your daily life?\n\n- Act as sparring partners for investment teams, developing a collaborative relationship with experienced portfolio managers while being able to challenge them. You will also need to pitch our capabilities in front of clients and at conferences. In nutshell, developing our savoir faire (expertise) as well as our faire savoir (to inform).\n\n- Contribute towards making BNP Paribas Asset Management ambitions real. You will work with investment teams for which the use of quantitative techniques is still not sufficiently strong and develop the relationship and models with such teams, leading to cutting edge robust investment processes while respecting the investment team's philosophy.\n\n- Contribute towards BNP Paribas Asset Management factor investing ambitions by... researching and enriching our library of factors with new ones, putting strong emphasis on their economic rationale and ensuring that portfolio construction is delivering the targeted factor exposures given various constraints. Factor investing ambitions cover equities, fixed income and other asset classes. You will also take the responsibility for presenting our research to clients and at conferences.\n\n- Contribute towards the design of sustainable and innovative investment solutions. He/she will need to play a key role in measuring ESG criteria and taking them into account in our investment strategies. He/she will help our solutions group answering client needs and increasing our AUM. We also expect them to keep track of industry developments and to propose new and innovative ideas to develop quantitative investment solutions that give the BNP Paribas Asset Management a competitive advantage.\n\n- Work along with our data scientists assisting the Quant Research Group with extracting value from big data. He/she will rely on machine learning and artificial intelligence techniques to improve and develop quantitative strategies where required, bringing the quantitative investment expertise required to make such strategies work.\n\n- Work on topics listed above as well as on other topics that may be considered in the future as key for BNP Paribas Asset Management. As such he/she needs to be flexible and capable of addressing new research topics as a function of priorities.\n\n- We offer a challenging role with many responsibilities and visible impact. Your daily work will go from processing big data to analyzing various signals and discussing research insights with your colleagues and PMs. Your frequent interactions with various parties inside and outside our department provide many learning opportunities. You will experience quantitative research and quantitative portfolio management from nearby. You are expected to contribute to our future success by generating innovative ideas and getting things done!\n\nThe work environment is important!\n\nBNP Paribas Asset Management is looking to hire data scientists/quantitative analysts to strengthen its Quant Research Group. BNP Paribas Asset Management is the investment management arm of BNP Paribas, one of the world's major financial institutions. Managing and advising around EUR 0.5 trillion in assets in 2023, BNP Paribas Asset Management offers a comprehensive range of active, passive and quantitative investment solutions covering a broad spectrum of asset classes and regions. The Quant Research Group was created 15 years ago with the objective of creating a team with a critical size to develop a strong quantitative culture at BNP Paribas Asset Management. The team has about 30 people in Paris, Amsterdam, London and Hong Kong.\n\nThe Quant Research Group is looking to hire quantitative analysts to help us meet the four quantitative ambitions of BNP Paribas Asset ...
#     'related_links': [{'link': 'https://www.bnpparibas.com/',
#       'text': 'bnpparibas.com'},
#      {'link': 'https://www.google.com/search?sca_esv=c3b077f30ef0887c&q=BNP+Paribas&sa=X&ved=0ahUKEwih7PSNmv6DAxXaTDABHZu9AT4QmJACCOYK',
#       'text': 'See web results for BNP Paribas'}],
#     'extensions': ['19 hours ago', 'Full-time'],
#     'detected_extensions': {'posted_at': '19 hours ago',
#      'schedule_type': 'Full-time'},
#     'job_id': '...'},
#    {'title': 'Product Owner for Data Referentials',
#     'company_name': 'AXA Group',
#     'location': '  Puteaux, France   ',
#     'via': 'via Careers At AXA',
#     'description': 'At AXA IM our purpose, to act for human progress by investing for what matters, is central to every action we take as a business. As a responsible asset manager, we actively invest for the long-term to help our clients, our people and the world to prosper.\n\nAs a future Product Owner for Data Referentials, you will report to our Head of Data Products and you will be part of the Technology – Data, Finance & Digital team.\n\nDISCOVER your opportunity\n\nAs part of its Data strategy, AXA IM has built a very successful/state of the heart Data Product Factory . About 15 various Data Product squads from different domains (Data Referential, Responsible Investment, Quant & Research, Finance, Digital, Front office, Operations, Trading, etc.) are building their own data families and leveraging the data families produced and maintained by others. The platform offers Data Science, Exploration, Visualisation, to hundreds of our internal and AXA Group customers.\n\nAs a Product Owner for Data... Referentials, you will be responsible for designing, implementing and maintaining our Master Data Management (MDM) for AXA IM, i.e. developing the Data Families around Data Referentials (Instruments, Products and Portfolios, Indices, Forex, Assets, etc.). You will oversee the definition and delivery of our product vision and delivery initiatives. You will coordinate the book of work with the Data Management Evolution Team to deliver values for our customers. Your squad will be composed of 2 Data Analysts 8 Data Engineers and 2 Dev Ops Engineers.\n\nThe Product Owner is also accountable for the entire product life cycle, including user needs gathering, market trend analysis, product trajectory, build, transition to support, operations, continual improvement and decommissioning.\n\nYour role and responsibilities will notably include:\n\nAs a Product Owner for Data Referentials, you wil:\n• Help Data Management administrate the referential golden sources;\n• Drive the implementation of data referential features for our internal customers and delivery key functionalities for strategic and less strategic projects;\n• Improve Data quality on our referentials;\n• Transform and simplify our current architecture;\n• Leverage our Data Platform Core team and partner with our Neoxam vendor to develop our MDM.\n\nYou will also engage our Business to:\n• Agree on a product vision, strategy and initiatives to implement a 3 year plan;\n• Define the path to deliver the best business outcome via POCs and MVPs;\n• Deep dive into the high-level requirements, define the delivery approach, influence prioritisation and high-level delivery strategy;\n• Highlight optimisation through constant feedback loops involving all actors of the value chain;\n• Influence towards tackling technical depth, testing automation, software industrialisation.\n\nYou will engage with various representatives, demonstrate the ability to understand the business concepts and Operational Data Management, Operational security. Translate these into your feature designs and business outcomes.\n\nYou will participate in the design of the MDM architecture to expose strategic Datamarts, build clean data catalogue easily understandable, build trust on data quality with our consumers, build data models, build consumer centric APIs, distribute data efficiently in a generic way Participate to the Data commities to represent technology.\n\nFinally, as part of the AXA IM family, you are expected to also\n• Keep team’s morale up;\n• Value diversity and difference of opinion;\n• Transform AXA IM to simplify our value chain, increase our velocity, build a great working environment.\n\n#LI-JB1\n\nYour Profile\n\nSHARE your unique expertise\n\nWe welcome different combinations of skills and experiences.\n• Data Driven person with an ambition to drive the data agenda at AXAIM;\n• Experienced in technology deliveries in the Cloud (Azure preferred);\n• Experience in the financial services industry ...
#     'job_highlights': [{'items': ['At AXA IM our purpose, to act for human progress by investing for what matters, is central to every action we take as a business. As a responsible asset manager, we actively invest for the long-term to help our clients, our people and the world to prosper.\n\nAs a future Product Owner for Data Referentials, you will report to our Head of Data Products and you will be part of the Technology – Data, Finance & Digital team.\n\nDISCOVER your opportunity\n\nAs part of its Data strategy, AXA IM has built a very successful/state of the heart Data Product Factory . About 15 various Data Product squads from different domains (Data Referential, Responsible Investment, Quant & Research, Finance, Digital, Front office, Operations, Trading, etc.) are building their own data families and leveraging the data families produced and maintained by others. The platform offers Data Science, Exploration, Visualisation, to hundreds of our internal and AXA Group customers.\n\nAs a Product Owner for Data... Referentials, you will be responsible for designing, implementing and maintaining our Master Data Management (MDM) for AXA IM, i.e. developing the Data Families around Data Referentials (Instruments, Products and Portfolios, Indices, Forex, Assets, etc.). You will oversee the definition and delivery of our product vision and delivery initiatives. You will coordinate the book of work with the Data Management Evolution Team to deliver values for our customers. Your squad will be composed of 2 Data Analysts 8 Data Engineers and 2 Dev Ops Engineers.\n\nThe Product Owner is also accountable for the entire product life cycle, including user needs gathering, market trend analysis, product trajectory, build, transition to support, operations, continual improvement and decommissioning.\n\nYour role and responsibilities will notably include:\n\nAs a Product Owner for Data Referentials, you wil:\n• Help Data Management administrate the referential golden sources;\n• Drive the implementation of data referential features for our internal customers and delivery key functionalities for strategic and less strategic projects;\n• Improve Data quality on our referentials;\n• Transform and simplify our current architecture;\n• Leverage our Data Platform Core team and partner with our Neoxam vendor to develop our MDM.\n\nYou will also engage our Business to:\n• Agree on a product vision, strategy and initiatives to implement a 3 year plan;\n• Define the path to deliver the best business outcome via POCs and MVPs;\n• Deep dive into the high-level requirements, define the delivery approach, influence prioritisation and high-level delivery strategy;\n• Highlight optimisation through constant feedback loops involving all actors of the value chain;\n• Influence towards tackling technical depth, testing automation, software industrialisation.\n\nYou will engage with various representatives, demonstrate the ability to understand the business concepts and Operational Data Management, Operational security. Translate these into your feature designs and business outcomes.\n\nYou will participate in the design of the MDM architecture to expose strategic Datamarts, build clean data catalogue easily understandable, build trust on data quality with our consumers, build data models, build consumer centric APIs, distribute data efficiently in a generic way Participate to the Data commities to represent technology.\n\nFinally, as part of the AXA IM family, you are expected to also\n• Keep team’s morale up;\n• Value diversity and difference of opinion;\n• Transform AXA IM to simplify our value chain, increase our velocity, build a great working environment.\n\n#LI-JB1\n\nYour Profile\n\nSHARE your unique expertise\n\nWe welcome different combinations of skills and experiences.\n• Data Driven person with an ambition to drive the data agenda at AXAIM;\n• Experienced in technology deliveries in the Cloud (Azure preferred);\n• Experience in the financial se ...
#     'related_links': [{'link': 'http://www.axa.com/', 'text': 'axa.com'},
#      {'link': 'https://www.google.com/search?sca_esv=c3b077f30ef0887c&q=AXA+Group&sa=X&ved=0ahUKEwih7PSNmv6DAxXaTDABHZu9AT4QmJACCKAL',
#       'text': 'See web results for AXA Group'}],
#     'thumbnail': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQO6DoDObFTenHxT5tx3BsHshXYJng_evz6Spmg&s=0',
#     'extensions': ['19 hours ago', 'Full-time', 'No degree mentioned'],
#     'detected_extensions': {'posted_at': '19 hours ago',
#      'schedule_type': 'Full-time'},
#     'job_id': '...'},
#    {'title': 'Data Scientist',
#     'company_name': 'PUR',
#     'location': '  Paris, France   ',
#     'via': 'via PUR',
#     'description': "Data Scientist\n\nBased in Paris, France\n\nFull time position, local contract\n\nBeginning: February 2024\n\nWHO WE ARE\n\nPUR is a global leader in supply chain sustainability. We develop socio-environmental projects within the supply chains of our Corporate Partners. Through the economic and social empowerment of local communities and the introduction of sustainable development initiatives at the agricultural level, PUR seeks to address climate change, while regenerating and preserving the ecosystems upon which these supply chains depend. Many of PUR's projects fall within the categories of insetting, regenerative agriculture, agroforestry, forest conservation and landscape restoration. PUR is a B Corp Company which employs over 200 people and a presence in 10 countries.\n\nwww.pur.co\n\nThe Data Scientist will help us leverage our field and tree species information, translating it into the carbon impact we are making in the world. They will integrate the Data Team and work closely to the Carbon... team as well. They will use the extensive data we have to create models that will guide our project design, contracts, and state-of-the-art carbon modeling that is better suited to the reality of agroforestry projects in tropical areas.\n\nYour responsibilities will include in a non-exhaustive manner :\n• Implement and optimize Machine Learning (eventually Deep Learning) models.\n• Work with structured and unstructured data (geospatial and image data).\n• Process and treat large volumes of information to generate insights and train models.\n• Implement and maintain Python codes.\n• Create dashboards and visualizations to show what the data says;\n• Develop and maintain a species-based carbon forecast and quantification tool.\n• Perform statistical analysis to evaluate uncertainty of forecast, drafting possible scenarios of carbon sequestration figures.\n• Pinpoint the best plots to use as sample plots for the carbon quantification, based on their representativeness of our projects.\n• Continuous improvement of the model and analysis of forecasted results based on new data coming in (Project Dashboards/ Long-Term Monitoring/ Verification & Data Mining).\n• Provide internal consultancy, using the created models, on best project design meeting carbon obligations (based on carbon analysis) & others relevant impacts (biodiversity / livelihoods / crop yields / water).\n\nWe are looking for a candidate with :\n• 3 years experience in a Data Analyst / Data Scientist position.\n• Experience with Exploratory Data Analysis.\n• Solid knowledge of statistics - sampling methods, hypothesis testing, causal inference, correlograms.\n• Solid knowledge of SQL.\n• Solid knowledge of Python, including most of the following libs: Scikit-learn, Pandas, Numpy; Tensorflow, Keras, Xgboost and Matplotlib.\n• Experience with machine learning algorithms at work environment; knowledge of neural networks and Deep Learning algorithms at least on a personal project setting.\n• Knowledge of software engineering: unit testing, TDD, OOP, concern with performance and code quality.\n• Familiarity with project management tools such as JIRA and Confluence.\n• Interest and competence to be responsible for the complete process, from data experiments to implementation and monitoring in production (with the help of Data Engineers).\n• Some experience in Sustainability or Impact (or a least a strong interest).\n• Fluent in English. French and Spanish would be an asset.\n• Able to come 3x to the office per week minimum - this is not a full remote position.\n\nRecruitment process :\n• HR interview\n• Technical interview\n• Interview with the CDO + References check",
#     'job_highlights': [{'items': ["Data Scientist\n\nBased in Paris, France\n\nFull time position, local contract\n\nBeginning: February 2024\n\nWHO WE ARE\n\nPUR is a global leader in supply chain sustainability. We develop socio-environmental projects within the supply chains of our Corporate Partners. Through the economic and social empowerment of local communities and the introduction of sustainable development initiatives at the agricultural level, PUR seeks to address climate change, while regenerating and preserving the ecosystems upon which these supply chains depend. Many of PUR's projects fall within the categories of insetting, regenerative agriculture, agroforestry, forest conservation and landscape restoration. PUR is a B Corp Company which employs over 200 people and a presence in 10 countries.\n\nwww.pur.co\n\nThe Data Scientist will help us leverage our field and tree species information, translating it into the carbon impact we are making in the world. They will integrate the Data Team and work closely to the Carbon... team as well. They will use the extensive data we have to create models that will guide our project design, contracts, and state-of-the-art carbon modeling that is better suited to the reality of agroforestry projects in tropical areas.\n\nYour responsibilities will include in a non-exhaustive manner :\n• Implement and optimize Machine Learning (eventually Deep Learning) models.\n• Work with structured and unstructured data (geospatial and image data).\n• Process and treat large volumes of information to generate insights and train models.\n• Implement and maintain Python codes.\n• Create dashboards and visualizations to show what the data says;\n• Develop and maintain a species-based carbon forecast and quantification tool.\n• Perform statistical analysis to evaluate uncertainty of forecast, drafting possible scenarios of carbon sequestration figures.\n• Pinpoint the best plots to use as sample plots for the carbon quantification, based on their representativeness of our projects.\n• Continuous improvement of the model and analysis of forecasted results based on new data coming in (Project Dashboards/ Long-Term Monitoring/ Verification & Data Mining).\n• Provide internal consultancy, using the created models, on best project design meeting carbon obligations (based on carbon analysis) & others relevant impacts (biodiversity / livelihoods / crop yields / water).\n\nWe are looking for a candidate with :\n• 3 years experience in a Data Analyst / Data Scientist position.\n• Experience with Exploratory Data Analysis.\n• Solid knowledge of statistics - sampling methods, hypothesis testing, causal inference, correlograms.\n• Solid knowledge of SQL.\n• Solid knowledge of Python, including most of the following libs: Scikit-learn, Pandas, Numpy; Tensorflow, Keras, Xgboost and Matplotlib.\n• Experience with machine learning algorithms at work environment; knowledge of neural networks and Deep Learning algorithms at least on a personal project setting.\n• Knowledge of software engineering: unit testing, TDD, OOP, concern with performance and code quality.\n• Familiarity with project management tools such as JIRA and Confluence.\n• Interest and competence to be responsible for the complete process, from data experiments to implementation and monitoring in production (with the help of Data Engineers).\n• Some experience in Sustainability or Impact (or a least a strong interest).\n• Fluent in English. French and Spanish would be an asset.\n• Able to come 3x to the office per week minimum - this is not a full remote position.\n\nRecruitment process :\n• HR interview\n• Technical interview\n• Interview with the CDO + References check"]}],
#     'related_links': [{'link': 'https://www.google.com/search?sca_esv=c3b077f30ef0887c&q=PUR&sa=X&ved=0ahUKEwih7PSNmv6DAxXaTDABHZu9AT4QmJACCN0L',
#       'text': 'See web results for PUR'}],
#     'extensions': ['6 days ago', 'Full-time'],
#     'detected_extensions': {'posted_at': '6 days ago',
#      'schedule_type': 'Full-time'},
#     'job_id': '...'},
#    {'title': 'UX designer, Data Products & Services',
#     'company_name': 'STELLANTIS',
#     'location': ' Anywhere ',
#     'via': 'via JobTeaser',
#     'description': "Your Mission We are on a mission to be a leading global provider of highest quality data products, services, and rich, actionable insights derived from connected car data in a privacy compliant, non-discriminatory, and easy to consume fashion. As a UX Designer, Data Products & Services you will own the design & workflow definition for the data platform user interfaces for internal & external platform users. This is a key leadership role that will spearhead rapid buildout and delivery of data products and services to enable existing and emerging use-cases across a variety of market segments, ensuring its sustained long-term revenue growth. In this role, you should be an analytical and creative designer who is able to grasp user needs and solve problems. A strong portfolio of successful UX and other technical projects is essential. Ultimately, you will make our product user-friendly and intuitive attracting and retaining customers. We're looking for an individual with problem-solving... aptitude, an analytical mind with a business acumen and excellent design & communication skills. Responsibilities include but are not limited to, • Lead discovery of user requirements for a growing set of use-cases for multiple market segments by engaging with customers and prospects as well as GTM, Marketing, and Planning & Operations teams. Identify target user groups and carry out interviews or other types of inquiry to help understand user needs. Document user requirements. Communicate design ideas & workflows to the Product Owner & Development team. Use creative methods to solve UX problems. • Understand product specifications and user psychology and predict what might work for both. • Partner with Product Managers & Product Owners to create wireframe/UX prototype to create industry leading UI/UX experience for internal as well as external customers. Produce high-quality solutions through flow diagrams, graphic designs, storyboards and site maps. Conduct concept and usability testing and gather feedback defining the interaction model. • Provide guidance on the implementation of UX research techniques and testing activities to assess user behavior. Establish design best practices including definition of UX/UI processes. • Partner with development teams on fast prototyping innovative product ideas for demos and customer pilots. • Partner with Product Owner in user story definitions for the UX and exit criteria for user stories. • Collaborate with data governance and tech teams on institutionalizing strong data governance policy for data management of partner/3rd party data to ensure data privacy compliance with GDPR and CCPA. • Work closely with Marketing and GTM teams to assist on product marketing deliverables including product demos & to keep abreast of competitive & industry trends.\n\nProven experience as a UX Designer, UI Designer or similar role with hands-on experience in data or software products. A 0 to 1 mindset and a track record of supporting new market segments and use-cases through innovative products/designs. A passion for creatively solving product and business challenges with data, technology and design. Blue-sky, out-of-the-box thinking to find new applications for existing product capabilities. Ability to understand business metrics and translate company goals and objectives into digital experiences. Strong customer orientation, with a strong portfolio of UX/design projects. Direct customer engagement experience is desired; so is a high EQ and an ability to 'read the room'. Background in project management and research Familiarity with interaction design and information architecture Proficient in design software (e.g. UXPin, Balsamiq) Knowledge of HTML/CSS; JavaScript is a plus Strong communication skills with an ability to clearly articulate UX design supporting the product strategy to technical as well as commercial audiences across the organization. Skillful in managing stakeholders and their competin ...
#     'job_highlights': [{'items': ["Your Mission We are on a mission to be a leading global provider of highest quality data products, services, and rich, actionable insights derived from connected car data in a privacy compliant, non-discriminatory, and easy to consume fashion. As a UX Designer, Data Products & Services you will own the design & workflow definition for the data platform user interfaces for internal & external platform users. This is a key leadership role that will spearhead rapid buildout and delivery of data products and services to enable existing and emerging use-cases across a variety of market segments, ensuring its sustained long-term revenue growth. In this role, you should be an analytical and creative designer who is able to grasp user needs and solve problems. A strong portfolio of successful UX and other technical projects is essential. Ultimately, you will make our product user-friendly and intuitive attracting and retaining customers. We're looking for an individual with problem-solving... aptitude, an analytical mind with a business acumen and excellent design & communication skills. Responsibilities include but are not limited to, • Lead discovery of user requirements for a growing set of use-cases for multiple market segments by engaging with customers and prospects as well as GTM, Marketing, and Planning & Operations teams. Identify target user groups and carry out interviews or other types of inquiry to help understand user needs. Document user requirements. Communicate design ideas & workflows to the Product Owner & Development team. Use creative methods to solve UX problems. • Understand product specifications and user psychology and predict what might work for both. • Partner with Product Managers & Product Owners to create wireframe/UX prototype to create industry leading UI/UX experience for internal as well as external customers. Produce high-quality solutions through flow diagrams, graphic designs, storyboards and site maps. Conduct concept and usability testing and gather feedback defining the interaction model. • Provide guidance on the implementation of UX research techniques and testing activities to assess user behavior. Establish design best practices including definition of UX/UI processes. • Partner with development teams on fast prototyping innovative product ideas for demos and customer pilots. • Partner with Product Owner in user story definitions for the UX and exit criteria for user stories. • Collaborate with data governance and tech teams on institutionalizing strong data governance policy for data management of partner/3rd party data to ensure data privacy compliance with GDPR and CCPA. • Work closely with Marketing and GTM teams to assist on product marketing deliverables including product demos & to keep abreast of competitive & industry trends.\n\nProven experience as a UX Designer, UI Designer or similar role with hands-on experience in data or software products. A 0 to 1 mindset and a track record of supporting new market segments and use-cases through innovative products/designs. A passion for creatively solving product and business challenges with data, technology and design. Blue-sky, out-of-the-box thinking to find new applications for existing product capabilities. Ability to understand business metrics and translate company goals and objectives into digital experiences. Strong customer orientation, with a strong portfolio of UX/design projects. Direct customer engagement experience is desired; so is a high EQ and an ability to 'read the room'. Background in project management and research Familiarity with interaction design and information architecture Proficient in design software (e.g. UXPin, Balsamiq) Knowledge of HTML/CSS; JavaScript is a plus Strong communication skills with an ability to clearly articulate UX design supporting the product strategy to technical as well as commercial audiences across the organization. Skillful in managing stakeholders and ...
#     'related_links': [{'link': 'http://www.fcagroup.com/',
#       'text': 'fcagroup.com'},
#      {'link': 'https://www.google.com/search?sca_esv=c3b077f30ef0887c&q=STELLANTIS&sa=X&ved=0ahUKEwih7PSNmv6DAxXaTDABHZu9AT4QmJACCJYM',
#       'text': 'See web results for STELLANTIS'}],
#     'thumbnail': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTh6K-hTdDs9ur_aJu1tYeV4Stp3XfodpGFIB9y2d8&s',
#     'extensions': ['1 day ago', 'Work from home', 'Full-time'],
#     'detected_extensions': {'posted_at': '1 day ago',
#      'schedule_type': 'Full-time',
#      'work_from_home': True},
#     'job_id': '...'},
#    {'title': 'Global Senior Data Architect',
#     'company_name': 'CMA CGM',
#     'location': '  Marseille, France   ',
#     'via': 'via Careers Opportunities In CMA CGM Group',
#     'description': "CEVA Logistics provides global supply chain solutions to connect people, products and providers all around the world. Present in 170 countries and with more than 110,000 employees spread over 1,300 sites, we are well on our way to achieving our vision: to be a Top 5 global 3PL.\n\nWe believe that our employees are the key to our success. We want to engage and empower our diverse, global team to co-create value with our customers through our solutions in contract logistics and air, ocean, ground, and finished vehicle transport. That is why CEVA Logistics offers a dynamic and exceptional work environment that fosters personal growth, innovation, and continuous improvement.\n\nDARE TO GROW! Join CEVA Logistics, and you will be part of a team that values imagination, encourages boldness and exemplarity, and is committed to excellence in everything we do. Join us in our mission to shape the future of global logistics as we become a global leader in the logistics industry. As we continue... growing at a fast pace, will you “Dare to Grow” with us?\n\nYOUR ROLE\n\nDATA FACTORY MANAGER / SENIOR DATA ARCHITECT\n\nBased in France (Marseille or Puteaux).\n\nWHAT ARE YOU GOING TO DO?\n\nThe Senior Data Architect will join the Global IT Data and Digital organization at CEVA Logistics within the Global CIO organization and will report to the Head of the CEVA Global Data Factory.\n\nThis role operates in complex decision-making environments impacting the CEVA enterprise, works with senior management from IT, BD and Operations to ensure the best possible global solutions are available for our customers and CEVA employees alike.\n\nThe data architect will operate in the context of the set of the new Cloud Data Platform of CEVA and will contribute to its set up, development and growth and built up of the internal teams and resources of data architects and data analysts.\n\nMain Responsabilities:\n• Developing and implementing an overall organizational data strategy in line with business processes. The strategy includes data model designs, database development standards, implementation and management of data warehouses and data analytics systems.\n• Identifying data sources, both internal and external, and working out a plan for data management that is aligned with organizational data strategy.\n• Coordinating and collaborating with cross-functional teams, stakeholders, and vendors for the smooth functioning of the enterprise data system.\n• Managing end-to-end data architecture, from selecting the platform, designing the technical architecture, and developing the application to finally testing and implementing the proposed solution.\n• Planning and execution of big data solutions using appropriate technologies and ensure their full lifecycle and interoperability.\n• Defining and managing the flow of data and dissemination of information within the organization.\n• Integrating technical functionality, ensuring data accessibility, accuracy, and security.\n• Conducting a continuous audit of data management system performance, refine whenever required, and report immediately any breach or loopholes to the stakeholders.\n\nWHAT ARE WE LOOKING FOR?\n• Master's degree in computer science or equivalent work experience\n• Minimum of 10 years of experience in IT systems design or development.\n• Minimum 5 years of experience gained in data architecture and delivering large scale analytics data platforms environments.\n• Knowledge of systems development, including system development life cycle, project management approaches and requirements, design and testing techniques\n• Proven experience in design and building data models, data domains and understanding business data products (proficiency in data modeling and design, including SQL development and database administration).\n• Understanding of predictive modeling, AI models and technologies, Data mining, visualization and Machine Learning\n• Ability to implement common data management ...
#     'job_highlights': [{'items': ["CEVA Logistics provides global supply chain solutions to connect people, products and providers all around the world. Present in 170 countries and with more than 110,000 employees spread over 1,300 sites, we are well on our way to achieving our vision: to be a Top 5 global 3PL.\n\nWe believe that our employees are the key to our success. We want to engage and empower our diverse, global team to co-create value with our customers through our solutions in contract logistics and air, ocean, ground, and finished vehicle transport. That is why CEVA Logistics offers a dynamic and exceptional work environment that fosters personal growth, innovation, and continuous improvement.\n\nDARE TO GROW! Join CEVA Logistics, and you will be part of a team that values imagination, encourages boldness and exemplarity, and is committed to excellence in everything we do. Join us in our mission to shape the future of global logistics as we become a global leader in the logistics industry. As we continue... growing at a fast pace, will you “Dare to Grow” with us?\n\nYOUR ROLE\n\nDATA FACTORY MANAGER / SENIOR DATA ARCHITECT\n\nBased in France (Marseille or Puteaux).\n\nWHAT ARE YOU GOING TO DO?\n\nThe Senior Data Architect will join the Global IT Data and Digital organization at CEVA Logistics within the Global CIO organization and will report to the Head of the CEVA Global Data Factory.\n\nThis role operates in complex decision-making environments impacting the CEVA enterprise, works with senior management from IT, BD and Operations to ensure the best possible global solutions are available for our customers and CEVA employees alike.\n\nThe data architect will operate in the context of the set of the new Cloud Data Platform of CEVA and will contribute to its set up, development and growth and built up of the internal teams and resources of data architects and data analysts.\n\nMain Responsabilities:\n• Developing and implementing an overall organizational data strategy in line with business processes. The strategy includes data model designs, database development standards, implementation and management of data warehouses and data analytics systems.\n• Identifying data sources, both internal and external, and working out a plan for data management that is aligned with organizational data strategy.\n• Coordinating and collaborating with cross-functional teams, stakeholders, and vendors for the smooth functioning of the enterprise data system.\n• Managing end-to-end data architecture, from selecting the platform, designing the technical architecture, and developing the application to finally testing and implementing the proposed solution.\n• Planning and execution of big data solutions using appropriate technologies and ensure their full lifecycle and interoperability.\n• Defining and managing the flow of data and dissemination of information within the organization.\n• Integrating technical functionality, ensuring data accessibility, accuracy, and security.\n• Conducting a continuous audit of data management system performance, refine whenever required, and report immediately any breach or loopholes to the stakeholders.\n\nWHAT ARE WE LOOKING FOR?\n• Master's degree in computer science or equivalent work experience\n• Minimum of 10 years of experience in IT systems design or development.\n• Minimum 5 years of experience gained in data architecture and delivering large scale analytics data platforms environments.\n• Knowledge of systems development, including system development life cycle, project management approaches and requirements, design and testing techniques\n• Proven experience in design and building data models, data domains and understanding business data products (proficiency in data modeling and design, including SQL development and database administration).\n• Understanding of predictive modeling, AI models and technologies, Data mining, visualization and Machine Learning\n• Ability to implement common  ...
#     'related_links': [{'link': 'http://www.cma-cgm.com/',
#       'text': 'cma-cgm.com'},
#      {'link': 'https://www.google.com/search?sca_esv=c3b077f30ef0887c&q=CMA+CGM&sa=X&ved=0ahUKEwih7PSNmv6DAxXaTDABHZu9AT4QmJACCNIM',
#       'text': 'See web results for CMA CGM'}],
#     'thumbnail': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTQE46Bo5zXhGQGPVvTRXtAVQwYDz6yx4hFo_Kc&s=0',
#     'extensions': ['2 days ago', 'Full-time'],
#     'detected_extensions': {'posted_at': '2 days ago',
#      'schedule_type': 'Full-time'},
#     'job_id': '...'},
#    {'title': 'Data Scientist (full time, all seniority levels) - QuantumBlack',
#     'company_name': 'McKinsey & Company',
#     'location': '  Paris, France   ',
#     'via': 'via McKinsey',
#     'description': "Who You'll Work With\n\nBased in Paris and working across the region, as a consultant data scientist you will work closely with our clients, data engineers and all types of McKinsey consultants on interdisciplinary projects, using maths, stats and machine learning to derive structure and knowledge from raw data across various industry sectors.\n\nThis hybrid client-facing/technical role will allow you to use state of the art technologies to solve highly impactful business problems, whilst also leveraging your strong communication skills to convey complex intractable ideas to non-technical audiences.\n\nWho you are\n\nThis full time position is for a data scientist across all seniority levels with strong intrinsic technical ability and an aptitude to solving complex problems using technology.\n\nA core value at QuantumBlack is fusion and at the heart of our multi-disciplinary teams is the belief that the sum of individual parts will always be less than the impact of the entire team. You are a... highly collaborative individual who is capable of laying aside your own agenda, listening to and learning from colleagues, challenging thoughtfully and prioritizing impact. You search for ways to improve things and work collaboratively with colleagues. You believe in iterative change, experimenting with new approaches, learning and improving to move forward quickly. Trust between colleagues is paramount here – you are an individual who can always be trusted to work in the best interests of all colleagues and to achieve the best outcome for QuantumBlack and our clients. You are naturally enthusiastic and enjoy sharing your passion with others.\n\nWhat You'll Do\n\nAs a Data Scientist with the Paris office...\n\nYou will work in multi-disciplinary environments harnessing data to provide real-world impact for organisations globally.\n\nYou will influence many of the recommendations our clients need to positively change their businesses and enhance performance.\n\nRole responsibilities\n• Work on complex and extremely varied data sets from some of the world’s largest organisations to solve real world problems\n• Develop data science products and solutions for clients as well as for our data science team\n• Write highly optimized code to advance our internal Data Science Toolbox\n• Work in a multi-disciplinary environment with specialists in machine learning, engineering and design\n• Add real-world impact to your academic expertise, as you are encouraged to write ‘black’ papers and present at meetings and conferences should you wish\n• Attend conferences such as NIPS and ICML as one global team as well as Data Science retrospectives where you will have the opportunity to share and learn from your co-workers.\n• Work within one of the largest and most advanced data science teams in Europe, support the Lead Data Scientists to develop data science products\n\nWhat you’ll learn\n• How successful projections on real world problems across a variety of industries are completed through referencing past deliveries of end to end machine learning pipelines\n• Build products alongside the core engineering team and evolve the engineering process to scale with data, handling complex problems and advanced client situations\n• Be able to focus on modelling by working alongside the Data Engineering team which focuses on the wrangling, clean-up and transformation of data.\n• Best practices in software development and productionise machine learning by working with our Machine Learning Engineering teams which optimise code for model development and scale it\n• Work with our UX and Visual Design teams to interpret your complex models into stunning and user-focused visualisations\n• Using new technologies and problem-solving skills in a multicultural and creative environment\n\nYou will work on the frameworks and libraries that our teams of Data Scientists and Data Engineers use to progress from data to impact. You will guide global companies ...
# ...
#     'job_highlights': [{'items': ['Foxintelligence recherche un Business Data Analyst pour rejoindre le pôle Digital Services de l’équipe Digital & New Verticals, responsable de l’intégralité du dataflow sur nos verticales digitales (food delivery et ride sharing), du lancement de nouvelles industries innovantes telles que le gaming, le Buy-Now-Pay-Later ou le Travel, et de l’expansion de ces industries dans de nouveaux pays dans le cadre de notre expansion internationale (Canada, Australie, Japon, Kenya, etc).\n\nTes responsabilités au quotidien:\n\nExpertise industrielle et gestion de partenariats stratégiques:\n• Devenir l’expert de la donnée en comprenant les enjeux business sur nos deux verticales historiques chez Foxintelligence: la food delivery et le ride-sharing\n• Étendre des partenariats stratégiques avec nos clients globaux sur ces industries, en comprenant leurs besoins et en fournissant des analyses et insights pertinents.\n• Contribuer à l’expansion internationale de Foxintelligence en lançant ces industries... dans de nouveaux pays sur les 5 continents.\n\nLancement de nouveaux produits et développement de nouveaux enrichissements de données\n• Participer activement au lancement de nouveaux produits sur ces industries, que ce soit via Tableau, la construction d’applications SaaS natives, ou d’autres méthodes innovantes (par exemple des Data Clean Rooms)\n• Contribuer au développement de nouveaux enrichissements de données pour accroitre la valeur de nos datasets, par exemple, l’identification de programmes d’abonnement et de fidélité tels que Deliveroo Plus\n\nOptimisation des process et résolution des problématiques clients\n• Optimiser et automatiser les process de l’équipe pour accroître notre productivité globale\n• Répondre efficacement aux problématiques de nos clients tout en assurant la qualité de nos données, en étroite collaboration avec le pôle DataOps de notre équipe pour mettre en oeuvre des solutions appropriées et durables\n\nProjets stratégiques:\n• Travailler sur des projets data à fort potentiel stratégique et commercial, qui pourront avoir un impact sur d’autres industries, tels que le redressement et l’extrapolation de notre panel']}],
#     'related_links': [{'link': 'https://www.google.com/search?sca_esv=602026177&hl=en&q=Foxintelligence&sa=X&ved=0ahUKEwj0_badmv6DAxXNrJUCHTBJA6Y48AEQmJACCPUO',
#       'text': 'See web results for Foxintelligence'}],
#     'thumbnail': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQA42AGuq6pAQsZOLrUeykrJAsiXb8TCFZZJACAhM8&s',
#     'extensions': ['4 days ago', 'Full-time'],
#     'detected_extensions': {'posted_at': '4 days ago',
#      'schedule_type': 'Full-time'},
#     'job_id': '...'}],
#   'chips': [{'type': 'Title',
#     'param': 'job_family_1',
#     'options': [{'text': 'All'},
#      {'text': 'Data analyst', 'value': 'data analyst'},
#      {'text': 'Data scientist', 'value': 'data scientist'},
#      {'text': 'Data engineer', 'value': 'data engineer'},
#      {'text': 'Software engineer', 'value': 'software engineer'},
#      {'text': 'Data architect', 'value': 'data architect'},
#      {'text': 'Data manager', 'value': 'data manager'},
#      {'text': 'Product owner', 'value': 'product owner'},
#      {'text': 'Data science', 'value': 'data science'},
#      {'text': 'Manager', 'value': 'manager'},
#      {'text': 'Analyst', 'value': 'analyst'},
#      {'text': 'Master', 'value': 'master'},
#      {'text': 'Project manager', 'value': 'project manager'},
#      {'text': 'Protection officer', 'value': 'protection officer'},
#      {'text': 'Specialist', 'value': 'specialist'},
#      {'text': 'Business analyst', 'value': 'business analyst'},
#      {'text': 'Engineer', 'value': 'engineer'},
#      {'text': 'Entry specialist', 'value': 'entry specialist'},
#      {'text': 'Integration specialist', 'value': 'integration specialist'},
#      {'text': 'Marketing manager', 'value': 'marketing manager'},
#      {'text': 'Officer', 'value': 'officer'},
#      {'text': 'Senior', 'value': 'senior'},
#      {'text': 'Software engineers', 'value': 'software engineers'},
#      {'text': 'Solutions architect', 'value': 'solutions architect'},
#      {'text': 'Adjunct', 'value': 'adjunct'},
#      {'text': 'Analysis manager', 'value': 'analysis manager'},
#      {'text': 'Architect', 'value': 'architect'},
#      {'text': 'Associate director', 'value': 'associate director'},
#      {'text': 'Associate professor', 'value': 'associate professor'},
#      {'text': 'Business', 'value': 'business'},
#      {'text': 'Chef', 'value': 'chef'},
#      {'text': 'Consultant', 'value': 'consultant'},
#      {'text': 'Customer', 'value': 'customer'},
#      {'text': 'Data center', 'value': 'data center'},
#      {'text': 'Data engineering', 'value': 'data engineering'},
#      {'text': 'Data modeler', 'value': 'data modeler'},
#      {'text': 'Designer', 'value': 'designer'},
#      {'text': 'Development associate', 'value': 'development associate'},
#      {'text': 'Development engineer', 'value': 'development engineer'},
#      {'text': 'Head', 'value': 'head'},
#      {'text': 'Infrastructure', 'value': 'infrastructure'},
#      {'text': 'Integration analyst', 'value': 'integration analyst'},
#      {'text': 'Integrator', 'value': 'integrator'},
#      {'text': 'Investor relations', 'value': 'investor relations'},
#      {'text': 'Management engineer', 'value': 'management engineer'},
#      {'text': 'Modeling', 'value': 'modeling'},
#      {'text': 'No experience', 'value': 'no experience'},
#      {'text': 'Ops engineer', 'value': 'ops engineer'},
#      {'text': 'Principal', 'value': 'principal'},
#      {'text': 'Product manager', 'value': 'product manager'},
#      {'text': 'Protection specialist', 'value': 'protection specialist'},
#      {'text': 'Sales manager', 'value': 'sales manager'},
#      {'text': 'Security officer', 'value': 'security officer'}]},
#    {'type': 'Location',
#     'param': 'city',
#     'options': [{'text': 'All'},
#      {'text': 'Paris', 'value': 'D7fiBh9u5kdglIxow4ILBA=='},
#      {'text': 'Puteaux', 'value': 'xfUaLBpl5kfgyvJ51T872A=='},
#      {'text': 'Courbevoie', 'value': 'vccvsApl5kcQPotow4ILBA=='},
#      {'text': 'Lyon', 'value': 'l4foalHq9EfwIbvkKqsIBA=='},
#      {'text': 'Marseille', 'value': 'M1PaREO_yRIgApf9pRkIBA=='},
#      {'text': 'Boulogne-Billancourt', 'value': 'YUevEOh65keQPotow4ILBA=='},
#      {'text': 'Lille', 'value': 'EW4ls3nVwkdgY2SBPvEKBA=='},
#      {'text': 'Saint-Ouen-sur-Seine', 'value': 'Dak3HeRu5keQOotow4ILBA=='},
#      {'text': 'Antibes', 'value': 'qZFankXVzRKwn5f9pRkIBA=='},
#      {'text': 'Bordeaux', 'value': 'gcpR9-gnVQ2Jejl7A4ZjeQ=='},
#      {'text': 'Issy-les-Moulineaux', 'value': 'xy7Ltot65kehJ24ad9Amiw=='},
#      {'text': 'Marcoussis', 'value': '6cJ33_rW5UewRItow4ILBA=='},
#      {'text': 'Nanterre', 'value': 'vyXf2YRk5kfiR8FqHO4hew=='},
#      {'text': 'Pantin', 'value': 'Tx1XZ1Fs5kcQO4tow4ILBA=='},
#      {'text': 'Rouen', 'value': 'q_pxynbe4EfWk5-k76scPQ=='},
#      {'text': 'Toulouse', 'value': '_1J17G-7rhIwEEEvnPYGBA=='},
#      {'text': 'Us', 'value': 'kymq1B_y5kegLItow4ILBA=='},
#      {'text': 'Aimargues', 'value': 'HwAKlPqcthJASGsWIYgHBA=='},
#      {'text': 'Aix-en-Provence', 'value': 'WRK5BKONyRKjiLbIvlO5XA=='},
#      {'text': 'Antony', 'value': 'f8cFRhF35kfQPotow4ILBA=='},
#      {'text': 'Brest', 'value': 'k1uS2eG7FkirMJwXWINIxg=='},
#      {'text': 'Castelnau-le-Lez', 'value': 'HQWWl_ClthKAy2oWIYgHBA=='},
#      {'text': 'Eus', 'value': 'GQzYVW79rxKAa2cWIYgHBA=='},
#      {'text': 'Flexanville', 'value': '3UbS8Kai5kdl_yqOJ54iFQ=='},
#      {'text': 'Gouvieux', 'value': '94RmtplI5kei5arRQI9M9w=='},
#      {'text': 'Grenoble', 'value': 'b76J1ov0ikeYU5luzRCMYQ=='},
#      {'text': 'Le Havre', 'value': 'fYshlSMv4EcSrzOveobBWw=='},
#      {'text': 'Le Kremlin-Bicêtre', 'value': 'J2GTmHtx5kfgOItow4ILBA=='},
#      {'text': 'Marcq-en-Barœul', 'value': '33qpSSkqw0fW9h2_4l56qA=='},
#      {'text': "Marcy-l'Étoile", 'value': 'N5AHaWLt9Ecxeosz3RNYWg=='},
#      {'text': 'Metz', 'value': 'qbZ0YBvclEdpprs1tuRrWQ=='},
#      {'text': 'Montluel', 'value': 'J8lL4-a59EdOgK_m_0aGLg=='},
#      {'text': 'Montpellier', 'value': 'sZ3dJQevthIC6JQodFaHrQ=='},
#      {'text': 'Muret', 'value': 'saEjLYPJrhIwGkEvnPYGBA=='},
#      {'text': 'Nancy', 'value': 'zZKmF26YlEeNSYINsXHWTg=='},
#      {'text': 'Neuilly-sur-Seine', 'value': 'tZbjc2Nl5keXszL1nHU53A=='},
#      {'text': 'Nice', 'value': 'MS2FahDQzRJwmpf9pRkIBA=='},
#      {'text': 'Noidan', 'value': 'k9iViLgK8kfQShSzNM4JBA=='},
#      {'text': 'Orléans', 'value': '44bzndTk5EcpgMN55H25ng=='},
#      {'text': 'Plaisir', 'value': 'WbDBoOOE5keKBv1FsRhu8g=='},
#      {'text': 'Poissy', 'value': '42Xt3UeJ5kegOYxow4ILBA=='},
#      {'text': 'Pontoise', 'value': 'FbdRhm715kfY6aanU1egIA=='},
#      {'text': 'Rennes', 'value': 'hZDWpy_eDkgwq-Q2zaUMBA=='},
#      {'text': 'Rueil-Malmaison', 'value': 'K4enU1pj5kcgPYtow4ILBA=='},
#      {'text': 'Réau', 'value': 'SVWdk1f75UewToxow4ILBA=='},
#      {'text': 'Saint-Denis', 'value': 'YW0056pu5kcN6Sj5uuvvxw=='},
#      {'text': 'Saint-Maurice-Crillat', 'value': 'gTbIvjPkjEfARBKzNM4JBA=='},
#      {'text': 'Saint-Ouen', 'value': 'q4o-Euxr40cAHTgF18gNBA=='},
#      {'text': 'Surgères', 'value': 'wxRGpFEuAUggju5gktMFBA=='},
#      {'text': 'Villeurbanne', 'value': 'ryN2zS_A9EdSJlslKwy6ww=='},
#      {'text': 'Évry-Courcouronnes', 'value': 'D4p2DBne5UeYqgg1R6bxkw=='}]},
#    {'type': 'Date posted',
#     'param': 'date_posted',
#     'options': [{'text': 'All'},
#      {'text': 'Past day', 'value': 'today'},
#      {'text': 'Past 3 days', 'value': '3days'},
#      {'text': 'Past week', 'value': 'week'},
#      {'text': 'Past month', 'value': 'month'}]},
#    {'type': 'Requirements',
#     'param': 'requirements',
#     'options': [{'text': 'All'},
#      {'text': 'No degree', 'value': 'no_degree'},
#      {'text': 'No experience', 'value': 'no_experience'},
#      {'text': 'Under 3 years of experience', 'value': 'years3under'},
#      {'text': '3+ years of experience', 'value': 'years3plus'}]},
#    {'type': 'Language',
#     'param': 'language',
#     'options': [{'text': 'All'},
#      {'text': 'English Results', 'value': 'en'},
#      {'text': 'French Results', 'value': 'fr'}]},
#    {'type': 'Type',
#     'param': 'employment_type',
#     'options': [{'text': 'All'},
#      {'text': 'Full-time', 'value': 'FULLTIME'},
#      {'text': 'Internship', 'value': 'INTERN'},
#      {'text': 'Part-time', 'value': 'PARTTIME'},
#      {'text': 'Contractor', 'value': 'CONTRACTOR'}]},
#    {'type': 'Company type',
#     'param': 'industry.id',
#     'options': [{'text': 'All'},
#      {'text': 'Finance', 'value': '/business/naics2007/52'},
#      {'text': 'Information', 'value': '/business/naics2007/51'},
#      {'text': 'Manufacturing', 'value': '/business/naics2007/31'},
#      {'text': 'Computer Services', 'value': '/business/naics2007/5415'},
#      {'text': 'Logistics', 'value': '/business/naics2007/48'},
#      {'text': 'Consulting', 'value': '/business/naics2007/5416'},
#      {'text': 'Education', 'value': '/business/naics2007/61'},
#      {'text': 'Retail', 'value': '/business/naics2007/44'},
#      {'text': 'Engineering Services', 'value': '/business/naics2007/5413'},
#      {'text': 'Mining', 'value': '/business/naics2007/21'},
#      {'text': 'Utilities', 'value': '/business/naics2007/22'},
#      {'text': 'Toiletries', 'value': '/business/naics2007/3256'},
#      {'text': 'Research', 'value': '/business/naics2007/5417'},
#      {'text': 'Accommodation', 'value': '/business/naics2007/721'},
#      {'text': 'Accounting', 'value': '/business/naics2007/5412'},
#      {'text': 'Advertising', 'value': '/business/naics2007/5418'},
#      {'text': 'Construction', 'value': '/business/naics2007/23'},
#      {'text': 'Design Services', 'value': '/business/naics2007/5414'},
#      {'text': 'Foods & Beverages', 'value': '/business/naics2007/311'},
#      {'text': 'Personal Services', 'value': '/business/naics2007/8129'},
#      {'text': 'Staffing', 'value': '/business/naics2007/5613'},
#      {'text': 'Textiles & Apparel', 'value': '/business/naics2007/313'}]},
#    {'type': 'Employer',
#     'param': 'organization_mid',
#     'options': [{'text': 'All'},
#      {'text': 'AXA', 'value': '/m/04mn99'},
#      {'text': 'Alstom', 'value': '/m/011wfk'},
#      {'text': 'CMA CGM', 'value': '/m/0650jn'},
#      {'text': 'Dataiku', 'value': '/g/11bzyqdcsn'},
#      {'text': 'Mars', 'value': '/m/01kh5q'},
#      {'text': 'Back Market', 'value': '/g/11fy4vgk2d'},
#      {'text': 'ENGIE', 'value': '/m/04f7b89'},
#      {'text': 'Foxintelligence', 'value': '/g/11h31zbmrs'},
#      {'text': 'Kering', 'value': '/g/11cs19nq3t'},
#      {'text': 'Shift Technology', 'value': '/g/11h_q0qhfh'},
#      {'text': 'Akeneo', 'value': '/g/11bwdhgjb4'},
#      {'text': 'BNP Paribas', 'value': '/m/02qhk4'},
#      {'text': 'BlaBlaCar', 'value': '/g/11b5v2gkf7'},
#      {'text': 'Cognizant Technology Solutions', 'value': '/m/03bf9h'},
#      {'text': 'Datadog', 'value': '/m/0wfvvyq'},
#      {'text': 'Deel', 'value': '/g/11p67fg1nx'},
#      {'text': 'Enel X', 'value': '/m/02x39d1'},
#      {'text': 'Gameloft', 'value': '/m/064f29'},
#      {'text': 'IÉSEG School of Management', 'value': '/m/0286cqy'},
#      {'text': 'Ledger', 'value': '/g/11hzgkwqj0'},
#      {'text': 'MP DATA', 'value': '/g/11f086468m'},
#      {'text': 'PayFit', 'value': '/g/11cn6hxjbs'},
#      {'text': 'PayPal', 'value': '/g/122s91_5'},
#      {'text': 'Pernod Ricard', 'value': '/m/031vfd'},
#      {'text': 'Pleo', 'value': '/g/11fy28l36y'},
#      {'text': 'Publicis Sapient', 'value': '/m/02myjp'},
#      {'text': 'Sanofi', 'value': '/m/02qsg_'},
#      {'text': 'Volvo Group', 'value': '/m/07yw2'},
#      {'text': '2780 Avions de Transport Regional (ATR) GIE',
#       'value': '/m/01l2_v'},
#      {'text': '3507 Airbus Operations SAS', 'value': '/m/015zfz'},
#      {'text': 'ALTEN', 'value': '/m/05q4lgq'},
#      {'text': 'ARDIAN', 'value': '/m/0dj6l2'},
#      {'text': 'Accor', 'value': '/m/0496mw'},
#      {'text': 'Acryl Data', 'value': '/g/11nwb483gm'}]}]},
#  {'search_metadata': {'id': '65b54c51eb690f295efa4685',
#    'status': 'Success',
#    'json_endpoint': 'https://serpapi.com/searches/01e4b7b1c535b9ea/65b54c51eb690f295efa4685.json',
#    'created_at': '2024-01-27 18:32:49 UTC',
#    'processed_at': '2024-01-27 18:32:49 UTC',
#    'google_jobs_url': 'https://www.google.com/search?q=Data&ibp=htl;jobs&uule=w+CAIQICIGRnJhbmNl&hl=en&start=260',
#    'raw_html_file': 'https://serpapi.com/searches/01e4b7b1c535b9ea/65b54c51eb690f295efa4685.html',
#    'total_time_taken': 2.71},
#   'search_parameters': {'q': 'Data',
#    'engine': 'google_jobs',
#    'location_requested': 'France',
#    'location_used': 'France',
#    'google_domain': 'google.com',
#    'hl': 'en',
#    'start': 260},
#   'search_information': {'jobs_results_state': 'Fully empty'},
#   'error': "Google hasn't returned any results for this query."}]

# %%
import requests

payload = { 'api_key': '02c61b750bca71883a0e8dbb30c630b0', 'url': 'https://serpapi.com/search.json' }
r = requests.get('https://api.scraperapi.com/', params=payload)
print(r.text)

# %%
import re

def extract_job_info(jobs_results):
    """
    Extrait les informations d'une liste d'offres d'emploi à partir de données JSON.

    :param jobs_results: Liste de dictionnaires contenant les données des emplois.
    :return: Liste de dictionnaires avec les informations extraites pour chaque emploi.
    """
    extracted_jobs = []
    for job_data in jobs_results:
        job_info = {
            "title": job_data.get("title", "N/A"),
            "company_name": job_data.get("company_name", "N/A"),
            "location": job_data.get("location", "N/A").strip(),
            "experience": extract_experience(job_data.get("description", "")),
            "technical_skills": extract_technical_skills(job_data.get("description", ""))
        }
        extracted_jobs.append(job_info)
    return extracted_jobs

def extract_experience(description):
    """
    Extrait l'expérience requise à partir de la description de l'emploi.

    :param description: La description de l'emploi.
    :return: Expérience requise (sous forme de texte).
    """
    experience_patterns = [
        r'(\d+ ans d’expérience)',
        r'expérience de (\d+ ans)',
        r'expérience d’au moins (\d+ ans)'
    ]
    for pattern in experience_patterns:
        match = re.search(pattern, description)
        if match:
            return match.group(0)
    return "Non spécifié"

def extract_technical_skills(description):
    """
    Extrait les compétences techniques de la description de l'emploi.

    :param description: La description de l'emploi.
    :return: Liste des compétences techniques.
    """
    # Liste des compétences techniques courantes à rechercher
    skills = [
    "Python", "R", "SQL", "Excel", "Tableau", "PowerBI", "Dataiku", "Snowflake",
    "GCP", "AWS", "AZURE", "Databricks", "Talend", "Spark", "Scala", "Dataiku",
    "Airflow", "S3", "Kafka", "Hadoop", "SQL", "NoSQL", "Cassandra", "MongoDB",
    "ELK", "Git", "Kubernetes", "Docker", "OVH", "Kanban", "Jira", "Jenkins",
    "ElasticSearch", "Linus", "Kibana", "LogStash", "keras", "Tensorflow", "Gitlab",
    "Snowflake", "NLP", "Random Forest", "XGBoost", "SQL Server", "Oracle", "LLM",
    "IA generative", "generative AI", "GPT", "Terraform", "Yolo", "Pytorch",
    "Transformers", "scikit-learn", "pySpark", "Pyspark", "PySpark", "SAS", "scipy",
    "Azure Data Factory", "Java", "VBA", "Matplotlib", "Seaborn", "Pandas",
    "NumPy", "SciKit-Learn", "Streamlit", "Dash", "Shiny", "Flask", "Django",
    "BigQuery", "Redshift", "PostgreSQL", "MySQL", "DB2", "SQLite", "MLflow",
    "Plotly", "Bokeh", "D3.js", "GraphQL", "REST API", "Microservices"
]


    found_skills = []
    for skill in skills:
        if skill.lower() in description.lower():
            found_skills.append(skill)
    return found_skills if found_skills else ["Non spécifié"]

# %%
import pandas as pd
from google.colab import files

def extract_job_info(complete_data):
    """
    Extrait les informations de toutes les offres d'emploi dans la structure de données complète.

    :param complete_data: Liste de dictionnaires contenant les métadonnées de recherche et les résultats des emplois.
    :return: Liste de dictionnaires avec les informations extraites pour chaque emploi.
    """
    all_job_infos = []
    for data in complete_data:
        jobs_results = data.get('jobs_results', [])
        for job_data in jobs_results:
            job_info = {
                "title": job_data.get("title", "N/A"),
                "company_name": job_data.get("company_name", "N/A"),
                "location": job_data.get("location", "N/A").strip(),
                "experience": extract_experience(job_data.get("description", "")),
                "technical_skills": extract_technical_skills(job_data.get("description", ""))
            }
            all_job_infos.append(job_info)
            print(job_info)
    return all_job_infos


# Exemple d'utilisation
extracted_job_infos = extract_job_info(complete_data)
# Création d'un DataFrame à partir de la liste des offres d'emploi
df = pd.DataFrame(extracted_job_infos)
# Sauvegarde du DataFrame dans un fichier CSV
df.to_csv("google_jobs_data.csv", index=False)


files.download('google_jobs_data.csv')
# Out:
# {'title': 'Job offer Data Scientist / Quant Research Analyst W/M - BNP Paribas', 'company_name': 'BNP Paribas', 'location': 'France', 'experience': 'Non spécifié', 'technical_skills': ['Python', 'R']}
# {'title': 'Product Owner for Data Referentials', 'company_name': 'AXA Group', 'location': 'Puteaux, France', 'experience': 'Non spécifié', 'technical_skills': ['R', 'Excel', 'AZURE', 'Git', 'SAS']}
# {'title': 'Data Scientist', 'company_name': 'PUR', 'location': 'Paris, France', 'experience': 'Non spécifié', 'technical_skills': ['Python', 'R', 'SQL', 'SQL', 'Jira', 'keras', 'Tensorflow', 'XGBoost', 'scikit-learn', 'Matplotlib', 'Pandas', 'NumPy', 'SciKit-Learn', 'Dash']}
# {'title': 'UX designer, Data Products & Services', 'company_name': 'STELLANTIS', 'location': 'Anywhere', 'experience': 'Non spécifié', 'technical_skills': ['R', 'Excel', 'Scala', 'Git', 'Java']}
# {'title': 'Global Senior Data Architect', 'company_name': 'CMA CGM', 'location': 'Marseille, France', 'experience': 'Non spécifié', 'technical_skills': ['R', 'SQL', 'Excel', 'Snowflake', 'AWS', 'SQL', 'NoSQL', 'Git', 'Snowflake']}
# {'title': 'Data Scientist (full time, all seniority levels) - QuantumBlack', 'company_name': 'McKinsey & Company', 'location': 'Paris, France', 'experience': 'Non spécifié', 'technical_skills': ['Python', 'R', 'SQL', 'Excel', 'SQL']}
# {'title': 'Data Engineer', 'company_name': 'MSX International', 'location': 'Nanterre, France', 'experience': 'Non spécifié', 'technical_skills': ['R', 'SQL', 'Excel', 'Tableau', 'PowerBI', 'AZURE', 'SQL', 'SQL Server']}
# {'title': 'Data Scientist', 'company_name': 'Back Market', 'location': 'Paris, France', 'experience': 'Non spécifié', 'technical_skills': ['Python', 'R', 'LLM', 'generative AI']}
# {'title': 'Data Scientist / Data engineer (graduate)', 'company_name': 'Shift Technology', 'location': 'Paris, France', 'experience': 'Non spécifié', 'technical_skills': ['R', 'SQL', 'Excel', 'SQL', 'ElasticSearch']}
# {'title': 'ECT Data Analysis Manager', 'company_name': 'Boston Consulting Group', 'location': 'Paris, France', 'experience': 'Non spécifié', 'technical_skills': ['Python', 'R', 'SQL', 'Excel', 'Tableau', 'SQL', 'Git', 'Dash']}
# {'title': 'Data Architect', 'company_name': 'K2 Partnering', 'location': 'France', 'experience': 'Non spécifié', 'technical_skills': ['R']}
# {'title': 'Data Scientist - Intern', 'company_name': 'Qlik', 'location': 'France', 'experience': 'Non spécifié', 'technical_skills': ['Python', 'R', 'Git', 'NLP', 'LLM']}
# {'title': 'Senior Data Scientist (H/F)', 'company_name': 'AZGROUPPROD', 'location': 'Hauts-de-Seine, France', 'experience': 'Non spécifié', 'technical_skills': ['Python', 'R', 'SQL', 'Spark', 'SQL', 'Git', 'NLP', 'pySpark', 'Pyspark', 'PySpark', 'PostgreSQL']}
# {'title': 'Architecte Talend Data Integration Senior (H/F)', 'company_name': 'Cognizant Technology Solutions', 'location': 'Paris, France', 'experience': 'Non spécifié', 'technical_skills': ['R', 'AZURE', 'Talend', 'Spark', 'Scala', 'Kafka', 'Hadoop', 'ELK', 'Git']}
# {'title': 'Client engagement Data Manager', 'company_name': 'Kering', 'location': 'Paris, France', 'experience': 'Non spécifié', 'technical_skills': ['R']}
# {'title': 'Data Modeler, Systematic Trading', 'company_name': 'Louis Dreyfus Company', 'location': 'Villeurbanne, France', 'experience': 'Non spécifié', 'technical_skills': ['Python', 'R', 'Excel', 'AZURE', 'Scala', 'Jenkins']}
# {'title': 'Data and Business Intelligence - Internship', 'company_name': 'Ledger', 'location': 'Paris, France', 'experience': 'Non spécifié', 'technical_skills': ['R']}
# {'title': 'Chief Data Officer', 'company_name': 'CXG', 'location': 'Paris, France', 'experience': 'Non spécifié', 'technical_skills': ['Python', 'R', 'SQL', 'Excel', 'Tableau', 'Snowflake', 'AWS', 'AZURE', 'Scala', 'SQL', 'Snowflake', 'LLM']}
# {'title': 'Investor Relations – Data Analyst – Internship', 'company_name': 'ARDIAN', 'location': 'Paris, France', 'experience': 'Non spécifié', 'technical_skills': ['Python', 'R', 'Excel', 'AWS']}
# {'title': 'Senior Marketing Data Analyst', 'company_name': 'Remote', 'location': 'Paris, France', 'experience': 'Non spécifié', 'technical_skills': ['R', 'SQL', 'SQL', 'Dash']}
# {'title': 'Data & Digital product owner M/F', 'company_name': 'Nestlé Operational Services Worldwide SA GTP', 'location': 'Issy-les-Moulineaux, France', 'experience': 'Non spécifié', 'technical_skills': ['R', 'Git']}
# {'title': 'Data Science Software Engineer', 'company_name': 'ORTEC', 'location': 'Paris, France', 'experience': 'Non spécifié', 'technical_skills': ['Python', 'R', 'SQL', 'Excel', 'AZURE', 'Databricks', 'SQL', 'NoSQL', 'Git', 'Java']}
# {'title': 'Data Integration Specialist', 'company_name': 'Sweep', 'location': 'Paris, France', 'experience': 'Non spécifié', 'technical_skills': ['Python', 'R', 'SQL', 'Excel', 'SQL']}
# {'title': 'Senior Data Scientist', 'company_name': 'Bigblue', 'location': 'Paris, France', 'experience': 'Non spécifié', 'technical_skills': ['Python', 'R', 'SQL', 'AZURE', 'SQL', 'LLM', 'Dash', 'BigQuery']}
# {'title': 'Intern, Data Engineering', 'company_name': 'DNA Script', 'location': 'Le Kremlin-Bicêtre, France', 'experience': 'Non spécifié', 'technical_skills': ['Python', 'R', 'SQL', 'Excel', 'PowerBI', 'AWS', 'SQL', 'Pandas', 'Dash', 'Flask', 'Django', 'PostgreSQL']}
# {'title': 'Data Analyst internship', 'company_name': 'PGBPGNGLOBAL', 'location': 'Paris, France', 'experience': 'Non spécifié', 'technical_skills': ['R', 'Excel']}
# {'title': 'CDI - Master Data Coordinator - NORTH AMERICA (W/M)', 'company_name': 'Sephora', 'location': 'Neuilly-sur-Seine, France', 'experience': 'Non spécifié', 'technical_skills': ['R', 'Excel']}
# {'title': 'Solution Engineer', 'company_name': 'Salesforce', 'location': 'Anywhere', 'experience': 'Non spécifié', 'technical_skills': ['Python', 'R', 'Tableau', 'Snowflake', 'Databricks', 'Scala', 'Snowflake', 'Pandas', 'Redshift']}
# {'title': 'Chief Data Officer', 'company_name': 'CXG', 'location': 'Paris, France', 'experience': 'Non spécifié', 'technical_skills': ['Python', 'R', 'SQL', 'Excel', 'Tableau', 'Snowflake', 'AWS', 'AZURE', 'Scala', 'SQL', 'Snowflake', 'LLM']}
# {'title': 'Product Data Scientist Intern', 'company_name': 'Criteo', 'location': 'Paris, France', 'experience': 'Non spécifié', 'technical_skills': ['Python', 'R', 'SQL', 'Excel', 'Scala', 'SQL', 'Git', 'Dash']}
# {'title': 'Senior Data Engineer', 'company_name': 'Infinit', 'location': 'Paris, France', 'experience': 'Non spécifié', 'technical_skills': ['Python', 'R', 'SQL', 'Excel', 'Scala', 'SQL']}
# {'title': 'Internship - AI & Data Science (Large Language Model)', 'company_name': 'CAST', 'location': 'Anywhere', 'experience': 'Non spécifié', 'technical_skills': ['Python', 'R', 'Excel', 'AWS', 'NLP', 'LLM', 'GPT']}
# {'title': 'Backend Software Engineer (blockchain data)', 'company_name': 'Cryptio', 'location': 'France', 'experience': 'Non spécifié', 'technical_skills': ['R', 'SQL', 'SQL', 'PostgreSQL']}
# {'title': 'Junior Data Analyst - Data Marketing', 'company_name': 'BlaBlaCar', 'location': 'Anywhere', 'experience': 'Non spécifié', 'technical_skills': ['Python', 'R', 'SQL', 'Excel', 'Tableau', 'Airflow', 'SQL', 'Dash', 'BigQuery']}
# {'title': 'Data Protection Officer, AXA DCP', 'company_name': 'AXA Group', 'location': 'Paris, France   (+8 others)', 'experience': 'Non spécifié', 'technical_skills': ['R', 'Excel', 'AWS', 'Git']}
# {'title': 'Data Analyste F/H', 'company_name': 'Enel X', 'location': 'France  (+1 other)', 'experience': 'Non spécifié', 'technical_skills': ['R']}
# {'title': 'Data Architect', 'company_name': 'Alstom', 'location': 'Saint-Ouen-sur-Seine, France', 'experience': 'Non spécifié', 'technical_skills': ['Python', 'R', 'SQL', 'AWS', 'AZURE', 'Scala', 'SQL', 'NoSQL', 'Git', 'Kubernetes', 'ElasticSearch', 'Java']}
# {'title': 'Senior Big Data Engineer', 'company_name': '1047 Amadeus S.A.S. (Nice)', 'location': 'Anywhere', 'experience': 'Non spécifié', 'technical_skills': ['R', 'Spark', 'Scala', 'Kafka', 'Hadoop']}
# {'title': 'Data Steward', 'company_name': 'Ubisoft', 'location': 'Anywhere', 'experience': 'Non spécifié', 'technical_skills': ['R', 'SAS']}
# {'title': 'Data Scientist', 'company_name': 'Descartes Underwriting Old', 'location': 'Puteaux, France', 'experience': 'Non spécifié', 'technical_skills': ['Python', 'R', 'Excel', 'AWS', 'scikit-learn', 'SAS', 'SciKit-Learn']}
# {'title': 'CHEF DE PROJECT FORECASTING', 'company_name': 'Eni', 'location': 'Paris, France', 'experience': 'Non spécifié', 'technical_skills': ['Python', 'R', 'SQL', 'Excel', 'SQL', 'keras', 'Tensorflow', 'scikit-learn', 'Pandas', 'NumPy', 'SciKit-Learn']}
# {'title': 'Senior Manager Data Strategist (H/F)', 'company_name': 'Publicis Sapient', 'location': 'Paris, France', 'experience': 'Non spécifié', 'technical_skills': ['R']}
# {'title': 'CHAIR OF EXCELLENCE - Multiomics Methodologies and Data...', 'company_name': 'University of Rouen Normandy', 'location': 'Rouen, France', 'experience': 'Non spécifié', 'technical_skills': ['R', 'Excel']}
# {'title': 'Data Center Infrastructure Lead – France H/F', 'company_name': 'DATA4 - Smart Data Centers at Scale', 'location': 'Marcoussis, France', 'experience': 'Non spécifié', 'technical_skills': ['R', 'Excel', 'Jira']}
# {'title': 'Software Engineers - Data Platform - France or Remote EMEA', 'company_name': 'Dataiku', 'location': 'Anywhere', 'experience': 'Non spécifié', 'technical_skills': ['Python', 'R', 'SQL', 'Excel', 'Dataiku', 'Snowflake', 'AWS', 'AZURE', 'Spark', 'Dataiku', 'S3', 'SQL', 'Git', 'Kubernetes', 'Snowflake', 'LLM', 'generative AI', 'GPT', 'Java', 'BigQuery', 'Redshift', 'REST API']}
# {'title': 'Data Scientist H/F', 'company_name': 'MP DATA', 'location': 'Boulogne-Billancourt, France', 'experience': 'Non spécifié', 'technical_skills': ['Python', 'R', 'Spark', 'Git', 'NLP', 'Transformers', 'pySpark', 'Pyspark', 'PySpark', 'MLflow']}
# {'title': 'Data Scientist - Payment Success', 'company_name': 'Checkout.com', 'location': 'France', 'experience': 'Non spécifié', 'technical_skills': ['Python', 'R', 'SQL', 'Databricks', 'Spark', 'Scala', 'SQL', 'Git', 'Dash']}
# {'title': 'Data Product Lead - Brand and Consumer', 'company_name': 'Mars', 'location': 'Aimargues, France', 'experience': 'Non spécifié', 'technical_skills': ['R', 'Excel', 'AZURE']}
# {'title': 'Senior Software Engineer - Data Reliability', 'company_name': 'Datadog', 'location': 'Paris, France', 'experience': 'Non spécifié', 'technical_skills': ['R', 'GCP', 'AWS', 'AZURE', 'Scala', 'Kafka', 'Cassandra', 'MongoDB', 'ElasticSearch', 'Java']}
# {'title': 'Data and Business Intelligence - Internship', 'company_name': 'Ledger', 'location': 'Paris, France', 'experience': 'Non spécifié', 'technical_skills': ['R', 'Tableau', 'Git', 'Jira']}
# {'title': 'Data Scientist Senior', 'company_name': 'Match Group', 'location': 'France', 'experience': '6 ans d’expérience', 'technical_skills': ['Python', 'R', 'SQL', 'Excel', 'Tableau', 'PowerBI', 'GCP', 'AWS', 'Spark', 'Scala', 'Hadoop', 'SQL', 'Tensorflow', 'Oracle', 'Pytorch', 'PostgreSQL']}
# {'title': 'Data Analyst (SQL Wizard)', 'company_name': 'Diamond Foundry', 'location': 'Anywhere', 'experience': 'Non spécifié', 'technical_skills': ['Python', 'R', 'SQL', 'Excel', 'Tableau', 'GCP', 'AWS', 'Scala', 'SQL', 'SAS', 'Java', 'Dash', 'BigQuery']}
# {'title': 'Remote Data Entry Specialist at The Elite Job', 'company_name': 'HR Admin', 'location': 'Anywhere', 'experience': 'Non spécifié', 'technical_skills': ['R', 'Excel']}
# {'title': 'Senior Data Engineer', 'company_name': 'PUR', 'location': 'Paris, France', 'experience': 'Non spécifié', 'technical_skills': ['Python', 'R', 'Snowflake', 'AZURE', 'Snowflake']}
# {'title': 'EMEA Data Center Technical Manager M/F', 'company_name': 'Carrier', 'location': 'Montluel, France', 'experience': 'Non spécifié', 'technical_skills': ['R', 'Excel']}
# {'title': 'Senior Specialist Solutions Architect - Data Warehousing', 'company_name': 'Databricks', 'location': 'Paris, France', 'experience': 'Non spécifié', 'technical_skills': ['Python', 'R', 'SQL', 'Excel', 'GCP', 'AWS', 'AZURE', 'Databricks', 'Spark', 'Scala', 'Kafka', 'Hadoop', 'SQL', 'NoSQL', 'Oracle', 'SAS', 'Java', 'MLflow']}
# {'title': 'Data analyst - apprenticeship/internship', 'company_name': 'PayFit', 'location': 'Paris, France', 'experience': 'Non spécifié', 'technical_skills': ['Python', 'R', 'SQL', 'Excel', 'Tableau', 'SQL', 'Dash']}
# {'title': 'DATA PROCESSOR GRADE II', 'company_name': 'Naurex Energy Recruitment', 'location': 'Eus, France', 'experience': 'Non spécifié', 'technical_skills': ['R']}
# {'title': 'Responsable Data et Pilotage TPE-PME (F/H)', 'company_name': 'Worldline', 'location': 'Courbevoie, France', 'experience': 'Non spécifié', 'technical_skills': ['R', 'Git', 'Dash']}
# {'title': 'Senior Software Development Engineer 2 (Data Analyst) (H/F)', 'company_name': 'Les Jeudis', 'location': 'Noidan, France', 'experience': 'Non spécifié', 'technical_skills': ['Python', 'R', 'SQL', 'Excel', 'Scala', 'SQL', 'Git', 'SAS', 'Java']}
# {'title': 'Senior Data Analyst - Marketing Analytics', 'company_name': 'Back Market', 'location': 'Paris, France', 'experience': 'Non spécifié', 'technical_skills': ['Python', 'R', 'SQL', 'SQL', 'Git']}
# {'title': "Data Architect- Modélisation d'objets métiers immobiliers et SPOT...", 'company_name': '3507 Airbus Operations SAS', 'location': 'Anywhere', 'experience': 'Non spécifié', 'technical_skills': ['R', 'Git', 'SAS']}
# {'title': 'Data Solutions Engineer / Software Engineer', 'company_name': 'Shift Technology', 'location': 'Paris, France', 'experience': 'Non spécifié', 'technical_skills': ['R', 'SQL', 'Excel', 'SQL', 'ElasticSearch']}
# {'title': 'Surveyor/Field Data Analyst', 'company_name': 'TSMG', 'location': 'Rouen, France', 'experience': 'Non spécifié', 'technical_skills': ['R', 'Excel']}
# {'title': 'Data Analyst w/m', 'company_name': 'DataDome', 'location': 'Paris, France', 'experience': 'Non spécifié', 'technical_skills': ['R', 'GCP', 'AWS', 'Scala', 'Kafka', 'Git', 'Docker', 'ElasticSearch', 'Kibana', 'Terraform', 'Java', 'Dash']}
# {'title': 'Data-Driven Control for Multivariable Systems', 'company_name': 'CRAN -CNRS UMR 7039', 'location': 'Nancy, France', 'experience': 'Non spécifié', 'technical_skills': ['R', 'Git']}
# {'title': 'CRM Data Engineer', 'company_name': 'Vestiaire Collective', 'location': 'Anywhere', 'experience': 'Non spécifié', 'technical_skills': ['Python', 'R', 'SQL', 'Excel', 'Tableau', 'AWS', 'Airflow', 'Kafka', 'Hadoop', 'SQL', 'NoSQL', 'Git']}
# {'title': 'Data Analyst Intern', 'company_name': 'Kering', 'location': 'Paris, France', 'experience': 'Non spécifié', 'technical_skills': ['R', 'SQL', 'Excel', 'Tableau', 'SQL']}
# {'title': 'Team Lead Data Software Engineer - Motion Planning', 'company_name': 'Motional', 'location': 'France', 'experience': 'Non spécifié', 'technical_skills': ['Python', 'R', 'SQL', 'AWS', 'Scala', 'SQL']}
# {'title': 'Associate Principal', 'company_name': 'IQVIA', 'location': 'Courbevoie, France', 'experience': 'Non spécifié', 'technical_skills': ['R', 'Excel', 'AWS']}
# {'title': 'Software Engineers - Data Platform - France Or Remote EMEA H/F', 'company_name': 'Dataiku', 'location': 'Anywhere', 'experience': 'Non spécifié', 'technical_skills': ['Python', 'R', 'SQL', 'Excel', 'Dataiku', 'Snowflake', 'AWS', 'AZURE', 'Spark', 'Dataiku', 'S3', 'SQL', 'Git', 'Kubernetes', 'Snowflake', 'LLM', 'generative AI', 'GPT', 'Java', 'BigQuery', 'Redshift', 'REST API']}
# {'title': 'Data Ops Engineer', 'company_name': 'A2MAC1', 'location': 'Anywhere', 'experience': 'Non spécifié', 'technical_skills': ['R', 'SQL', 'AZURE', 'SQL', 'NoSQL', 'Kanban', 'SQL Server', 'MySQL']}
# {'title': 'Data Engineer (x/f/m)', 'company_name': 'Hublo', 'location': 'Paris, France', 'experience': 'Non spécifié', 'technical_skills': ['R', 'Scala']}
# {'title': 'Data Analyst (Internship)', 'company_name': 'Equativ', 'location': 'Paris, France', 'experience': 'Non spécifié', 'technical_skills': ['Python', 'R', 'SQL', 'Excel', 'Tableau', 'Snowflake', 'Airflow', 'SQL', 'Snowflake', 'Dash']}
# {'title': 'Data Integration Platforms Specialist H/F', 'company_name': '2788 Airbus Defence and Space SAS', 'location': 'Anywhere', 'experience': 'Non spécifié', 'technical_skills': ['Python', 'R', 'SQL', 'SQL', 'NoSQL', 'Git', 'SAS', 'Java', 'Flask']}
# {'title': 'Master Data Governance (MDG) Engagement Lead', 'company_name': 'Mars', 'location': 'Aimargues, France   (+2 others)', 'experience': 'Non spécifié', 'technical_skills': ['R', 'Git']}
# {'title': 'Product Marketing Manager - Data and AI', 'company_name': 'Canonical', 'location': 'Anywhere', 'experience': 'Non spécifié', 'technical_skills': ['R', 'Excel', 'Git']}
# {'title': 'Chef de projet data', 'company_name': 'Enel X', 'location': 'Île-de-France, France', 'experience': 'Non spécifié', 'technical_skills': ['R']}
# {'title': 'Post doc position: searching asteroid binaries in Gaia data...', 'company_name': 'Observatoire de la Côte d’Azur', 'location': 'Nice, France', 'experience': 'Non spécifié', 'technical_skills': ['R']}
# {'title': 'Support AQ - Data Integrity et SIA H/F (En intérim 12 mois)', 'company_name': 'BoehringerPRD', 'location': 'Toulouse, France', 'experience': 'Non spécifié', 'technical_skills': ['R', 'Excel', 'Git']}
# {'title': 'Senior Data Scientist', 'company_name': 'HR Admin', 'location': 'Anywhere', 'experience': 'Non spécifié', 'technical_skills': ['Python', 'R', 'SQL', 'Excel', 'Tableau', 'Spark', 'Hadoop', 'SQL', 'Java', 'Matplotlib']}
# {'title': 'Data Analyst (m/f/d)', 'company_name': 'Artefact', 'location': 'Paris, France', 'experience': 'Non spécifié', 'technical_skills': ['Python', 'R', 'SQL', 'Tableau', 'Dataiku', 'AWS', 'AZURE', 'Dataiku', 'Airflow', 'SQL', 'Git', 'Dash', 'Shiny', 'Flask']}
# {'title': 'Partner Sales Manager - 28421', 'company_name': 'Splunk', 'location': 'Paris, France', 'experience': 'Non spécifié', 'technical_skills': ['R', 'Excel', 'AWS', 'Git']}
# {'title': 'Head of Data Science', 'company_name': 'ALPHA10X', 'location': 'Aix-en-Provence, France', 'experience': 'Non spécifié', 'technical_skills': ['Python', 'R', 'Excel', 'AZURE', 'NLP']}
# {'title': 'Climate Data Analyst', 'company_name': 'The Aga Khan Academies', 'location': 'Gouvieux, France', 'experience': 'Non spécifié', 'technical_skills': ['Python', 'R', 'SQL', 'Excel', 'PowerBI', 'AZURE', 'SQL', 'Git', 'Azure Data Factory']}
# {'title': 'Confirmed Data Analyst - Data Capabilities', 'company_name': 'BlaBlaCar', 'location': 'Anywhere', 'experience': 'Non spécifié', 'technical_skills': ['R', 'SQL', 'Excel', 'Tableau', 'SQL', 'Dash']}
# {'title': 'eDiscovery Data Analyst', 'company_name': 'PayPal', 'location': 'Paris, France', 'experience': 'Non spécifié', 'technical_skills': ['R', 'SQL', 'Excel', 'SQL', 'Git']}
# {'title': 'Data Integration Platforms Specialist H/F', 'company_name': '2788 Airbus Defence and Space SAS', 'location': 'Anywhere', 'experience': 'Non spécifié', 'technical_skills': ['Python', 'R', 'SQL', 'SQL', 'NoSQL', 'Git', 'SAS', 'Java', 'Flask']}
# {'title': 'Lead Data Scientist H/F', 'company_name': "Kellog's", 'location': 'Us, France', 'experience': 'Non spécifié', 'technical_skills': ['Python', 'R', 'SQL', 'SQL']}
# {'title': 'Data Scientist H/F', 'company_name': 'Malou', 'location': 'Paris, France', 'experience': 'Non spécifié', 'technical_skills': ['Python', 'R', 'AWS', 'MongoDB']}
# {'title': 'Adjunct(s) Professor(s) in Econometrics, Data Analysis, and...', 'company_name': 'IÉSEG School of Management', 'location': 'Paris, France  (+1 other)', 'experience': 'Non spécifié', 'technical_skills': ['R']}
# {'title': 'Senior Solutions Data Scientist', 'company_name': 'Dataiku', 'location': 'Paris, France', 'experience': 'Non spécifié', 'technical_skills': ['Python', 'R', 'Dataiku', 'AWS', 'Scala', 'Dataiku', 'Git', 'generative AI', 'Java', 'Dash', 'Shiny']}
# {'title': 'Software Engineer Internship', 'company_name': 'Pigment', 'location': 'Paris, France', 'experience': 'Non spécifié', 'technical_skills': ['R', 'SQL', 'Excel', 'AWS', 'Scala', 'SQL', 'Kubernetes', 'Docker', 'Terraform', 'PostgreSQL']}
# {'title': 'Data Management Engineer F/H', 'company_name': 'BNP Paribas', 'location': 'Pantin, France', 'experience': 'Non spécifié', 'technical_skills': ['R']}
# {'title': 'Data & Analytics Security Officer', 'company_name': 'Saint-Gobain', 'location': 'Lille, France', 'experience': 'Non spécifié', 'technical_skills': ['R', 'Git']}
# {'title': 'Growth Engineer', 'company_name': 'Giskard', 'location': 'Anywhere', 'experience': 'Non spécifié', 'technical_skills': ['Python', 'R', 'SQL', 'Tableau', 'AWS', 'SQL', 'Java', 'Dash', 'BigQuery', 'Redshift']}
# {'title': 'Senior Software Engineer Python / Vue JS', 'company_name': 'Akeneo', 'location': 'Paris, France  (+1 other)', 'experience': 'Non spécifié', 'technical_skills': ['Python', 'R', 'Git', 'Jira', 'Java', 'Django']}
# {'title': 'Lead Data Scientist H/F', 'company_name': "Kellog's", 'location': 'Us, France', 'experience': 'Non spécifié', 'technical_skills': ['Python', 'R', 'SQL', 'SQL']}
# {'title': 'Senior Data Engineer', 'company_name': 'Teads', 'location': 'Montpellier, France', 'experience': 'Non spécifié', 'technical_skills': ['R', 'SQL', 'AWS', 'Spark', 'Scala', 'Kafka', 'SQL', 'NoSQL', 'Cassandra', 'BigQuery', 'Redshift']}
# {'title': 'Real Estate Development Associate / Analyst', 'company_name': 'DATA4 - Smart Data Centers at Scale', 'location': 'Paris, France', 'experience': 'Non spécifié', 'technical_skills': ['R', 'Excel']}
# {'title': 'Data Analyst, Lyft Media', 'company_name': 'Lyft', 'location': 'Flexanville, France', 'experience': 'Non spécifié', 'technical_skills': ['R', 'SQL', 'Excel', 'Tableau', 'SQL', 'Git', 'Jira', 'Dash']}
# {'title': 'STAGE - Data Visualisation (H/F)', 'company_name': 'Engie', 'location': 'Saint-Denis, France', 'experience': 'Non spécifié', 'technical_skills': ['R']}
# {'title': 'Data Scientist', 'company_name': 'Back Market', 'location': 'Anywhere', 'experience': 'Non spécifié', 'technical_skills': ['Python', 'R', 'LLM', 'generative AI']}
# {'title': 'Senior Data Architect', 'company_name': 'Urban Linker', 'location': 'Paris, France', 'experience': 'Non spécifié', 'technical_skills': ['R', 'Excel', 'Git']}
# {'title': 'Software Engineer Intern - Data Drift at Large (MLOps)', 'company_name': 'Dataiku', 'location': 'Paris, France', 'experience': 'Non spécifié', 'technical_skills': ['Python', 'R', 'Dataiku', 'Dataiku', 'LLM', 'Java']}
# {'title': 'Data Steward Lead F/H', 'company_name': 'Safran Aircraft Engines', 'location': 'Réau, France', 'experience': 'Non spécifié', 'technical_skills': ['R']}
# {'title': 'Customer Data Platform (CDP) Specialist / Customer Data Consultant...', 'company_name': 'Deloitte', 'location': 'Île-de-France, France', 'experience': 'Non spécifié', 'technical_skills': ['R', 'SQL', 'Excel', 'Tableau', 'GCP', 'AWS', 'SQL']}
# {'title': 'Open source software engineer (data)', 'company_name': 'Cloudfuse', 'location': 'Paris, France', 'experience': 'Non spécifié', 'technical_skills': ['R', 'AWS', 'Scala']}
# {'title': '1st-Level-Supporter/in', 'company_name': 'Redline DATA GmbH EDV-Systeme', 'location': 'Lyon, France', 'experience': 'Non spécifié', 'technical_skills': ['R']}
# {'title': 'Junior Data Analyst (EMEA, remote)', 'company_name': 'Margera', 'location': 'Anywhere', 'experience': 'Non spécifié', 'technical_skills': ['Python', 'R', 'SQL', 'Excel', 'Tableau', 'PowerBI', 'SQL', 'Git']}
# {'title': 'Full stack w/ data experience - contract or fte', 'company_name': 'Mindmesh', 'location': 'Paris, France', 'experience': 'Non spécifié', 'technical_skills': ['R', 'NLP', 'Java']}
# {'title': 'Data Analyst Trainee', 'company_name': 'HR Admin', 'location': 'Anywhere', 'experience': 'Non spécifié', 'technical_skills': ['R', 'Excel']}
# {'title': "Ingenieur d'etudes en statistiques - Data analyst (H/F) ...", 'company_name': 'Adalid', 'location': 'Paris, France', 'experience': 'Non spécifié', 'technical_skills': ['R', 'SAS']}
# {'title': 'Data Analyst Confirmé.e H/F', 'company_name': 'WizVille', 'location': 'Paris, France', 'experience': 'Non spécifié', 'technical_skills': ['R']}
# {'title': 'Senior Data Scientist H/F', 'company_name': 'Volvo Group', 'location': 'Anywhere', 'experience': 'Non spécifié', 'technical_skills': ['Python', 'R', 'Spark', 'Git', 'Tensorflow', 'Pytorch']}
# {'title': 'Regional Field Marketing Manager (23R-199)', 'company_name': 'Semarchy', 'location': 'Anywhere', 'experience': 'Non spécifié', 'technical_skills': ['R', 'Excel', 'Git']}
# {'title': 'Data Protection Officer, AXA DCP', 'company_name': 'AXA Group', 'location': 'Paris, France   (+8 others)', 'experience': 'Non spécifié', 'technical_skills': ['R', 'Excel', 'AWS', 'Git']}
# {'title': 'Business Analyst - DATA & IA', 'company_name': 'StedY', 'location': 'Paris, France', 'experience': 'Non spécifié', 'technical_skills': ['R', 'Git']}
# {'title': 'Data Scientist IA Generative H/F - Devoteam M Cloud', 'company_name': 'Devoteam', 'location': 'Anywhere', 'experience': '25 ans d’expérience', 'technical_skills': ['Python', 'R', 'Excel', 'AZURE', 'Databricks', 'Spark', 'Git', 'Kubernetes', 'Docker', 'NLP', 'LLM', 'generative AI']}
# {'title': 'Data Analyst - Data Scientist Intern H/F', 'company_name': 'Aircall', 'location': 'Paris, France', 'experience': 'Non spécifié', 'technical_skills': ['Python', 'R', 'SQL', 'Excel', 'SQL', 'Dash']}
# {'title': 'Data Sharing Product Owner H/F', 'company_name': 'Alstom', 'location': 'Saint-Ouen, France', 'experience': 'Non spécifié', 'technical_skills': ['R', 'Excel', 'Git']}
# {'title': 'ESG Regulations, Data & Reporting Lead (x/f/m)', 'company_name': 'AXA Group', 'location': 'Puteaux, France', 'experience': 'Non spécifié', 'technical_skills': ['R', 'Git']}
# {'title': 'Data Privacy Legal Counsel', 'company_name': 'Spendesk', 'location': 'Paris, France', 'experience': 'Non spécifié', 'technical_skills': ['R', 'Excel']}
# {'title': 'Data scientist -  Mobilités', 'company_name': 'MP DATA', 'location': 'Bordeaux, France   (+2 others)', 'experience': 'Non spécifié', 'technical_skills': ['Python', 'R', 'Spark', 'Git', 'NLP', 'Transformers', 'pySpark', 'Pyspark', 'PySpark', 'MLflow']}
# {'title': 'Investment & Finance Data Analyst', 'company_name': 'AXA Group', 'location': 'Puteaux, France', 'experience': 'Non spécifié', 'technical_skills': ['Python', 'R']}
# {'title': 'Clinical Data Manager / Senior Clinical Data Manager ...', 'company_name': 'Worldwide Clinical Trials', 'location': 'Anywhere', 'experience': 'Non spécifié', 'technical_skills': ['R', 'Excel', 'SAS']}
# {'title': 'Business & Data Analyst – Stage', 'company_name': 'Foxintelligence', 'location': 'Paris, France', 'experience': 'Non spécifié', 'technical_skills': ['R', 'Tableau', 'Git']}
# {'title': 'Internship - Financial Data Analyst - (M/F) - January 2024 - (Job...', 'company_name': 'AXA', 'location': 'Hauts-de-Seine, France', 'experience': 'Non spécifié', 'technical_skills': ['R', 'Excel', 'VBA']}
# {'title': 'Data Engineer', 'company_name': 'CellCarta', 'location': 'Anywhere', 'experience': 'Non spécifié', 'technical_skills': ['Python', 'R', 'SQL', 'Excel', 'Snowflake', 'AWS', 'AZURE', 'SQL', 'Snowflake', 'SQL Server', 'SAS', 'VBA', 'Shiny']}
# {'title': 'Business Data Analyst - Digital Services', 'company_name': 'Foxintelligence', 'location': 'Paris, France', 'experience': 'Non spécifié', 'technical_skills': ['R', 'Tableau', 'Git']}
