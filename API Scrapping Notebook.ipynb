# %% [markdown]
# #API scrapping of all the pages of Google Jobs

# %%
import requests

def fetch_all_google_jobs_data(api_key, query, location, hl="en", chips=None):
    """
    Récupère les données de toutes les pages de l'API Google Jobs pour une recherche donnée.

    Paramètres :
    api_key (str): Clé privée SerpApi.
    query (str): Requête de recherche.
    location (str, optionnel): Lieu géographique pour la recherche.
    hl (str): Langue pour la recherche.
    chips (list, optionnel): Conditions supplémentaires pour la requête.

    Retourne :
    list: Toutes les réponses JSON analysées de l'API.
    """
    all_results = []
    start = 0
    while True:
        # Paramètres pour la requête API
        params = {
            "engine": "google_jobs",
            "q": query,
            "start": start,
            "hl": hl,
            "api_key": api_key
        }

        if location:
            params["location"] = location

        if chips:
            params["chips"] = ','.join(chips)

        # URL de base pour l'API Google Jobs
        base_url = "https://serpapi.com/search.json"

        # Envoi d'une requête GET à l'API
        response = requests.get(base_url, params=params)
        if response.status_code == 200:
            data = response.json()
            all_results.append(data)

            # Vérifier s'il y a encore des résultats
            if "jobs_results" not in data or not data["jobs_results"]:
                break

            start += 10  # Incrémenter pour la prochaine page
        else:
            break

    return all_results

# Utilisation de la fonction
# Remplacez 'your_api_key' par votre clé SerpApi réelle
complete_data = fetch_all_google_jobs_data("65c15aeae94ce28a059108557e76ff428c362bd6550714533d91c1cf3c77f016", "Data Scientist", "Ile-De-France, France")

# %%
complete_data
# Out:
# [{'search_metadata': {'id': '65606c63216a9d78e2b8aad2',
#    'status': 'Success',
#    'json_endpoint': 'https://serpapi.com/searches/51e01b28f204085f/65606c63216a9d78e2b8aad2.json',
#    'created_at': '2023-11-24 09:26:59 UTC',
#    'processed_at': '2023-11-24 09:26:59 UTC',
#    'google_jobs_url': 'https://www.google.com/search?q=Data+Scientist&ibp=htl;jobs&uule=w+CAIQICIgUGFyaXMsUGFyaXMsSWxlLWRlLUZyYW5jZSxGcmFuY2U&hl=en&start=0',
#    'raw_html_file': 'https://serpapi.com/searches/51e01b28f204085f/65606c63216a9d78e2b8aad2.html',
#    'total_time_taken': 2.26},
#   'search_parameters': {'q': 'Data Scientist',
#    'engine': 'google_jobs',
#    'location_requested': 'Paris, France',
#    'location_used': 'Paris,Paris,Ile-de-France,France',
#    'google_domain': 'google.com',
#    'hl': 'en',
#    'start': 0},
#   'jobs_results': [{'title': 'AVP-Data Scientist',
#     'company_name': "Moody's Career",
#     'location': '  Paris, France   ',
#     'via': 'via Moodys Careers',
#     'description': "Moody’s is a developmental culture where we value candidates who are willing to grow. So, if you are excited about this opportunity but don’t meet every single requirement, please apply! You may be a perfect fit for this role or other open roles.\n\nMoody's is a global integrated risk assessment firm that empowers organizations to make better decisions.\n\nAt Moody’s, we’re taking action. We’re hiring diverse talent and providing underrepresented groups with equitable opportunities in their careers. We’re educating, empowering and elevating our people, and creating a workplace where each person can be their true selves, reach their full potential and thrive on every level. Learn more about our DE&I initiatives, employee development programs and view our annual DE&I Report at moodys.com/diversity\nTeam/Department Description :\n\nMoody’s Digital Finance team covers the analytical and operational aspects of emerging technologies and risks, including artificial intelligence, blockchain, digital... assets, and cyber security.\n\nRole/Responsibilities :\n\nWithin the Digital Finance team, the Associate Vice President – Data Science (AVP – Data Science) will be responsible for developing machine learning solutions for high-profile data science initiatives. The AVP – Data Science will notably focus on designing and training predictive analytics models and creating high-value-added solutions converting quantitative predictions into actionable insights for the business.\n\nA successful candidate will demonstrate an excellent knowledge of the various steps of a machine learning project, including modeling, data engineering, and MLOps. The candidate should also be innovation-minded, result-oriented, autonomous, and able to deliver finished products, sometimes under short deadlines.\n\nThe data science team will work closely with technology teams, rating and research teams, and other departments. The candidate should therefore be able to collaborate across multiple divisions and communicate clearly and understandably to business representatives unfamiliar with data science.\n\nThe AVP – Data Science will also strive to meet Moody’s values: openness, diversity, inclusivity, respect, and a willingness to learn.\n\nThe duties of the AVP – Data Science include:\n• Select and train machine learning models for predictive analytics, sometimes with relatively small and unbalanced datasets.\n• Build solutions predicting activities and extracting signals from multiple data sources.\n• Design explainability tools understandable by non-data scientists.\n• Collaborate with tech teams to create data ingestion pipelines connected to sources spread across different parts of the organization and delivered in varying formats.\n• Support tech teams in developing MLOps solutions and putting models in production.\n• Evaluate and select the best tools and IT architectures with tech teams.\n• Support tech teams in the management of cloud resources.\n• Communicate results to business stakeholders and decision-makers.\n• Collaborate with subject matter experts from ratings and research teams to incorporate fundamental expertise into machine learning models.\n• Mentor team members without data science backgrounds, as required, and foster a culture of knowledge sharing and learning.\n• Stay current with the latest research and technology developments.\n• Speak at internal and external events, as required\n\nQualifications :\n• Master’s degree or Ph.D. in data science, computer science, statistics, mathematics, or a related quantitative field.\n• 7+ years in machine learning, with a strong knowledge of algorithms and principles.\n• Proven track record of successfully modeling, building, and putting in production machine learning applications.\n• Deep understanding of the tools explaining machine learning predictions.\n• Expertise in Python and SQL.\n• Proven experience in natural language processing.\n• Excellent communication and presentation sk ...
#     'job_highlights': [{'items': ["Moody’s is a developmental culture where we value candidates who are willing to grow. So, if you are excited about this opportunity but don’t meet every single requirement, please apply! You may be a perfect fit for this role or other open roles.\n\nMoody's is a global integrated risk assessment firm that empowers organizations to make better decisions.\n\nAt Moody’s, we’re taking action. We’re hiring diverse talent and providing underrepresented groups with equitable opportunities in their careers. We’re educating, empowering and elevating our people, and creating a workplace where each person can be their true selves, reach their full potential and thrive on every level. Learn more about our DE&I initiatives, employee development programs and view our annual DE&I Report at moodys.com/diversity\nTeam/Department Description :\n\nMoody’s Digital Finance team covers the analytical and operational aspects of emerging technologies and risks, including artificial intelligence, blockchain, digital... assets, and cyber security.\n\nRole/Responsibilities :\n\nWithin the Digital Finance team, the Associate Vice President – Data Science (AVP – Data Science) will be responsible for developing machine learning solutions for high-profile data science initiatives. The AVP – Data Science will notably focus on designing and training predictive analytics models and creating high-value-added solutions converting quantitative predictions into actionable insights for the business.\n\nA successful candidate will demonstrate an excellent knowledge of the various steps of a machine learning project, including modeling, data engineering, and MLOps. The candidate should also be innovation-minded, result-oriented, autonomous, and able to deliver finished products, sometimes under short deadlines.\n\nThe data science team will work closely with technology teams, rating and research teams, and other departments. The candidate should therefore be able to collaborate across multiple divisions and communicate clearly and understandably to business representatives unfamiliar with data science.\n\nThe AVP – Data Science will also strive to meet Moody’s values: openness, diversity, inclusivity, respect, and a willingness to learn.\n\nThe duties of the AVP – Data Science include:\n• Select and train machine learning models for predictive analytics, sometimes with relatively small and unbalanced datasets.\n• Build solutions predicting activities and extracting signals from multiple data sources.\n• Design explainability tools understandable by non-data scientists.\n• Collaborate with tech teams to create data ingestion pipelines connected to sources spread across different parts of the organization and delivered in varying formats.\n• Support tech teams in developing MLOps solutions and putting models in production.\n• Evaluate and select the best tools and IT architectures with tech teams.\n• Support tech teams in the management of cloud resources.\n• Communicate results to business stakeholders and decision-makers.\n• Collaborate with subject matter experts from ratings and research teams to incorporate fundamental expertise into machine learning models.\n• Mentor team members without data science backgrounds, as required, and foster a culture of knowledge sharing and learning.\n• Stay current with the latest research and technology developments.\n• Speak at internal and external events, as required\n\nQualifications :\n• Master’s degree or Ph.D. in data science, computer science, statistics, mathematics, or a related quantitative field.\n• 7+ years in machine learning, with a strong knowledge of algorithms and principles.\n• Proven track record of successfully modeling, building, and putting in production machine learning applications.\n• Deep understanding of the tools explaining machine learning predictions.\n• Expertise in Python and SQL.\n• Proven experience in natural language processing.\n• Excellent communication and  ...
#     'related_links': [{'link': 'https://www.google.com/search?sca_esv=585011986&hl=en&q=Moody%27s+Career&sa=X&ved=0ahUKEwjt3q_vqNyCAxW_LzQIHQkmAcoQmJACCOIK',
#       'text': "See web results for Moody's Career"}],
#     'extensions': ['2 days ago', 'Full-time'],
#     'detected_extensions': {'posted_at': '2 days ago',
#      'schedule_type': 'Full-time'},
#     'job_id': '...'},
#    {'title': 'Staff Data Scientist - Data Scientist',
#     'company_name': 'Datadog',
#     'location': '  Paris, France   ',
#     'via': 'via Datadog Careers',
#     'description': "We are looking for a staff data scientist to join our data science organization. Reporting directly to the director of engineering for data science, your scope and impact will span across the whole data science organization.\n\nAs a staff data scientist, you will help design, implement and scale new and existing Datadog’s features. You will thrive to answer questions such as: “Is it feasible?”, “can we do it more efficiently with another technique?” and “what’s the business opportunity of this new data science framework?”.\n\nYour roles will cover the whole data science lifecycle (design, prototyping, scaling and productionisation). And as one of the most senior members of the team will help coach, mentor and develop team members by being a champion for data science and engineering best practices.\n\nAt Datadog, we place value in our office culture - the relationships and collaboration it builds and the creativity it brings to the table. We operate as a hybrid workplace to ensure our... Datadogs can create a work-life harmony that best fits them.\n\nWhat You’ll Do:\n• Identify high impact business opportunities through data exploration, model prototypes and bootstrapping projects.\n• Hands-on development, productionisation, and operation of machine learning models and pipelines at scale, including both batch and real-time use cases, structured and unstructured data\n• Collaborate closely with data scientists and engineers to develop the next generation of Datadog’s features\n• Mentor and guide data scientists in the organization by promoting best practices, strong technical decisions, coding standards and thorough documentation\n• Regularly present work internally (data science demo, internal talks,...) to technical, engineering and product stakeholders to iterate and generate excitement\n• Engage with the data science and engineering community to advance Datadog’s standing\n\nWho You Are:\n• 8+ years of industry experience (data scientist, ML engineer, tech lead…) and a Master’s degree or PhD in relevant fields\n• Strong track records of designing, prototyping, scaling and launching data science products to solve business problems.\n• Deep understanding of Machine Learning lifecycle, best practices, algorithms and domains (eg. anomaly detection, natural language processing, computer vision, personalization and recommendation)\n• Experience collaborating with and understanding the needs of stakeholders from a variety of business functions and ability to work with domain experts to leverage their expertise into your solution\n• Strong coding skills in general purpose languages like Scala or Python, and familiarity with software engineering principles around testing, code reviews and deployment.\n• Fundamental understandings of the data engineering practice around creation of data pipelines, processing data and storing data using technologies such as spark\n• Ability to take a product-oriented mindset in using conceptual and innovative thinking to develop and apply solutions taking into consideration the user experience\n• Proven ability to communicate clearly and effectively to audiences of varying technical levels\n\nDatadog values people from all walks of life. We understand not everyone will meet all the above qualifications on day one. That's okay. If you’re passionate about technology and want to grow your skills, we encourage you to apply.\n\nBenefits and Growth:\n• High income earning opportunities based on individual performance\n• New hire stock equity (RSUs) and employee stock purchase plan (ESPP)\n• Continuous professional development, product training, and career pathing\n• Sales training in MEDDIC and Command of the Message\n• Intradepartmental mentor and buddy program for in-house networking\n• An inclusive company culture, ability to join our Community Guilds (Datadog employee resource groups)\n• Access to Inclusion Talks, our Internal panel discussions\n• Free, global Spring Health benefits f ...
#     'job_highlights': [{'items': ["We are looking for a staff data scientist to join our data science organization. Reporting directly to the director of engineering for data science, your scope and impact will span across the whole data science organization.\n\nAs a staff data scientist, you will help design, implement and scale new and existing Datadog’s features. You will thrive to answer questions such as: “Is it feasible?”, “can we do it more efficiently with another technique?” and “what’s the business opportunity of this new data science framework?”.\n\nYour roles will cover the whole data science lifecycle (design, prototyping, scaling and productionisation). And as one of the most senior members of the team will help coach, mentor and develop team members by being a champion for data science and engineering best practices.\n\nAt Datadog, we place value in our office culture - the relationships and collaboration it builds and the creativity it brings to the table. We operate as a hybrid workplace to ensure our... Datadogs can create a work-life harmony that best fits them.\n\nWhat You’ll Do:\n• Identify high impact business opportunities through data exploration, model prototypes and bootstrapping projects.\n• Hands-on development, productionisation, and operation of machine learning models and pipelines at scale, including both batch and real-time use cases, structured and unstructured data\n• Collaborate closely with data scientists and engineers to develop the next generation of Datadog’s features\n• Mentor and guide data scientists in the organization by promoting best practices, strong technical decisions, coding standards and thorough documentation\n• Regularly present work internally (data science demo, internal talks,...) to technical, engineering and product stakeholders to iterate and generate excitement\n• Engage with the data science and engineering community to advance Datadog’s standing\n\nWho You Are:\n• 8+ years of industry experience (data scientist, ML engineer, tech lead…) and a Master’s degree or PhD in relevant fields\n• Strong track records of designing, prototyping, scaling and launching data science products to solve business problems.\n• Deep understanding of Machine Learning lifecycle, best practices, algorithms and domains (eg. anomaly detection, natural language processing, computer vision, personalization and recommendation)\n• Experience collaborating with and understanding the needs of stakeholders from a variety of business functions and ability to work with domain experts to leverage their expertise into your solution\n• Strong coding skills in general purpose languages like Scala or Python, and familiarity with software engineering principles around testing, code reviews and deployment.\n• Fundamental understandings of the data engineering practice around creation of data pipelines, processing data and storing data using technologies such as spark\n• Ability to take a product-oriented mindset in using conceptual and innovative thinking to develop and apply solutions taking into consideration the user experience\n• Proven ability to communicate clearly and effectively to audiences of varying technical levels\n\nDatadog values people from all walks of life. We understand not everyone will meet all the above qualifications on day one. That's okay. If you’re passionate about technology and want to grow your skills, we encourage you to apply.\n\nBenefits and Growth:\n• High income earning opportunities based on individual performance\n• New hire stock equity (RSUs) and employee stock purchase plan (ESPP)\n• Continuous professional development, product training, and career pathing\n• Sales training in MEDDIC and Command of the Message\n• Intradepartmental mentor and buddy program for in-house networking\n• An inclusive company culture, ability to join our Community Guilds (Datadog employee resource groups)\n• Access to Inclusion Talks, our Internal panel discussions\n• Free, global Spring He ...
#     'related_links': [{'link': 'https://www.datadog.com/',
#       'text': 'datadog.com'},
#      {'link': 'https://www.google.com/search?sca_esv=585011986&hl=en&q=Datadog&sa=X&ved=0ahUKEwjt3q_vqNyCAxW_LzQIHQkmAcoQmJACCJsL',
#       'text': 'See web results for Datadog'}],
#     'extensions': ['2 days ago', 'Full-time'],
#     'detected_extensions': {'posted_at': '2 days ago',
#      'schedule_type': 'Full-time'},
#     'job_id': '...'},
#    {'title': 'Data Scientist (full time, all seniority levels) - QuantumBlack',
#     'company_name': 'McKinsey & Company',
#     'location': '  Paris, France   ',
#     'via': 'via McKinsey & Company',
#     'description': "Who You'll Work With\n\nBased in Paris and working across the region, as a consultant data scientist you will work closely with our clients, data engineers and all types of McKinsey consultants on interdisciplinary projects, using maths, stats and machine learning to derive structure and knowledge from raw data across various industry sectors.\n\nThis hybrid client-facing/technical role will allow you to use state of the art technologies to solve highly impactful business problems, whilst also leveraging your strong communication skills to convey complex intractable ideas to non-technical audiences.\n\nWho you are\n\nThis full time position is for a data scientist across all seniority levels with strong intrinsic technical ability and an aptitude to solving complex problems using technology.\n\nA core value at QuantumBlack is fusion and at the heart of our multi-disciplinary teams is the belief that the sum of individual parts will always be less than the impact of the entire team. You are a... highly collaborative individual who is capable of laying aside your own agenda, listening to and learning from colleagues, challenging thoughtfully and prioritizing impact. You search for ways to improve things and work collaboratively with colleagues. You believe in iterative change, experimenting with new approaches, learning and improving to move forward quickly. Trust between colleagues is paramount here – you are an individual who can always be trusted to work in the best interests of all colleagues and to achieve the best outcome for QuantumBlack and our clients. You are naturally enthusiastic and enjoy sharing your passion with others.\n\nWhat You'll Do\n\nAs a Data Scientist with the Paris office...\n\nYou will work in multi-disciplinary environments harnessing data to provide real-world impact for organisations globally.\n\nYou will influence many of the recommendations our clients need to positively change their businesses and enhance performance.\n\nRole responsibilities\n• Work on complex and extremely varied data sets from some of the world’s largest organisations to solve real world problems\n• Develop data science products and solutions for clients as well as for our data science team\n• Write highly optimized code to advance our internal Data Science Toolbox\n• Work in a multi-disciplinary environment with specialists in machine learning, engineering and design\n• Add real-world impact to your academic expertise, as you are encouraged to write ‘black’ papers and present at meetings and conferences should you wish\n• Attend conferences such as NIPS and ICML as one global team as well as Data Science retrospectives where you will have the opportunity to share and learn from your co-workers.\n• Work within one of the largest and most advanced data science teams in Europe, support the Lead Data Scientists to develop data science products\n\nWhat you’ll learn\n• How successful projections on real world problems across a variety of industries are completed through referencing past deliveries of end to end machine learning pipelines\n• Build products alongside the core engineering team and evolve the engineering process to scale with data, handling complex problems and advanced client situations\n• Be able to focus on modelling by working alongside the Data Engineering team which focuses on the wrangling, clean-up and transformation of data.\n• Best practices in software development and productionise machine learning by working with our Machine Learning Engineering teams which optimise code for model development and scale it\n• Work with our UX and Visual Design teams to interpret your complex models into stunning and user-focused visualisations\n• Using new technologies and problem-solving skills in a multicultural and creative environment\n\nYou will work on the frameworks and libraries that our teams of Data Scientists and Data Engineers use to progress from data to impact. You will guide global companies ...
#     'job_highlights': [{'items': ["Who You'll Work With\n\nBased in Paris and working across the region, as a consultant data scientist you will work closely with our clients, data engineers and all types of McKinsey consultants on interdisciplinary projects, using maths, stats and machine learning to derive structure and knowledge from raw data across various industry sectors.\n\nThis hybrid client-facing/technical role will allow you to use state of the art technologies to solve highly impactful business problems, whilst also leveraging your strong communication skills to convey complex intractable ideas to non-technical audiences.\n\nWho you are\n\nThis full time position is for a data scientist across all seniority levels with strong intrinsic technical ability and an aptitude to solving complex problems using technology.\n\nA core value at QuantumBlack is fusion and at the heart of our multi-disciplinary teams is the belief that the sum of individual parts will always be less than the impact of the entire team. You are a... highly collaborative individual who is capable of laying aside your own agenda, listening to and learning from colleagues, challenging thoughtfully and prioritizing impact. You search for ways to improve things and work collaboratively with colleagues. You believe in iterative change, experimenting with new approaches, learning and improving to move forward quickly. Trust between colleagues is paramount here – you are an individual who can always be trusted to work in the best interests of all colleagues and to achieve the best outcome for QuantumBlack and our clients. You are naturally enthusiastic and enjoy sharing your passion with others.\n\nWhat You'll Do\n\nAs a Data Scientist with the Paris office...\n\nYou will work in multi-disciplinary environments harnessing data to provide real-world impact for organisations globally.\n\nYou will influence many of the recommendations our clients need to positively change their businesses and enhance performance.\n\nRole responsibilities\n• Work on complex and extremely varied data sets from some of the world’s largest organisations to solve real world problems\n• Develop data science products and solutions for clients as well as for our data science team\n• Write highly optimized code to advance our internal Data Science Toolbox\n• Work in a multi-disciplinary environment with specialists in machine learning, engineering and design\n• Add real-world impact to your academic expertise, as you are encouraged to write ‘black’ papers and present at meetings and conferences should you wish\n• Attend conferences such as NIPS and ICML as one global team as well as Data Science retrospectives where you will have the opportunity to share and learn from your co-workers.\n• Work within one of the largest and most advanced data science teams in Europe, support the Lead Data Scientists to develop data science products\n\nWhat you’ll learn\n• How successful projections on real world problems across a variety of industries are completed through referencing past deliveries of end to end machine learning pipelines\n• Build products alongside the core engineering team and evolve the engineering process to scale with data, handling complex problems and advanced client situations\n• Be able to focus on modelling by working alongside the Data Engineering team which focuses on the wrangling, clean-up and transformation of data.\n• Best practices in software development and productionise machine learning by working with our Machine Learning Engineering teams which optimise code for model development and scale it\n• Work with our UX and Visual Design teams to interpret your complex models into stunning and user-focused visualisations\n• Using new technologies and problem-solving skills in a multicultural and creative environment\n\nYou will work on the frameworks and libraries that our teams of Data Scientists and Data Engineers use to progress from data to impact. You will guide g ...
#     'related_links': [{'link': 'http://www.mckinsey.com/',
#       'text': 'mckinsey.com'},
#      {'link': 'https://www.google.com/search?sca_esv=585011986&hl=en&q=McKinsey+%26+Company&sa=X&ved=0ahUKEwjt3q_vqNyCAxW_LzQIHQkmAcoQmJACCNEL',
#       'text': 'See web results for McKinsey & Company'}],
#     'thumbnail': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRZPbw9ZL0xF1gbrBe4t_LgmplpG25qKZ1Ey5Q8&s=0',
#     'extensions': ['Full-time'],
#     'detected_extensions': {'schedule_type': 'Full-time'},
#     'job_id': '...'},
#    {'title': 'Data Scientist',
#     'company_name': 'ENGIE',
#     'location': '  Courbevoie, France   ',
#     'via': 'via Engie.com',
#     'description': 'About US (GEMS):ENGIE Global Energy Management & Sales (GEMS) provides energy supply solutions and risk management services to support its clients through their decarbonization journey, while optimizing ENGIE’s assets and contributing to value creation. ENGIE is a global reference in low-carbon energy and services with a leading energy management business, piloted by its entity "Global Energy Management & Sales" who built its savoir-faire managing the Group’s large and diverse asset portfolio over 20+ years. 3,300 employees around the world develop our solutions, through +20 international business platforms. We cover the full energy mix: renewable and thermal power, natural gas & LNG, biomass, environmental products. Our experts provide tailor made solutions based on a wide range of savoir-faire in energy management with a strong focus on decarbonation and decentralization.Our +120,00 clients span the entire value chain: producers, asset developers, financial players, utilities... distributors and industrials. Our global reach and strong local presence enable us to offer these diverse clients tailor-made services and respond to rapid changes in mature or emerging markets alike. Our 4 expertises:• Asset management• Energy transition services• Energy supply & global commodities• Risk management & market access At GEMS we encourage breakthrough results, team spirit, curiosity and innovation while preserving the right work/life balance for you. More info on GEMS Hub (https://gems.engie.com) or LinkedIn (https://www.linkedin.com/company/engie-global-energy-management-solutions). Context:Battery Energy Storage Systems (BESS) are central to ENGIE’s strategy driven by decarbonization, decentralization, and digitalization. Our ambition is to become a major player in BESS. BESS are an important piece of the global decarbonisation drive providing flexibility to systems and portfolios by replacing part of conventional generation (coal exit), complementing increasing renewables buildout (wind, solar), and supporting to balance power grids (ancillaries) and save excess energy (arbitrage). Several countries have been identified standing out as promising for BESS investments. Those countries show strong potential for capacity deployment over the coming years, driven by ambitious decarbonisation targets, projected exponential growth in renewables, and retirement of ageing conventional power plants. ENGIE is uniquely placed to deliver on these objectives as 3 Global Business Units are active in BESS deployment: front-of-the meter grid connected BESS and residential BESS (GBU TS), front-of-the meter grid-connected paired with renewables (GBU R) and behind-the-meter at client’s premises (GBU ES). Our worldwide presence, strong industrial capabilities, and local anchorage as well as a deep know-how in power management and trading (GEMS) will allow us to develop integrated solutions for systems, internal portfolio needs and our customers across the value chain: from development through construction into operations, portfolio optimization while providing ancillary services and flexible power when required. Our ambition is to become a BESS player present in key markets worldwide providing flexibility while extracting value from the embedded optionality offered by deploying BESS.To succeed in this rapidly evolving business, Engie want to embrace digital technologies as part of its strategy to bring differentiating solutions and protect its competitive advantages. This includes developing solutions to deliver value on core business activities, as well as investing in innovation, research, and development to explore new business models and solutions.For this reason, a strong focus and ambition has been put on building and implementing an ambitious digital strategy for BESS, we offer you the opportunity to join this incredible mission as Senior Digital Project Manager. Role:As a Data Scientist/Data Engineer in our BESS business, you w ...
#     'job_highlights': [{'items': ['About US (GEMS):ENGIE Global Energy Management & Sales (GEMS) provides energy supply solutions and risk management services to support its clients through their decarbonization journey, while optimizing ENGIE’s assets and contributing to value creation. ENGIE is a global reference in low-carbon energy and services with a leading energy management business, piloted by its entity "Global Energy Management & Sales" who built its savoir-faire managing the Group’s large and diverse asset portfolio over 20+ years. 3,300 employees around the world develop our solutions, through +20 international business platforms. We cover the full energy mix: renewable and thermal power, natural gas & LNG, biomass, environmental products. Our experts provide tailor made solutions based on a wide range of savoir-faire in energy management with a strong focus on decarbonation and decentralization.Our +120,00 clients span the entire value chain: producers, asset developers, financial players, utilities... distributors and industrials. Our global reach and strong local presence enable us to offer these diverse clients tailor-made services and respond to rapid changes in mature or emerging markets alike. Our 4 expertises:• Asset management• Energy transition services• Energy supply & global commodities• Risk management & market access At GEMS we encourage breakthrough results, team spirit, curiosity and innovation while preserving the right work/life balance for you. More info on GEMS Hub (https://gems.engie.com) or LinkedIn (https://www.linkedin.com/company/engie-global-energy-management-solutions). Context:Battery Energy Storage Systems (BESS) are central to ENGIE’s strategy driven by decarbonization, decentralization, and digitalization. Our ambition is to become a major player in BESS. BESS are an important piece of the global decarbonisation drive providing flexibility to systems and portfolios by replacing part of conventional generation (coal exit), complementing increasing renewables buildout (wind, solar), and supporting to balance power grids (ancillaries) and save excess energy (arbitrage). Several countries have been identified standing out as promising for BESS investments. Those countries show strong potential for capacity deployment over the coming years, driven by ambitious decarbonisation targets, projected exponential growth in renewables, and retirement of ageing conventional power plants. ENGIE is uniquely placed to deliver on these objectives as 3 Global Business Units are active in BESS deployment: front-of-the meter grid connected BESS and residential BESS (GBU TS), front-of-the meter grid-connected paired with renewables (GBU R) and behind-the-meter at client’s premises (GBU ES). Our worldwide presence, strong industrial capabilities, and local anchorage as well as a deep know-how in power management and trading (GEMS) will allow us to develop integrated solutions for systems, internal portfolio needs and our customers across the value chain: from development through construction into operations, portfolio optimization while providing ancillary services and flexible power when required. Our ambition is to become a BESS player present in key markets worldwide providing flexibility while extracting value from the embedded optionality offered by deploying BESS.To succeed in this rapidly evolving business, Engie want to embrace digital technologies as part of its strategy to bring differentiating solutions and protect its competitive advantages. This includes developing solutions to deliver value on core business activities, as well as investing in innovation, research, and development to explore new business models and solutions.For this reason, a strong focus and ambition has been put on building and implementing an ambitious digital strategy for BESS, we offer you the opportunity to join this incredible mission as Senior Digital Project Manager. Role:As a Data Scientist/Data Engineer in our BESS  ...
#     'related_links': [{'link': 'http://www.engie.com/', 'text': 'engie.com'},
#      {'link': 'https://www.google.com/search?sca_esv=585011986&hl=en&q=ENGIE&sa=X&ved=0ahUKEwjt3q_vqNyCAxW_LzQIHQkmAcoQmJACCIkM',
#       'text': 'See web results for ENGIE'}],
#     'thumbnail': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQfdC_vOPjdnvTfFKJOVjE-g3HgZPYDUkQdbpTtk5bEgvi_Wxj07xb88v4&s',
#     'extensions': ['16 days ago', 'Full-time'],
#     'detected_extensions': {'posted_at': '16 days ago',
#      'schedule_type': 'Full-time'},
#     'job_id': '...'},
#    {'title': 'Data Scientist',
#     'company_name': 'BIC',
#     'location': '  Clichy, France   ',
#     'via': 'via Careers At BIC',
#     'description': 'For over 75 years, BIC has been creating ingeniously simple and joyful products that are a part of every heart and home.\n\nAs a member of our team, you\'ll be a part of reigniting a beloved brand as we continue to reimagine everyday essentials in new, sustainable and responsible ways.\n\nOur "roll up your sleeves and get the job done" approach to work creates an environment where self-starters, problem solvers and innovative thinkers thrive. BIC team members are empowered to take ownership of their careers and bring their unique perspectives to the table to make a meaningful impact on our mission.\n\nIt\'s a colorful world - make your mark by joining the BIC team today.\n\nJOB DESCRIPTION\n\nThe Data Scientist (DS) is responsible for delivering intelligence through compelling analysis to support the business and the decision-making to all aspects concerning his/her markets. This role collaborates closely with Market Experts in the Shavers and Stationery departments to generate data-driven... Insights\n\nThe DS provides support in using analytics to provide insights, automate business actions, and improve the speed and quality of decisions. This position provides support in ensuring data management, integrity, quality and consistency throughout the sources for data including: standards and processes to source, ingest, prepare and explore data; support design, build, and implement data analytics structures and reporting process; developing analytics solutions to business questions; deep dive and information extraction relevant to business needs.\n\nThe Market & Consumer Insights/Intelligence team operates as the Centre Of Excellence (COE) on actionable insights in the areas of Market Analysis & Research (business analytics, opportunities), Consumer/Shopper Behavioral Research (trends, needs, motivations, purchase habits) and User/Product Research (user perception & attitudes, product evaluation).\n\nThe DS will play a key role in the sourcing, processing and extraction of insights and support engagement and reporting in close collaboration with other members to support decision making of all MCI stakeholders\n\nMAIN RESPONSIBILITIES\n• Oversee data acquisition, developing data set processes. data integrity, quality and consistency throughout the data sources\n• Lead the development of data analytics solutions and pipeline development (data structures / reporting and processes) in collaboration with Data Science team commiserate with business needs\n• Responsible for deep dive/investigating the data from multiple sources with an exploratory mindset to uncover relationships and insights relevant to the business\n• Develop new data stores with team members; use programming language and tools to transform, combine, and clean data in preparation for analysis; document data definitions and issues for future reference\n• Facilitate sharing of insights and intelligence in a manner that is easy to understand (for non-technical audience) and recommend specific action\n• Support establishing and documenting modeling standards and processes, including: identify and define problem, and design approach; prepare, explore, transform, and select data; build, validate, and deploy analytic solutions/models; and monitor and evaluate results\n• Leverage and implement advanced analytics solutions (incl. machine learning/AI) to drive solutions to help drive better, faster business decision making\n• Handle complex structured and unstructured data sets from internal and external sources\n• Collaborate with Marketing, Innovation, product design and customer teams in data management and extraction of insights\n• Drive data quality, availability, analytics capability throughout the company. Take ownership of quality, accuracy and usability of data and reporting structure/dashboards\n\nQUALIFICATIONS\n• Bachelor’s and/or Master’s degree in statistics, computer science, engineering, math, econometrics, or other quantitative decision sci ...
#     'job_highlights': [{'items': ['For over 75 years, BIC has been creating ingeniously simple and joyful products that are a part of every heart and home.\n\nAs a member of our team, you\'ll be a part of reigniting a beloved brand as we continue to reimagine everyday essentials in new, sustainable and responsible ways.\n\nOur "roll up your sleeves and get the job done" approach to work creates an environment where self-starters, problem solvers and innovative thinkers thrive. BIC team members are empowered to take ownership of their careers and bring their unique perspectives to the table to make a meaningful impact on our mission.\n\nIt\'s a colorful world - make your mark by joining the BIC team today.\n\nJOB DESCRIPTION\n\nThe Data Scientist (DS) is responsible for delivering intelligence through compelling analysis to support the business and the decision-making to all aspects concerning his/her markets. This role collaborates closely with Market Experts in the Shavers and Stationery departments to generate data-driven... Insights\n\nThe DS provides support in using analytics to provide insights, automate business actions, and improve the speed and quality of decisions. This position provides support in ensuring data management, integrity, quality and consistency throughout the sources for data including: standards and processes to source, ingest, prepare and explore data; support design, build, and implement data analytics structures and reporting process; developing analytics solutions to business questions; deep dive and information extraction relevant to business needs.\n\nThe Market & Consumer Insights/Intelligence team operates as the Centre Of Excellence (COE) on actionable insights in the areas of Market Analysis & Research (business analytics, opportunities), Consumer/Shopper Behavioral Research (trends, needs, motivations, purchase habits) and User/Product Research (user perception & attitudes, product evaluation).\n\nThe DS will play a key role in the sourcing, processing and extraction of insights and support engagement and reporting in close collaboration with other members to support decision making of all MCI stakeholders\n\nMAIN RESPONSIBILITIES\n• Oversee data acquisition, developing data set processes. data integrity, quality and consistency throughout the data sources\n• Lead the development of data analytics solutions and pipeline development (data structures / reporting and processes) in collaboration with Data Science team commiserate with business needs\n• Responsible for deep dive/investigating the data from multiple sources with an exploratory mindset to uncover relationships and insights relevant to the business\n• Develop new data stores with team members; use programming language and tools to transform, combine, and clean data in preparation for analysis; document data definitions and issues for future reference\n• Facilitate sharing of insights and intelligence in a manner that is easy to understand (for non-technical audience) and recommend specific action\n• Support establishing and documenting modeling standards and processes, including: identify and define problem, and design approach; prepare, explore, transform, and select data; build, validate, and deploy analytic solutions/models; and monitor and evaluate results\n• Leverage and implement advanced analytics solutions (incl. machine learning/AI) to drive solutions to help drive better, faster business decision making\n• Handle complex structured and unstructured data sets from internal and external sources\n• Collaborate with Marketing, Innovation, product design and customer teams in data management and extraction of insights\n• Drive data quality, availability, analytics capability throughout the company. Take ownership of quality, accuracy and usability of data and reporting structure/dashboards\n\nQUALIFICATIONS\n• Bachelor’s and/or Master’s degree in statistics, computer science, engineering, math, econometrics, or other quantitati ...
#     'related_links': [{'link': 'http://www.bic.com/', 'text': 'bic.com'},
#      {'link': 'https://www.google.com/search?sca_esv=585011986&hl=en&q=BIC&sa=X&ved=0ahUKEwjt3q_vqNyCAxW_LzQIHQkmAcoQmJACCMEM',
#       'text': 'See web results for BIC'}],
#     'extensions': ['17 days ago', 'Full-time'],
#     'detected_extensions': {'posted_at': '17 days ago',
#      'schedule_type': 'Full-time'},
#     'job_id': '...'},
#    {'title': 'Data Scientist H/F',
#     'company_name': 'HomeExchange',
#     'location': '  Paris, France   ',
#     'via': 'via Welcome To The Jungle',
#     'description': 'Bienvenue chez vous, partout dans le Monde\n\nChez HomeExchange, nous avons la conviction qu’une autre manière de voyager est possible.\n\nNotre plateforme, leader mondial de l’échange de maison, propose aujourd’hui plus de 150 000 membres, dans 145 pays.\nGrâce à un système innovant, elle permet aux membres de notre communauté d’échanger facilement leur maison, de manière transparente et en toute sécurité.\nC’est pour leur offrir une expérience de voyage authentique, basée sur la confiance et l’hospitalité, que notre équipe crée, innove et prend des initiatives au quotidien.\n\nSi, pour vous, bienveillance, engagement et équilibre s’accordent avec détermination et audace.\nSi, comme nous, vous recherchez des expériences authentiques et êtes soucieux(euse) de la préservation de notre planète.\n\nRejoignez-nous et construisons ensemble l’avenir du voyage !\n\nAfin de répondre à nos ambitions et challenges, nous sommes à la recherche d’un·e Data Scientist qui saura proposer, impulser, créer et... partager ses idées et connaissances avec ses collègues.\n\nL’équipe est actuellement composée de :\n• Rémi , Vincent & Quentin - Data Engineer\n• Christopher, Leeroy & Guillaume - Data Analyst\n• Alexandre - Data Scientist\n• Soizic - Head of Data\n\nNous cherchons donc une nouvelle pépite avec au moins deux ans d’expérience pour rejoindre cette belle équipe!\n\nVos missions principales seront les suivantes :\n• Objectif : aider les équipes à anticiper et agir au moment le plus opportun\n• Echanges avec les équipes métiers pour cerner au mieux les problématiques\n• Identification et préparation des données\n• Préparation et mise en production du modèle\n• Mise à disposition et explication des résultats aux équipes métiers\n• Mesure d’impact et documentation du projet\n• Etudes exploratoires en amont des projets\n• Conception, entraînement, amélioration et mise en production de modèles ML efficaces, du notebook à la production (sous l’oeil avisé des Data Engineers)\n\nProjets à venir:\n• Détection de patterns à partir d’images (Computer Vision)\n• Détection de patterns à partir de textes (NLP)\n• Optimisation des promotions\n• Prédictions/Forecasts',
# ...
#     'job_highlights': [{'items': ["Are you interested in model risk monitoring topics? So join us!\n\nThe Model Risk Management department ensures the quality and relevance of the LLM models (Large language models) developed within the Group, as well as monitoring the bank's model risk. The team is, among other things, responsible for carrying out benchmarks in order to test the limits of the models of the audited entities. The objective of the mission is to carry out a study of explainable AI techniques by analyzing their limits and their applications in the banking field.\n\nConcretely, you will be required to:\n• Review the state of the art of explainability techniques for LLMs;\n• Test the use of these techniques on textual data;\n• Evaluate the performance and limits of these techniques in the context of model risk management;\n• Participate in the continuous improvement of data science model review protocols;\n• Document the study and lead interactive workshops to present progress to team members.\n\nAND IF IT WERE YOU ?\n•... You are a Bac + 4/5 level student in an engineering school, business school or university with a specialization in IT.\n• You have solid theoretical and operational knowledge in Machine Learning.\n• You have good knowledge of Python and R.\n• With writing skills, you know how to write summary notes and present your results in PowerPoint or Web app format. Autonomous, rigorous, curious, you are proactive.\n• A strong team spirit, enthusiasm and good interpersonal skills will allow you to quickly integrate into the team.\n• You're fluent in English! You are our ideal candidate!\n\nMORE THAN A POSITION, A SPRINGBOARD\n\nAs soon as you arrive, you will be integrated into our teams and will learn every day alongside our experts who will support you in your missions. Gradually, you will gain autonomy over your projects to make this experience a real career accelerator. You will also discover the full diversity of our professions, in a sector that is constantly evolving and innovating.\n\nAs an intern, you will be able to benefit from teleworking days (for any long-term internship and depending on the pace of your service), 50% coverage of your transport ticket and reduced ticket prices for our Works Council (concerts, cinema, sport, etc.). During your presence on site, you will have access to a varied offering of company restaurants and cafeterias at a very competitive price.\n\nAt the end of your studies or your LIFE, various opportunities may be available to you, in France and internationally.\n\nWHY CHOOSE US ?\n\nAt Société Générale, we are convinced that people are the drivers of change, and that the world of tomorrow will be made up of all their initiatives, from the smallest to the most ambitious.\n\nWhether you join us for a few months, a few years or your entire career, together we have the means to have a positive impact on the future.\n\nCreating, daring, innovating, undertaking are part of our DNA. If you also want to be in action, evolve in a stimulating and caring environment, feel useful on a daily basis and develop or strengthen your expertise, we are made to meet!\n\nAre you still hesitant?\n\nPlease note that our employees can commit a few days a year to solidarity actions during their working time: sponsoring people experiencing difficulty in their career path or professional integration, participating in the financial education of young people in apprenticeships or even sharing their skills with an association. There are multiple engagement formats"]}],
#     'related_links': [{'link': 'http://www.societegenerale.com/',
#       'text': 'societegenerale.com'},
#      {'link': 'https://www.google.com/search?sca_esv=d388e2d0245757a4&sca_upv=1&hl=en&q=Societe+Generale&sa=X&ved=0ahUKEwjzgvuTqdyCAxWnTDABHWUSCU84ogIQmJACCKkM',
#       'text': 'See web results for Societe Generale'}],
#     'thumbnail': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTKf-V4YutEkoO32GUqUFcSD2zsvcONUKxG3ulT&s=0',
#     'extensions': ['7 days ago', '€61K–€95K a year', 'Full-time'],
#     'detected_extensions': {'posted_at': '7 days ago',
#      'schedule_type': 'Full-time'},
#     'job_id': '...'}],
#   'chips': [{'type': 'Title',
#     'param': 'job_family_1',
#     'options': [{'text': 'All'},
#      {'text': 'Data scientist', 'value': 'data scientist'},
#      {'text': 'Data science', 'value': 'data science'},
#      {'text': 'Officer', 'value': 'officer'},
#      {'text': 'Senior', 'value': 'senior'},
#      {'text': 'Data engineer', 'value': 'data engineer'},
#      {'text': 'Data analyst', 'value': 'data analyst'},
#      {'text': 'Software engineer', 'value': 'software engineer'},
#      {'text': 'Director', 'value': 'director'},
#      {'text': 'Engineering manager', 'value': 'engineering manager'},
#      {'text': 'Manager', 'value': 'manager'},
#      {'text': 'Scientist', 'value': 'scientist'},
#      {'text': 'Specialist', 'value': 'specialist'},
#      {'text': 'Apprentice', 'value': 'apprentice'},
#      {'text': 'Apprenticeship', 'value': 'apprenticeship'},
#      {'text': 'Backend engineer', 'value': 'backend engineer'},
#      {'text': 'Business', 'value': 'business'},
#      {'text': 'Learning engineer', 'value': 'learning engineer'},
#      {'text': 'Research scientist', 'value': 'research scientist'},
#      {'text': 'Researcher', 'value': 'researcher'},
#      {'text': 'Science', 'value': 'science'},
#      {'text': 'Senior specialist', 'value': 'senior specialist'}]},
#    {'type': 'Location',
#     'param': 'city',
#     'options': [{'text': 'All'},
#      {'text': 'Paris', 'value': 'D7fiBh9u5kdglIxow4ILBA=='},
#      {'text': 'Toulouse', 'value': '_1J17G-7rhIwEEEvnPYGBA=='},
#      {'text': 'Lyon', 'value': 'l4foalHq9EfwIbvkKqsIBA=='},
#      {'text': 'Nanterre', 'value': 'vyXf2YRk5kfiR8FqHO4hew=='},
#      {'text': 'Lille', 'value': 'EW4ls3nVwkdgY2SBPvEKBA=='},
#      {'text': 'Bordeaux', 'value': 'gcpR9-gnVQ2Jejl7A4ZjeQ=='},
#      {'text': 'Courbevoie', 'value': 'vccvsApl5kcQPotow4ILBA=='},
#      {'text': 'Issy-les-Moulineaux', 'value': 'xy7Ltot65kehJ24ad9Amiw=='},
#      {'text': 'Marseille', 'value': 'M1PaREO_yRIgApf9pRkIBA=='},
#      {'text': 'Montrouge', 'value': '_1dbg_9w5kdwPYtow4ILBA=='},
#      {'text': 'Vélizy-Villacoublay', 'value': '-acYgeR75kdQNoxow4ILBA=='},
#      {'text': 'Boulogne-Billancourt', 'value': 'YUevEOh65keQPotow4ILBA=='},
#      {'text': 'Grenoble', 'value': 'b76J1ov0ikeYU5luzRCMYQ=='},
#      {'text': 'Massy', 'value': 'ASDNmoR35kenA6QiZFUPAw=='},
#      {'text': 'Nantes', 'value': 'ra6o8IHuBUgw7Q0eUjcNBA=='},
#      {'text': 'Puteaux', 'value': 'xfUaLBpl5kfgyvJ51T872A=='},
#      {'text': 'Antibes', 'value': 'qZFankXVzRKwn5f9pRkIBA=='},
#      {'text': 'Clichy', 'value': '37pZhAxv5kfLaxOwc6RdcA=='},
#      {'text': 'Levallois-Perret', 'value': '0_88t4Nv5kewPYtow4ILBA=='},
#      {'text': 'Neuilly-sur-Seine', 'value': 'tZbjc2Nl5keXszL1nHU53A=='},
#      {'text': 'Strasbourg', 'value': 'wbIYXknIlkcfJOcYMUgalw=='},
#      {'text': 'Agen', 'value': 'D4OF_xqzqxLwuxVIF2UGBA=='},
#      {'text': 'Allemagne-en-Provence', 'value': 'oVNVKdbCyxJgt5f9pRkIBA=='},
#      {'text': 'Bezons', 'value': '04KEHBZk5kegNYtow4ILBA=='},
#      {'text': 'Bourges', 'value': 'F7SbuHeW-ke-hVzNLCj7yw=='},
#      {'text': 'Canéjan', 'value': 'A5fzhL_eVA1g6xZIF2UGBA=='},
#      {'text': 'Charleville-Mézières', 'value': 'JwwUbuAN6keAej-auV8KBA=='},
#      {'text': 'Chilly-Mazarin', 'value': 'WcQYRi125kcASItow4ILBA=='},
#      {'text': 'Colombes', 'value': 'S0wd8shl5kcgPotow4ILBA=='},
#      {'text': 'Flavignerot', 'value': 'o1wYtnaD8kdgVhSzNM4JBA=='},
#      {'text': 'Gennevilliers', 'value': 'MbQYxkVv5kd18XYNkk4MlQ=='},
#      {'text': 'Hyères', 'value': '7xx-cKIjyRJr7ZQfIa7BaQ=='},
#      {'text': 'Lannion', 'value': 'OcUjxYorEkgANOY2zaUMBA=='},
#      {'text': 'Malakoff', 'value': 'd8fRiVlw5keYvnXO7sKbPQ=='},
#      {'text': 'Metz', 'value': 'qbZ0YBvclEdpprs1tuRrWQ=='},
#      {'text': 'Meudon', 'value': 'Ae9HWkt65keAPYtow4ILBA=='},
#      {'text': 'Montereau-sur-le-Jard', 'value': 'uwmGP5D75UcwU4xow4ILBA=='},
#      {'text': 'Montpellier', 'value': 'sZ3dJQevthIC6JQodFaHrQ=='},
#      {'text': 'Montréal', 'value': 'F5gMpnhKrhLKGeV33xjrWw=='},
#      {'text': 'Mérignac', 'value': 'tyOAutvZVA12HoHc9b1EVg=='},
#      {'text': 'Nice', 'value': 'MS2FahDQzRJwmpf9pRkIBA=='},
#      {'text': 'Palaiseau', 'value': '64K8yBV45kemNIxi0I3PDw=='},
#      {'text': 'Poissy', 'value': '42Xt3UeJ5kegOYxow4ILBA=='},
#      {'text': 'Reims', 'value': 'CTtTSjN06UfARTuauV8KBA=='},
#      {'text': 'Saint-Ouen-sur-Seine', 'value': 'Dak3HeRu5keQOotow4ILBA=='},
#      {'text': 'Saint-Sébastien-sur-Loire',
#       'value': 'vejCfDPvBUhA6A0eUjcNBA=='},
#      {'text': 'Suresnes', 'value': '584OtMVk5kfgPItow4ILBA=='},
#      {'text': 'Tremblay-en-France', 'value': 'z0HtktIV5kdgOotow4ILBA=='},
#      {'text': 'Villejuif', 'value': '8zhyol9x5keAN4tow4ILBA=='},
#      {'text': 'Évry-Courcouronnes', 'value': 'D4p2DBne5UeYqgg1R6bxkw=='}]},
#    {'type': 'Date posted',
#     'param': 'date_posted',
#     'options': [{'text': 'All'},
#      {'text': 'Past day', 'value': 'today'},
#      {'text': 'Past 3 days', 'value': '3days'},
#      {'text': 'Past week', 'value': 'week'},
#      {'text': 'Past month', 'value': 'month'}]},
#    {'type': 'Requirements',
#     'param': 'requirements',
#     'options': [{'text': 'All'},
#      {'text': 'No degree', 'value': 'no_degree'},
#      {'text': 'No experience', 'value': 'no_experience'},
#      {'text': 'Under 3 years of experience', 'value': 'years3under'},
#      {'text': '3+ years of experience', 'value': 'years3plus'}]},
#    {'type': 'Language',
#     'param': 'language',
#     'options': [{'text': 'All'},
#      {'text': 'English Results', 'value': 'en'},
#      {'text': 'French Results', 'value': 'fr'}]},
#    {'type': 'Type',
#     'param': 'employment_type',
#     'options': [{'text': 'All'},
#      {'text': 'Full-time', 'value': 'FULLTIME'},
#      {'text': 'Internship', 'value': 'INTERN'},
#      {'text': 'Part-time', 'value': 'PARTTIME'},
#      {'text': 'Contractor', 'value': 'CONTRACTOR'}]},
#    {'type': 'Company type',
#     'param': 'industry.id',
#     'options': [{'text': 'All'},
#      {'text': 'Finance', 'value': '/business/naics2007/52'},
#      {'text': 'Information', 'value': '/business/naics2007/51'},
#      {'text': 'Manufacturing', 'value': '/business/naics2007/31'},
#      {'text': 'Computer Services', 'value': '/business/naics2007/5415'},
#      {'text': 'Consulting', 'value': '/business/naics2007/5416'},
#      {'text': 'Retail', 'value': '/business/naics2007/44'},
#      {'text': 'Logistics', 'value': '/business/naics2007/48'},
#      {'text': 'Textiles & Apparel', 'value': '/business/naics2007/313'},
#      {'text': 'Utilities', 'value': '/business/naics2007/22'},
#      {'text': 'Advertising', 'value': '/business/naics2007/5418'},
#      {'text': 'Education', 'value': '/business/naics2007/61'},
#      {'text': 'Health Care', 'value': '/business/naics2007/62'},
#      {'text': 'Mining', 'value': '/business/naics2007/21'},
#      {'text': 'Accommodation', 'value': '/business/naics2007/721'},
#      {'text': 'Accounting', 'value': '/business/naics2007/5412'},
#      {'text': 'Administrative and Support and Waste Management and Remediation Services',
#       'value': '/business/naics2007/56'},
#      {'text': 'Engineering Services', 'value': '/business/naics2007/5413'},
#      {'text': 'Foods & Beverages', 'value': '/business/naics2007/311'},
#      {'text': 'Management', 'value': '/business/naics2007/55'},
#      {'text': 'Personal Services', 'value': '/business/naics2007/8129'},
#      {'text': 'Professional, Scientific, and Technical Services',
#       'value': '/business/naics2007/54'},
#      {'text': 'Rental', 'value': '/business/naics2007/532'},
#      {'text': 'Staffing', 'value': '/business/naics2007/5613'},
#      {'text': 'Toiletries', 'value': '/business/naics2007/3256'}]},
#    {'type': 'Employer',
#     'param': 'organization_mid',
#     'options': [{'text': 'All'},
#      {'text': 'Datadog', 'value': '/m/0wfvvyq'},
#      {'text': 'Societe Generale', 'value': '/m/02qhc8'},
#      {'text': 'AXA S.A.', 'value': '/m/04mn99'},
#      {'text': 'Shift Technology', 'value': '/g/11h_q0qhfh'},
#      {'text': 'Airbus SE', 'value': '/g/11bc58lzpk'},
#      {'text': 'BNP Paribas', 'value': '/m/02qhk4'},
#      {'text': 'Doctolib', 'value': '/g/1ptx3f6gm'},
#      {'text': 'Hewlett-Packard Company', 'value': '/m/03mnk'},
#      {'text': 'Kayrros', 'value': '/g/11s1t5rdj0'},
#      {'text': 'Allianz', 'value': '/m/03s59j'},
#      {'text': 'Bayer', 'value': '/m/01snr1'},
#      {'text': 'Crédit Agricole SA', 'value': '/m/028vbm'},
#      {'text': 'Ekimetrics', 'value': '/g/1tl_l0gw'},
#      {'text': 'Groupe BPCE', 'value': '/m/0cm90f2'},
#      {'text': 'Stellantis', 'value': '/g/11fpjwysk8'},
#      {'text': 'Capgemini', 'value': '/m/03vlk0'},
#      {'text': 'Capgemini Engineering', 'value': '/m/0410vv'},
#      {'text': 'Carrefour', 'value': '/m/016drc'},
#      {'text': 'Cdiscount', 'value': '/m/0121rjwm'},
#      {'text': 'ENGIE', 'value': '/m/04f7b89'},
#      {'text': 'Essity', 'value': '/g/11fx8k5xpn'},
#      {'text': 'Glocomms', 'value': '/g/11t42n5g9b'},
#      {'text': 'Iliad', 'value': '/m/04jhmd3'},
#      {'text': 'King', 'value': '/m/03gp092'},
#      {'text': 'Levi Strauss & Co.', 'value': '/m/02j46m'},
#      {'text': 'McKinsey & Company', 'value': '/m/02zt92'},
#      {'text': 'Orange SA', 'value': '/m/0jd05'},
#      {'text': 'Pernod Ricard', 'value': '/m/031vfd'},
#      {'text': 'Pôle Emploi', 'value': '/m/064k86k'},
#      {'text': 'Qantev', 'value': '/g/11l1n1zkfs'},
#      {'text': 'QuantCube Technology', 'value': '/g/11fmddnjr2'},
#      {'text': 'SUEZ', 'value': '/g/11b6yf66qy'},
#      {'text': 'Sanofi S.A.', 'value': '/m/02qsg_'},
#      {'text': 'Volvo Group', 'value': '/m/07yw2'},
#      {'text': 'ACAVI', 'value': '/g/1w111hry'},
#      {'text': 'ACCORINVEST', 'value': '/g/11g9mwkltn'},
#      {'text': 'AFPA', 'value': '/g/122p7tdj'},
#      {'text': 'ARDIAN', 'value': '/m/0dj6l2'},
#      {'text': 'AUTO1 Group', 'value': '/g/11f3w6lm1y'}]}]},
#  {'search_metadata': {'id': '65606cb13944b0fe21cedea8',
#    'status': 'Success',
#    'json_endpoint': 'https://serpapi.com/searches/e26f1d31d665de90/65606cb13944b0fe21cedea8.json',
#    'created_at': '2023-11-24 09:28:17 UTC',
#    'processed_at': '2023-11-24 09:28:17 UTC',
#    'google_jobs_url': 'https://www.google.com/search?q=Data+Scientist&ibp=htl;jobs&uule=w+CAIQICIgUGFyaXMsUGFyaXMsSWxlLWRlLUZyYW5jZSxGcmFuY2U&hl=en&start=300',
#    'raw_html_file': 'https://serpapi.com/searches/e26f1d31d665de90/65606cb13944b0fe21cedea8.html',
#    'total_time_taken': 1.91},
#   'search_parameters': {'q': 'Data Scientist',
#    'engine': 'google_jobs',
#    'location_requested': 'Paris, France',
#    'location_used': 'Paris,Paris,Ile-de-France,France',
#    'google_domain': 'google.com',
#    'hl': 'en',
#    'start': 300},
#   'search_information': {'jobs_results_state': 'Fully empty'},
#   'error': "Google hasn't returned any results for this query."}]
